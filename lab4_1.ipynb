# %%
"""This module implements data feeding and training loop to create model
to classify X-Ray chest images as a lab example for BSU students.
"""

__author__ = 'Alexander Soroka, soroka.a.m@gmail.com'
__copyright__ = """Copyright 2020 Alexander Soroka"""


import argparse
import glob
import numpy as np
import tensorflow as tf
import time
from tensorflow.python import keras as keras
from tensorflow.python.keras.callbacks import LearningRateScheduler


LOG_DIR = 'logs'
SHUFFLE_BUFFER = 4
BATCH_SIZE = 32
NUM_CLASSES = 6
PARALLEL_CALLS=4
RESIZE_TO = 224
TRAINSET_SIZE = 14034
VALSET_SIZE = 3000


def parse_proto_example(proto):
    keys_to_features = {
        'image/encoded': tf.io.FixedLenFeature((), tf.string, default_value=''),
        'image/class/label': tf.io.FixedLenFeature([], tf.int64, default_value=tf.zeros([], dtype=tf.int64))
    }
    example = tf.io.parse_single_example(proto, keys_to_features)
    example['image'] = tf.image.decode_jpeg(example['image/encoded'], channels=3)
    example['image'] = tf.image.convert_image_dtype(example['image'], dtype=tf.float32)
    example['image'] = tf.image.resize(example['image'], tf.constant([RESIZE_TO, RESIZE_TO]))
    return example['image'], tf.one_hot(example['image/class/label'], depth=NUM_CLASSES)


def normalize(image, label):
    return tf.image.per_image_standardization(image), label

def resize(image, label):
    return tf.image.resize(image, tf.constant([RESIZE_TO, RESIZE_TO])), label

def create_dataset(filenames, batch_size):
    """Create dataset from tfrecords file
    :tfrecords_files: Mask to collect tfrecords file of dataset
    :returns: tf.data.Dataset
    """
    return tf.data.TFRecordDataset(filenames)\
        .map(parse_proto_example)\
        .map(resize)\
        .map(normalize)\
        .batch(batch_size)\
        .prefetch(batch_size)

def create_aug_dataset(filenames, batch_size):
    """Create dataset from tfrecords file
    :tfrecords_files: Mask to collect tfrecords file of dataset
    :returns: tf.data.Dataset
    """
    return tf.data.TFRecordDataset(filenames)\
        .map(parse_proto_example)\
        .map(augmentation)\
        .map(resize)\
        .map(normalize)\
        .shuffle(buffer_size=5 * batch_size)\
        .batch(batch_size)\
        .prefetch(2 * batch_size)

def augmentation(image, label):
    image = tf.image.convert_image_dtype(image, tf.float32)
    image = tf.image.random_flip_left_right(image)
    return image, label

def build_model():

    new_model = tf.keras.applications.MobileNetV2(input_shape=(224,224,3),
						classes = NUM_CLASSES,
            include_top=False,
            weights='imagenet')
    

    inputs = tf.keras.Input(shape=(224, 224, 3))

    x = new_model(inputs)
    x = tf.keras.layers.GlobalAveragePooling2D()(x)
    x = tf.keras.layers.Dropout(0.2)(x)
    x = tf.keras.layers.Flatten()(x)
    outputs = tf.keras.layers.Dense(NUM_CLASSES, activation=tf.keras.activations.softmax)(x)
    model = tf.keras.Model(inputs, outputs)

    return model


def main():
    train_path = '/content/drive/My Drive/SMOMI/dataset/train*'
    test_path = '/content/drive/My Drive/SMOMI/dataset/val*'

    train_dataset = create_aug_dataset(glob.glob(train_path), BATCH_SIZE)
    validation_dataset = create_dataset(glob.glob(test_path), BATCH_SIZE)

    model = build_model()

    model.compile(
        optimizer=tf.optimizers.Adam(lr=4e-6),
        loss=tf.keras.losses.categorical_crossentropy,
        metrics=[tf.keras.metrics.categorical_accuracy],
    )

    log_dir='/content/drive/My Drive/SMOMI/{}/lab4_1/ilcd-{}'.format(LOG_DIR, time.time())
    weights_file = "/content/drive/My Drive/SMOMI/w-l-4_1new.hdf5"

    model.fit(
        train_dataset,
        epochs=100,
        validation_data=validation_dataset,
        callbacks=[
            tf.keras.callbacks.TensorBoard(log_dir),
            tf.keras.callbacks.ModelCheckpoint(filepath=weights_file, monitor='val_categorical_accuracy', mode='max', save_best_only=True, save_weights_only=True, verbose=1)
        ]
    )

if __name__ == '__main__':
    main()
# Out:
# Epoch 1/100
#       2/Unknown - 1s 456ms/step - loss: 2.2913 - categorical_accuracy: 0.0469WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1039s vs `on_train_batch_end` time: 0.8049s). Check your callbacks.
#     439/Unknown - 48s 110ms/step - loss: 1.8281 - categorical_accuracy: 0.0938
# Epoch 00001: val_categorical_accuracy improved from -inf to 0.12900, saving model to /content/drive/My Drive/SMOMI/w-l-4_1new.hdf5
# 439/439 [==============================] - 60s 136ms/step - loss: 1.8281 - categorical_accuracy: 0.0938 - val_loss: 1.6713 - val_categorical_accuracy: 0.1290
# Epoch 2/100
# 439/439 [==============================] - ETA: 0s - loss: 1.6761 - categorical_accuracy: 0.1242
# Epoch 00002: val_categorical_accuracy improved from 0.12900 to 0.15400, saving model to /content/drive/My Drive/SMOMI/w-l-4_1new.hdf5
# 439/439 [==============================] - 58s 133ms/step - loss: 1.6761 - categorical_accuracy: 0.1242 - val_loss: 1.5428 - val_categorical_accuracy: 0.1540
# Epoch 3/100
# 439/439 [==============================] - ETA: 0s - loss: 1.5521 - categorical_accuracy: 0.1541
# Epoch 00003: val_categorical_accuracy improved from 0.15400 to 0.18733, saving model to /content/drive/My Drive/SMOMI/w-l-4_1new.hdf5
# 439/439 [==============================] - 58s 133ms/step - loss: 1.5521 - categorical_accuracy: 0.1541 - val_loss: 1.4471 - val_categorical_accuracy: 0.1873
# Epoch 4/100
# 439/439 [==============================] - ETA: 0s - loss: 1.4448 - categorical_accuracy: 0.1965
# Epoch 00004: val_categorical_accuracy improved from 0.18733 to 0.22333, saving model to /content/drive/My Drive/SMOMI/w-l-4_1new.hdf5
# 439/439 [==============================] - 59s 133ms/step - loss: 1.4448 - categorical_accuracy: 0.1965 - val_loss: 1.3718 - val_categorical_accuracy: 0.2233
# Epoch 5/100
# 439/439 [==============================] - ETA: 0s - loss: 1.3564 - categorical_accuracy: 0.2359
# Epoch 00005: val_categorical_accuracy improved from 0.22333 to 0.25433, saving model to /content/drive/My Drive/SMOMI/w-l-4_1new.hdf5
# 439/439 [==============================] - 59s 133ms/step - loss: 1.3564 - categorical_accuracy: 0.2359 - val_loss: 1.3091 - val_categorical_accuracy: 0.2543
# Epoch 6/100
# 439/439 [==============================] - ETA: 0s - loss: 1.2795 - categorical_accuracy: 0.2697
# Epoch 00006: val_categorical_accuracy improved from 0.25433 to 0.28433, saving model to /content/drive/My Drive/SMOMI/w-l-4_1new.hdf5
# 439/439 [==============================] - 58s 133ms/step - loss: 1.2795 - categorical_accuracy: 0.2697 - val_loss: 1.2539 - val_categorical_accuracy: 0.2843
# Epoch 7/100
# 439/439 [==============================] - ETA: 0s - loss: 1.2089 - categorical_accuracy: 0.3061
# Epoch 00007: val_categorical_accuracy improved from 0.28433 to 0.31400, saving model to /content/drive/My Drive/SMOMI/w-l-4_1new.hdf5
# 439/439 [==============================] - 59s 133ms/step - loss: 1.2089 - categorical_accuracy: 0.3061 - val_loss: 1.2027 - val_categorical_accuracy: 0.3140
# Epoch 8/100
# 439/439 [==============================] - ETA: 0s - loss: 1.1474 - categorical_accuracy: 0.3352
# Epoch 00008: val_categorical_accuracy improved from 0.31400 to 0.33533, saving model to /content/drive/My Drive/SMOMI/w-l-4_1new.hdf5
# 439/439 [==============================] - 58s 132ms/step - loss: 1.1474 - categorical_accuracy: 0.3352 - val_loss: 1.1548 - val_categorical_accuracy: 0.3353
# Epoch 9/100
# 439/439 [==============================] - ETA: 0s - loss: 1.0883 - categorical_accuracy: 0.3707
# Epoch 00009: val_categorical_accuracy improved from 0.33533 to 0.36100, saving model to /content/drive/My Drive/SMOMI/w-l-4_1new.hdf5
# 439/439 [==============================] - 59s 133ms/step - loss: 1.0883 - categorical_accuracy: 0.3707 - val_loss: 1.1096 - val_categorical_accuracy: 0.3610
# Epoch 10/100
# 439/439 [==============================] - ETA: 0s - loss: 1.0366 - categorical_accuracy: 0.4031
# Epoch 00010: val_categorical_accuracy improved from 0.36100 to 0.39267, saving model to /content/drive/My Drive/SMOMI/w-l-4_1new.hdf5
# 439/439 [==============================] - 58s 133ms/step - loss: 1.0366 - categorical_accuracy: 0.4031 - val_loss: 1.0669 - val_categorical_accuracy: 0.3927
# Epoch 11/100
# 439/439 [==============================] - ETA: 0s - loss: 0.9856 - categorical_accuracy: 0.4268
# Epoch 00011: val_categorical_accuracy improved from 0.39267 to 0.41067, saving model to /content/drive/My Drive/SMOMI/w-l-4_1new.hdf5
# 439/439 [==============================] - 58s 133ms/step - loss: 0.9856 - categorical_accuracy: 0.4268 - val_loss: 1.0261 - val_categorical_accuracy: 0.4107
# Epoch 12/100
# 439/439 [==============================] - ETA: 0s - loss: 0.9443 - categorical_accuracy: 0.4506
# Epoch 00012: val_categorical_accuracy improved from 0.41067 to 0.43500, saving model to /content/drive/My Drive/SMOMI/w-l-4_1new.hdf5
# 439/439 [==============================] - 58s 133ms/step - loss: 0.9443 - categorical_accuracy: 0.4506 - val_loss: 0.9875 - val_categorical_accuracy: 0.4350
# Epoch 13/100
# 439/439 [==============================] - ETA: 0s - loss: 0.9015 - categorical_accuracy: 0.4705
# Epoch 00013: val_categorical_accuracy improved from 0.43500 to 0.45367, saving model to /content/drive/My Drive/SMOMI/w-l-4_1new.hdf5
# 439/439 [==============================] - 59s 133ms/step - loss: 0.9015 - categorical_accuracy: 0.4705 - val_loss: 0.9516 - val_categorical_accuracy: 0.4537
# Epoch 14/100
# 439/439 [==============================] - ETA: 0s - loss: 0.8539 - categorical_accuracy: 0.4989
# Epoch 00014: val_categorical_accuracy improved from 0.45367 to 0.47500, saving model to /content/drive/My Drive/SMOMI/w-l-4_1new.hdf5
# 439/439 [==============================] - 58s 133ms/step - loss: 0.8539 - categorical_accuracy: 0.4989 - val_loss: 0.9178 - val_categorical_accuracy: 0.4750
# Epoch 15/100
# 439/439 [==============================] - ETA: 0s - loss: 0.8191 - categorical_accuracy: 0.5176
# Epoch 00015: val_categorical_accuracy improved from 0.47500 to 0.49467, saving model to /content/drive/My Drive/SMOMI/w-l-4_1new.hdf5
# 439/439 [==============================] - 59s 134ms/step - loss: 0.8191 - categorical_accuracy: 0.5176 - val_loss: 0.8858 - val_categorical_accuracy: 0.4947
# Epoch 16/100
# 439/439 [==============================] - ETA: 0s - loss: 0.7916 - categorical_accuracy: 0.5270
# Epoch 00016: val_categorical_accuracy improved from 0.49467 to 0.50900, saving model to /content/drive/My Drive/SMOMI/w-l-4_1new.hdf5
# 439/439 [==============================] - 58s 133ms/step - loss: 0.7916 - categorical_accuracy: 0.5270 - val_loss: 0.8559 - val_categorical_accuracy: 0.5090
# Epoch 17/100
# 439/439 [==============================] - ETA: 0s - loss: 0.7603 - categorical_accuracy: 0.5467
# Epoch 00017: val_categorical_accuracy improved from 0.50900 to 0.52300, saving model to /content/drive/My Drive/SMOMI/w-l-4_1new.hdf5
# 439/439 [==============================] - 59s 134ms/step - loss: 0.7603 - categorical_accuracy: 0.5467 - val_loss: 0.8277 - val_categorical_accuracy: 0.5230
# Epoch 18/100
# 439/439 [==============================] - ETA: 0s - loss: 0.7298 - categorical_accuracy: 0.5553
# Epoch 00018: val_categorical_accuracy improved from 0.52300 to 0.53400, saving model to /content/drive/My Drive/SMOMI/w-l-4_1new.hdf5
# 439/439 [==============================] - 59s 134ms/step - loss: 0.7298 - categorical_accuracy: 0.5553 - val_loss: 0.8013 - val_categorical_accuracy: 0.5340
# Epoch 19/100
# 439/439 [==============================] - ETA: 0s - loss: 0.6990 - categorical_accuracy: 0.5733
# Epoch 00019: val_categorical_accuracy improved from 0.53400 to 0.54833, saving model to /content/drive/My Drive/SMOMI/w-l-4_1new.hdf5
# 439/439 [==============================] - 59s 133ms/step - loss: 0.6990 - categorical_accuracy: 0.5733 - val_loss: 0.7767 - val_categorical_accuracy: 0.5483
# Epoch 20/100
# 439/439 [==============================] - ETA: 0s - loss: 0.6840 - categorical_accuracy: 0.5748
# Epoch 00020: val_categorical_accuracy improved from 0.54833 to 0.55833, saving model to /content/drive/My Drive/SMOMI/w-l-4_1new.hdf5
# 439/439 [==============================] - 58s 133ms/step - loss: 0.6840 - categorical_accuracy: 0.5748 - val_loss: 0.7533 - val_categorical_accuracy: 0.5583
# Epoch 21/100
# 439/439 [==============================] - ETA: 0s - loss: 0.6571 - categorical_accuracy: 0.5837
# Epoch 00021: val_categorical_accuracy improved from 0.55833 to 0.56900, saving model to /content/drive/My Drive/SMOMI/w-l-4_1new.hdf5
# 439/439 [==============================] - 59s 133ms/step - loss: 0.6571 - categorical_accuracy: 0.5837 - val_loss: 0.7315 - val_categorical_accuracy: 0.5690
# Epoch 22/100
# 439/439 [==============================] - ETA: 0s - loss: 0.6326 - categorical_accuracy: 0.5965
# Epoch 00022: val_categorical_accuracy improved from 0.56900 to 0.57767, saving model to /content/drive/My Drive/SMOMI/w-l-4_1new.hdf5
# 439/439 [==============================] - 59s 133ms/step - loss: 0.6326 - categorical_accuracy: 0.5965 - val_loss: 0.7113 - val_categorical_accuracy: 0.5777
# Epoch 23/100
# 439/439 [==============================] - ETA: 0s - loss: 0.6145 - categorical_accuracy: 0.5992
# Epoch 00023: val_categorical_accuracy improved from 0.57767 to 0.58400, saving model to /content/drive/My Drive/SMOMI/w-l-4_1new.hdf5
# 439/439 [==============================] - 59s 133ms/step - loss: 0.6145 - categorical_accuracy: 0.5992 - val_loss: 0.6924 - val_categorical_accuracy: 0.5840
# Epoch 24/100
# 439/439 [==============================] - ETA: 0s - loss: 0.5956 - categorical_accuracy: 0.6081
# Epoch 00024: val_categorical_accuracy improved from 0.58400 to 0.59033, saving model to /content/drive/My Drive/SMOMI/w-l-4_1new.hdf5
# 439/439 [==============================] - 58s 133ms/step - loss: 0.5956 - categorical_accuracy: 0.6081 - val_loss: 0.6743 - val_categorical_accuracy: 0.5903
# Epoch 25/100
# 439/439 [==============================] - ETA: 0s - loss: 0.5814 - categorical_accuracy: 0.6137
# Epoch 00025: val_categorical_accuracy improved from 0.59033 to 0.59833, saving model to /content/drive/My Drive/SMOMI/w-l-4_1new.hdf5
# 439/439 [==============================] - 59s 134ms/step - loss: 0.5814 - categorical_accuracy: 0.6137 - val_loss: 0.6576 - val_categorical_accuracy: 0.5983
# Epoch 26/100
# 439/439 [==============================] - ETA: 0s - loss: 0.5688 - categorical_accuracy: 0.6201
# Epoch 00026: val_categorical_accuracy improved from 0.59833 to 0.60633, saving model to /content/drive/My Drive/SMOMI/w-l-4_1new.hdf5
# 439/439 [==============================] - 59s 133ms/step - loss: 0.5688 - categorical_accuracy: 0.6201 - val_loss: 0.6417 - val_categorical_accuracy: 0.6063
# Epoch 27/100
# 439/439 [==============================] - ETA: 0s - loss: 0.5516 - categorical_accuracy: 0.6228
# Epoch 00027: val_categorical_accuracy improved from 0.60633 to 0.61267, saving model to /content/drive/My Drive/SMOMI/w-l-4_1new.hdf5
# 439/439 [==============================] - 59s 134ms/step - loss: 0.5516 - categorical_accuracy: 0.6228 - val_loss: 0.6268 - val_categorical_accuracy: 0.6127
# Epoch 28/100
# 439/439 [==============================] - ETA: 0s - loss: 0.5341 - categorical_accuracy: 0.6320
# Epoch 00028: val_categorical_accuracy improved from 0.61267 to 0.61667, saving model to /content/drive/My Drive/SMOMI/w-l-4_1new.hdf5
# 439/439 [==============================] - 58s 133ms/step - loss: 0.5341 - categorical_accuracy: 0.6320 - val_loss: 0.6128 - val_categorical_accuracy: 0.6167
# Epoch 29/100
# 439/439 [==============================] - ETA: 0s - loss: 0.5216 - categorical_accuracy: 0.6361
# Epoch 00029: val_categorical_accuracy improved from 0.61667 to 0.62333, saving model to /content/drive/My Drive/SMOMI/w-l-4_1new.hdf5
# 439/439 [==============================] - 59s 134ms/step - loss: 0.5216 - categorical_accuracy: 0.6361 - val_loss: 0.5995 - val_categorical_accuracy: 0.6233
# Epoch 30/100
# 439/439 [==============================] - ETA: 0s - loss: 0.5125 - categorical_accuracy: 0.6380
# Epoch 00030: val_categorical_accuracy improved from 0.62333 to 0.62667, saving model to /content/drive/My Drive/SMOMI/w-l-4_1new.hdf5
# 439/439 [==============================] - 59s 134ms/step - loss: 0.5125 - categorical_accuracy: 0.6380 - val_loss: 0.5869 - val_categorical_accuracy: 0.6267
# Epoch 31/100
# 439/439 [==============================] - ETA: 0s - loss: 0.5010 - categorical_accuracy: 0.6428
# Epoch 00031: val_categorical_accuracy improved from 0.62667 to 0.63067, saving model to /content/drive/My Drive/SMOMI/w-l-4_1new.hdf5
# 439/439 [==============================] - 59s 134ms/step - loss: 0.5010 - categorical_accuracy: 0.6428 - val_loss: 0.5749 - val_categorical_accuracy: 0.6307
# Epoch 32/100
# 439/439 [==============================] - ETA: 0s - loss: 0.4912 - categorical_accuracy: 0.6451
# Epoch 00032: val_categorical_accuracy improved from 0.63067 to 0.63467, saving model to /content/drive/My Drive/SMOMI/w-l-4_1new.hdf5
# 439/439 [==============================] - 59s 133ms/step - loss: 0.4912 - categorical_accuracy: 0.6451 - val_loss: 0.5638 - val_categorical_accuracy: 0.6347
# Epoch 33/100
# 439/439 [==============================] - ETA: 0s - loss: 0.4815 - categorical_accuracy: 0.6478
# Epoch 00033: val_categorical_accuracy improved from 0.63467 to 0.63833, saving model to /content/drive/My Drive/SMOMI/w-l-4_1new.hdf5
# 439/439 [==============================] - 59s 135ms/step - loss: 0.4815 - categorical_accuracy: 0.6478 - val_loss: 0.5533 - val_categorical_accuracy: 0.6383
# Epoch 34/100
# 439/439 [==============================] - ETA: 0s - loss: 0.4758 - categorical_accuracy: 0.6474
# Epoch 00034: val_categorical_accuracy improved from 0.63833 to 0.64133, saving model to /content/drive/My Drive/SMOMI/w-l-4_1new.hdf5
# 439/439 [==============================] - 59s 134ms/step - loss: 0.4758 - categorical_accuracy: 0.6474 - val_loss: 0.5435 - val_categorical_accuracy: 0.6413
# Epoch 35/100
# 439/439 [==============================] - ETA: 0s - loss: 0.4610 - categorical_accuracy: 0.6552
# Epoch 00035: val_categorical_accuracy improved from 0.64133 to 0.64400, saving model to /content/drive/My Drive/SMOMI/w-l-4_1new.hdf5
# 439/439 [==============================] - 59s 134ms/step - loss: 0.4610 - categorical_accuracy: 0.6552 - val_loss: 0.5340 - val_categorical_accuracy: 0.6440
# Epoch 36/100
# 439/439 [==============================] - ETA: 0s - loss: 0.4580 - categorical_accuracy: 0.6572
# Epoch 00036: val_categorical_accuracy improved from 0.64400 to 0.64767, saving model to /content/drive/My Drive/SMOMI/w-l-4_1new.hdf5
# 439/439 [==============================] - 59s 134ms/step - loss: 0.4580 - categorical_accuracy: 0.6572 - val_loss: 0.5252 - val_categorical_accuracy: 0.6477
# Epoch 37/100
# 439/439 [==============================] - ETA: 0s - loss: 0.4491 - categorical_accuracy: 0.6591
# Epoch 00037: val_categorical_accuracy improved from 0.64767 to 0.65233, saving model to /content/drive/My Drive/SMOMI/w-l-4_1new.hdf5
# 439/439 [==============================] - 59s 134ms/step - loss: 0.4491 - categorical_accuracy: 0.6591 - val_loss: 0.5167 - val_categorical_accuracy: 0.6523
# Epoch 38/100
# 439/439 [==============================] - ETA: 0s - loss: 0.4431 - categorical_accuracy: 0.6623
# Epoch 00038: val_categorical_accuracy improved from 0.65233 to 0.65600, saving model to /content/drive/My Drive/SMOMI/w-l-4_1new.hdf5
# 439/439 [==============================] - 59s 134ms/step - loss: 0.4431 - categorical_accuracy: 0.6623 - val_loss: 0.5088 - val_categorical_accuracy: 0.6560
# Epoch 39/100
# 439/439 [==============================] - ETA: 0s - loss: 0.4340 - categorical_accuracy: 0.6670
# Epoch 00039: val_categorical_accuracy improved from 0.65600 to 0.65867, saving model to /content/drive/My Drive/SMOMI/w-l-4_1new.hdf5
# 439/439 [==============================] - 59s 134ms/step - loss: 0.4340 - categorical_accuracy: 0.6670 - val_loss: 0.5011 - val_categorical_accuracy: 0.6587
# Epoch 40/100
# 439/439 [==============================] - ETA: 0s - loss: 0.4287 - categorical_accuracy: 0.6704
# Epoch 00040: val_categorical_accuracy improved from 0.65867 to 0.66067, saving model to /content/drive/My Drive/SMOMI/w-l-4_1new.hdf5
# 439/439 [==============================] - 59s 134ms/step - loss: 0.4287 - categorical_accuracy: 0.6704 - val_loss: 0.4939 - val_categorical_accuracy: 0.6607
# Epoch 41/100
# 439/439 [==============================] - ETA: 0s - loss: 0.4229 - categorical_accuracy: 0.6679
# Epoch 00041: val_categorical_accuracy improved from 0.66067 to 0.66367, saving model to /content/drive/My Drive/SMOMI/w-l-4_1new.hdf5
# 439/439 [==============================] - 59s 134ms/step - loss: 0.4229 - categorical_accuracy: 0.6679 - val_loss: 0.4871 - val_categorical_accuracy: 0.6637
# Epoch 42/100
# 439/439 [==============================] - ETA: 0s - loss: 0.4181 - categorical_accuracy: 0.6732
# Epoch 00042: val_categorical_accuracy improved from 0.66367 to 0.66567, saving model to /content/drive/My Drive/SMOMI/w-l-4_1new.hdf5
# 439/439 [==============================] - 59s 134ms/step - loss: 0.4181 - categorical_accuracy: 0.6732 - val_loss: 0.4806 - val_categorical_accuracy: 0.6657
# Epoch 43/100
# 439/439 [==============================] - ETA: 0s - loss: 0.4111 - categorical_accuracy: 0.6763
# Epoch 00043: val_categorical_accuracy improved from 0.66567 to 0.66667, saving model to /content/drive/My Drive/SMOMI/w-l-4_1new.hdf5
# 439/439 [==============================] - 59s 134ms/step - loss: 0.4111 - categorical_accuracy: 0.6763 - val_loss: 0.4743 - val_categorical_accuracy: 0.6667
# Epoch 44/100
# 439/439 [==============================] - ETA: 0s - loss: 0.4069 - categorical_accuracy: 0.6702
# Epoch 00044: val_categorical_accuracy improved from 0.66667 to 0.66800, saving model to /content/drive/My Drive/SMOMI/w-l-4_1new.hdf5
# 439/439 [==============================] - 59s 134ms/step - loss: 0.4069 - categorical_accuracy: 0.6702 - val_loss: 0.4684 - val_categorical_accuracy: 0.6680
# Epoch 45/100
# 439/439 [==============================] - ETA: 0s - loss: 0.4027 - categorical_accuracy: 0.6788
# Epoch 00045: val_categorical_accuracy improved from 0.66800 to 0.66933, saving model to /content/drive/My Drive/SMOMI/w-l-4_1new.hdf5
# 439/439 [==============================] - 59s 134ms/step - loss: 0.4027 - categorical_accuracy: 0.6788 - val_loss: 0.4629 - val_categorical_accuracy: 0.6693
# Epoch 46/100
# 439/439 [==============================] - ETA: 0s - loss: 0.3937 - categorical_accuracy: 0.6829
# Epoch 00046: val_categorical_accuracy did not improve from 0.66933
# 439/439 [==============================] - 57s 131ms/step - loss: 0.3937 - categorical_accuracy: 0.6829 - val_loss: 0.4575 - val_categorical_accuracy: 0.6693
# Epoch 47/100
# 439/439 [==============================] - ETA: 0s - loss: 0.3933 - categorical_accuracy: 0.6776
# Epoch 00047: val_categorical_accuracy improved from 0.66933 to 0.67000, saving model to /content/drive/My Drive/SMOMI/w-l-4_1new.hdf5
# 439/439 [==============================] - 59s 134ms/step - loss: 0.3933 - categorical_accuracy: 0.6776 - val_loss: 0.4525 - val_categorical_accuracy: 0.6700
# Epoch 48/100
# 439/439 [==============================] - ETA: 0s - loss: 0.3878 - categorical_accuracy: 0.6822
# Epoch 00048: val_categorical_accuracy improved from 0.67000 to 0.67267, saving model to /content/drive/My Drive/SMOMI/w-l-4_1new.hdf5
# 439/439 [==============================] - 59s 134ms/step - loss: 0.3878 - categorical_accuracy: 0.6822 - val_loss: 0.4475 - val_categorical_accuracy: 0.6727
# Epoch 49/100
# 439/439 [==============================] - ETA: 0s - loss: 0.3826 - categorical_accuracy: 0.6828
# Epoch 00049: val_categorical_accuracy improved from 0.67267 to 0.67333, saving model to /content/drive/My Drive/SMOMI/w-l-4_1new.hdf5
# 439/439 [==============================] - 59s 134ms/step - loss: 0.3826 - categorical_accuracy: 0.6828 - val_loss: 0.4428 - val_categorical_accuracy: 0.6733
# Epoch 50/100
# 439/439 [==============================] - ETA: 0s - loss: 0.3792 - categorical_accuracy: 0.6868
# Epoch 00050: val_categorical_accuracy improved from 0.67333 to 0.67467, saving model to /content/drive/My Drive/SMOMI/w-l-4_1new.hdf5
# 439/439 [==============================] - 59s 134ms/step - loss: 0.3792 - categorical_accuracy: 0.6868 - val_loss: 0.4386 - val_categorical_accuracy: 0.6747
# Epoch 51/100
# 439/439 [==============================] - ETA: 0s - loss: 0.3729 - categorical_accuracy: 0.6900
# Epoch 00051: val_categorical_accuracy improved from 0.67467 to 0.67567, saving model to /content/drive/My Drive/SMOMI/w-l-4_1new.hdf5
# 439/439 [==============================] - 59s 134ms/step - loss: 0.3729 - categorical_accuracy: 0.6900 - val_loss: 0.4344 - val_categorical_accuracy: 0.6757
# Epoch 52/100
# 439/439 [==============================] - ETA: 0s - loss: 0.3721 - categorical_accuracy: 0.6889
# Epoch 00052: val_categorical_accuracy improved from 0.67567 to 0.67667, saving model to /content/drive/My Drive/SMOMI/w-l-4_1new.hdf5
# 439/439 [==============================] - 59s 133ms/step - loss: 0.3721 - categorical_accuracy: 0.6889 - val_loss: 0.4301 - val_categorical_accuracy: 0.6767
# Epoch 53/100
# 439/439 [==============================] - ETA: 0s - loss: 0.3682 - categorical_accuracy: 0.6920
# Epoch 00053: val_categorical_accuracy improved from 0.67667 to 0.67967, saving model to /content/drive/My Drive/SMOMI/w-l-4_1new.hdf5
# 439/439 [==============================] - 59s 134ms/step - loss: 0.3682 - categorical_accuracy: 0.6920 - val_loss: 0.4257 - val_categorical_accuracy: 0.6797
# Epoch 54/100
# 439/439 [==============================] - ETA: 0s - loss: 0.3682 - categorical_accuracy: 0.6860
# Epoch 00054: val_categorical_accuracy improved from 0.67967 to 0.68067, saving model to /content/drive/My Drive/SMOMI/w-l-4_1new.hdf5
# 439/439 [==============================] - 59s 134ms/step - loss: 0.3682 - categorical_accuracy: 0.6860 - val_loss: 0.4223 - val_categorical_accuracy: 0.6807
# Epoch 55/100
# 439/439 [==============================] - ETA: 0s - loss: 0.3633 - categorical_accuracy: 0.6903
# Epoch 00055: val_categorical_accuracy improved from 0.68067 to 0.68133, saving model to /content/drive/My Drive/SMOMI/w-l-4_1new.hdf5
# 439/439 [==============================] - 59s 134ms/step - loss: 0.3633 - categorical_accuracy: 0.6903 - val_loss: 0.4187 - val_categorical_accuracy: 0.6813
# Epoch 56/100
# 439/439 [==============================] - ETA: 0s - loss: 0.3604 - categorical_accuracy: 0.6940
# Epoch 00056: val_categorical_accuracy improved from 0.68133 to 0.68267, saving model to /content/drive/My Drive/SMOMI/w-l-4_1new.hdf5
# 439/439 [==============================] - 59s 134ms/step - loss: 0.3604 - categorical_accuracy: 0.6940 - val_loss: 0.4153 - val_categorical_accuracy: 0.6827
# Epoch 57/100
# 439/439 [==============================] - ETA: 0s - loss: 0.3583 - categorical_accuracy: 0.6957
# Epoch 00057: val_categorical_accuracy improved from 0.68267 to 0.68300, saving model to /content/drive/My Drive/SMOMI/w-l-4_1new.hdf5
# 439/439 [==============================] - 59s 135ms/step - loss: 0.3583 - categorical_accuracy: 0.6957 - val_loss: 0.4120 - val_categorical_accuracy: 0.6830
# Epoch 58/100
# 439/439 [==============================] - ETA: 0s - loss: 0.3551 - categorical_accuracy: 0.6962
# Epoch 00058: val_categorical_accuracy improved from 0.68300 to 0.68400, saving model to /content/drive/My Drive/SMOMI/w-l-4_1new.hdf5
# 439/439 [==============================] - 59s 134ms/step - loss: 0.3551 - categorical_accuracy: 0.6962 - val_loss: 0.4087 - val_categorical_accuracy: 0.6840
# Epoch 59/100
# 439/439 [==============================] - ETA: 0s - loss: 0.3545 - categorical_accuracy: 0.6960
# Epoch 00059: val_categorical_accuracy improved from 0.68400 to 0.68533, saving model to /content/drive/My Drive/SMOMI/w-l-4_1new.hdf5
# 439/439 [==============================] - 59s 134ms/step - loss: 0.3545 - categorical_accuracy: 0.6960 - val_loss: 0.4053 - val_categorical_accuracy: 0.6853
# Epoch 60/100
# 439/439 [==============================] - ETA: 0s - loss: 0.3485 - categorical_accuracy: 0.6974
# Epoch 00060: val_categorical_accuracy improved from 0.68533 to 0.68567, saving model to /content/drive/My Drive/SMOMI/w-l-4_1new.hdf5
# 439/439 [==============================] - 59s 134ms/step - loss: 0.3485 - categorical_accuracy: 0.6974 - val_loss: 0.4024 - val_categorical_accuracy: 0.6857
# Epoch 61/100
# 439/439 [==============================] - ETA: 0s - loss: 0.3473 - categorical_accuracy: 0.7012
# Epoch 00061: val_categorical_accuracy improved from 0.68567 to 0.68600, saving model to /content/drive/My Drive/SMOMI/w-l-4_1new.hdf5
# 439/439 [==============================] - 59s 135ms/step - loss: 0.3473 - categorical_accuracy: 0.7012 - val_loss: 0.3993 - val_categorical_accuracy: 0.6860
# Epoch 62/100
# 439/439 [==============================] - ETA: 0s - loss: 0.3460 - categorical_accuracy: 0.6988
# Epoch 00062: val_categorical_accuracy improved from 0.68600 to 0.68633, saving model to /content/drive/My Drive/SMOMI/w-l-4_1new.hdf5
# 439/439 [==============================] - 59s 135ms/step - loss: 0.3460 - categorical_accuracy: 0.6988 - val_loss: 0.3967 - val_categorical_accuracy: 0.6863
# Epoch 63/100
# 439/439 [==============================] - ETA: 0s - loss: 0.3421 - categorical_accuracy: 0.6982
# Epoch 00063: val_categorical_accuracy improved from 0.68633 to 0.68833, saving model to /content/drive/My Drive/SMOMI/w-l-4_1new.hdf5
# 439/439 [==============================] - 59s 135ms/step - loss: 0.3421 - categorical_accuracy: 0.6982 - val_loss: 0.3940 - val_categorical_accuracy: 0.6883
# Epoch 64/100
# 439/439 [==============================] - ETA: 0s - loss: 0.3418 - categorical_accuracy: 0.7014
# Epoch 00064: val_categorical_accuracy improved from 0.68833 to 0.68867, saving model to /content/drive/My Drive/SMOMI/w-l-4_1new.hdf5
# 439/439 [==============================] - 59s 134ms/step - loss: 0.3418 - categorical_accuracy: 0.7014 - val_loss: 0.3914 - val_categorical_accuracy: 0.6887
# Epoch 65/100
# 439/439 [==============================] - ETA: 0s - loss: 0.3348 - categorical_accuracy: 0.7042
# Epoch 00065: val_categorical_accuracy improved from 0.68867 to 0.69000, saving model to /content/drive/My Drive/SMOMI/w-l-4_1new.hdf5
# 439/439 [==============================] - 59s 134ms/step - loss: 0.3348 - categorical_accuracy: 0.7042 - val_loss: 0.3889 - val_categorical_accuracy: 0.6900
# Epoch 66/100
# 439/439 [==============================] - ETA: 0s - loss: 0.3342 - categorical_accuracy: 0.7039
# Epoch 00066: val_categorical_accuracy improved from 0.69000 to 0.69067, saving model to /content/drive/My Drive/SMOMI/w-l-4_1new.hdf5
# 439/439 [==============================] - 59s 135ms/step - loss: 0.3342 - categorical_accuracy: 0.7039 - val_loss: 0.3863 - val_categorical_accuracy: 0.6907
# Epoch 67/100
# 439/439 [==============================] - ETA: 0s - loss: 0.3357 - categorical_accuracy: 0.7017
# Epoch 00067: val_categorical_accuracy improved from 0.69067 to 0.69167, saving model to /content/drive/My Drive/SMOMI/w-l-4_1new.hdf5
# 439/439 [==============================] - 59s 134ms/step - loss: 0.3357 - categorical_accuracy: 0.7017 - val_loss: 0.3843 - val_categorical_accuracy: 0.6917
# Epoch 68/100
# 439/439 [==============================] - ETA: 0s - loss: 0.3320 - categorical_accuracy: 0.7047
# Epoch 00068: val_categorical_accuracy did not improve from 0.69167
# 439/439 [==============================] - 57s 131ms/step - loss: 0.3320 - categorical_accuracy: 0.7047 - val_loss: 0.3821 - val_categorical_accuracy: 0.6917
# Epoch 69/100
# 439/439 [==============================] - ETA: 0s - loss: 0.3298 - categorical_accuracy: 0.7046
# Epoch 00069: val_categorical_accuracy improved from 0.69167 to 0.69267, saving model to /content/drive/My Drive/SMOMI/w-l-4_1new.hdf5
# 439/439 [==============================] - 59s 135ms/step - loss: 0.3298 - categorical_accuracy: 0.7046 - val_loss: 0.3799 - val_categorical_accuracy: 0.6927
# Epoch 70/100
# 439/439 [==============================] - ETA: 0s - loss: 0.3287 - categorical_accuracy: 0.7064
# Epoch 00070: val_categorical_accuracy improved from 0.69267 to 0.69367, saving model to /content/drive/My Drive/SMOMI/w-l-4_1new.hdf5
# 439/439 [==============================] - 59s 135ms/step - loss: 0.3287 - categorical_accuracy: 0.7064 - val_loss: 0.3777 - val_categorical_accuracy: 0.6937
# Epoch 71/100
# 439/439 [==============================] - ETA: 0s - loss: 0.3298 - categorical_accuracy: 0.7056
# Epoch 00071: val_categorical_accuracy improved from 0.69367 to 0.69467, saving model to /content/drive/My Drive/SMOMI/w-l-4_1new.hdf5
# 439/439 [==============================] - 59s 134ms/step - loss: 0.3298 - categorical_accuracy: 0.7056 - val_loss: 0.3756 - val_categorical_accuracy: 0.6947
# Epoch 72/100
# 439/439 [==============================] - ETA: 0s - loss: 0.3249 - categorical_accuracy: 0.7074
# Epoch 00072: val_categorical_accuracy improved from 0.69467 to 0.69533, saving model to /content/drive/My Drive/SMOMI/w-l-4_1new.hdf5
# 439/439 [==============================] - 59s 135ms/step - loss: 0.3249 - categorical_accuracy: 0.7074 - val_loss: 0.3737 - val_categorical_accuracy: 0.6953
# Epoch 73/100
# 439/439 [==============================] - ETA: 0s - loss: 0.3262 - categorical_accuracy: 0.7064
# Epoch 00073: val_categorical_accuracy improved from 0.69533 to 0.69567, saving model to /content/drive/My Drive/SMOMI/w-l-4_1new.hdf5
# 439/439 [==============================] - 59s 135ms/step - loss: 0.3262 - categorical_accuracy: 0.7064 - val_loss: 0.3718 - val_categorical_accuracy: 0.6957
# Epoch 74/100
# 439/439 [==============================] - ETA: 0s - loss: 0.3245 - categorical_accuracy: 0.7057
# Epoch 00074: val_categorical_accuracy did not improve from 0.69567
# 439/439 [==============================] - 58s 131ms/step - loss: 0.3245 - categorical_accuracy: 0.7057 - val_loss: 0.3700 - val_categorical_accuracy: 0.6953
# Epoch 75/100
# 439/439 [==============================] - ETA: 0s - loss: 0.3207 - categorical_accuracy: 0.7073
# Epoch 00075: val_categorical_accuracy improved from 0.69567 to 0.69667, saving model to /content/drive/My Drive/SMOMI/w-l-4_1new.hdf5
# 439/439 [==============================] - 59s 135ms/step - loss: 0.3207 - categorical_accuracy: 0.7073 - val_loss: 0.3683 - val_categorical_accuracy: 0.6967
# Epoch 76/100
# 439/439 [==============================] - ETA: 0s - loss: 0.3200 - categorical_accuracy: 0.7109
# Epoch 00076: val_categorical_accuracy improved from 0.69667 to 0.69867, saving model to /content/drive/My Drive/SMOMI/w-l-4_1new.hdf5
# 439/439 [==============================] - 59s 134ms/step - loss: 0.3200 - categorical_accuracy: 0.7109 - val_loss: 0.3666 - val_categorical_accuracy: 0.6987
# Epoch 77/100
# 439/439 [==============================] - ETA: 0s - loss: 0.3184 - categorical_accuracy: 0.7098
# Epoch 00077: val_categorical_accuracy improved from 0.69867 to 0.69967, saving model to /content/drive/My Drive/SMOMI/w-l-4_1new.hdf5
# 439/439 [==============================] - 59s 135ms/step - loss: 0.3184 - categorical_accuracy: 0.7098 - val_loss: 0.3646 - val_categorical_accuracy: 0.6997
# Epoch 78/100
# 439/439 [==============================] - ETA: 0s - loss: 0.3176 - categorical_accuracy: 0.7114
# Epoch 00078: val_categorical_accuracy improved from 0.69967 to 0.70033, saving model to /content/drive/My Drive/SMOMI/w-l-4_1new.hdf5
# 439/439 [==============================] - 59s 135ms/step - loss: 0.3176 - categorical_accuracy: 0.7114 - val_loss: 0.3627 - val_categorical_accuracy: 0.7003
# Epoch 79/100
# 439/439 [==============================] - ETA: 0s - loss: 0.3164 - categorical_accuracy: 0.7112
# Epoch 00079: val_categorical_accuracy did not improve from 0.70033
# 439/439 [==============================] - 57s 131ms/step - loss: 0.3164 - categorical_accuracy: 0.7112 - val_loss: 0.3615 - val_categorical_accuracy: 0.7000
# Epoch 80/100
# 439/439 [==============================] - ETA: 0s - loss: 0.3119 - categorical_accuracy: 0.7147
# Epoch 00080: val_categorical_accuracy improved from 0.70033 to 0.70067, saving model to /content/drive/My Drive/SMOMI/w-l-4_1new.hdf5
# 439/439 [==============================] - 59s 134ms/step - loss: 0.3119 - categorical_accuracy: 0.7147 - val_loss: 0.3602 - val_categorical_accuracy: 0.7007
# Epoch 81/100
# 439/439 [==============================] - ETA: 0s - loss: 0.3145 - categorical_accuracy: 0.7108
# Epoch 00081: val_categorical_accuracy did not improve from 0.70067
# 439/439 [==============================] - 58s 131ms/step - loss: 0.3145 - categorical_accuracy: 0.7108 - val_loss: 0.3587 - val_categorical_accuracy: 0.7007
# Epoch 82/100
# 439/439 [==============================] - ETA: 0s - loss: 0.3110 - categorical_accuracy: 0.7126
# Epoch 00082: val_categorical_accuracy improved from 0.70067 to 0.70167, saving model to /content/drive/My Drive/SMOMI/w-l-4_1new.hdf5
# 439/439 [==============================] - 59s 134ms/step - loss: 0.3110 - categorical_accuracy: 0.7126 - val_loss: 0.3574 - val_categorical_accuracy: 0.7017
# Epoch 83/100
# 439/439 [==============================] - ETA: 0s - loss: 0.3112 - categorical_accuracy: 0.7138
# Epoch 00083: val_categorical_accuracy did not improve from 0.70167
# 439/439 [==============================] - 58s 131ms/step - loss: 0.3112 - categorical_accuracy: 0.7138 - val_loss: 0.3562 - val_categorical_accuracy: 0.7013
# Epoch 84/100
# 439/439 [==============================] - ETA: 0s - loss: 0.3112 - categorical_accuracy: 0.7133
# Epoch 00084: val_categorical_accuracy did not improve from 0.70167
# 439/439 [==============================] - 58s 131ms/step - loss: 0.3112 - categorical_accuracy: 0.7133 - val_loss: 0.3550 - val_categorical_accuracy: 0.7010
# Epoch 85/100
# 439/439 [==============================] - ETA: 0s - loss: 0.3090 - categorical_accuracy: 0.7147
# Epoch 00085: val_categorical_accuracy did not improve from 0.70167
# 439/439 [==============================] - 58s 131ms/step - loss: 0.3090 - categorical_accuracy: 0.7147 - val_loss: 0.3536 - val_categorical_accuracy: 0.7013
# Epoch 86/100
# 439/439 [==============================] - ETA: 0s - loss: 0.3063 - categorical_accuracy: 0.7143
# Epoch 00086: val_categorical_accuracy improved from 0.70167 to 0.70200, saving model to /content/drive/My Drive/SMOMI/w-l-4_1new.hdf5
# 439/439 [==============================] - 59s 135ms/step - loss: 0.3063 - categorical_accuracy: 0.7143 - val_loss: 0.3522 - val_categorical_accuracy: 0.7020
# Epoch 87/100
# 439/439 [==============================] - ETA: 0s - loss: 0.3036 - categorical_accuracy: 0.7170
# Epoch 00087: val_categorical_accuracy improved from 0.70200 to 0.70233, saving model to /content/drive/My Drive/SMOMI/w-l-4_1new.hdf5
# 439/439 [==============================] - 59s 135ms/step - loss: 0.3036 - categorical_accuracy: 0.7170 - val_loss: 0.3512 - val_categorical_accuracy: 0.7023
# Epoch 88/100
# 439/439 [==============================] - ETA: 0s - loss: 0.3045 - categorical_accuracy: 0.7172
# Epoch 00088: val_categorical_accuracy improved from 0.70233 to 0.70267, saving model to /content/drive/My Drive/SMOMI/w-l-4_1new.hdf5
# 439/439 [==============================] - 59s 135ms/step - loss: 0.3045 - categorical_accuracy: 0.7172 - val_loss: 0.3496 - val_categorical_accuracy: 0.7027
# Epoch 89/100
# 439/439 [==============================] - ETA: 0s - loss: 0.3048 - categorical_accuracy: 0.7175
# Epoch 00089: val_categorical_accuracy improved from 0.70267 to 0.70367, saving model to /content/drive/My Drive/SMOMI/w-l-4_1new.hdf5
# 439/439 [==============================] - 59s 135ms/step - loss: 0.3048 - categorical_accuracy: 0.7175 - val_loss: 0.3483 - val_categorical_accuracy: 0.7037
# Epoch 90/100
# 439/439 [==============================] - ETA: 0s - loss: 0.3000 - categorical_accuracy: 0.7193
# Epoch 00090: val_categorical_accuracy did not improve from 0.70367
# 439/439 [==============================] - 58s 131ms/step - loss: 0.3000 - categorical_accuracy: 0.7193 - val_loss: 0.3471 - val_categorical_accuracy: 0.7037
# Epoch 91/100
# 439/439 [==============================] - ETA: 0s - loss: 0.3001 - categorical_accuracy: 0.7183
# Epoch 00091: val_categorical_accuracy improved from 0.70367 to 0.70400, saving model to /content/drive/My Drive/SMOMI/w-l-4_1new.hdf5
# 439/439 [==============================] - 59s 135ms/step - loss: 0.3001 - categorical_accuracy: 0.7183 - val_loss: 0.3458 - val_categorical_accuracy: 0.7040
# Epoch 92/100
# 439/439 [==============================] - ETA: 0s - loss: 0.3024 - categorical_accuracy: 0.7179
# Epoch 00092: val_categorical_accuracy improved from 0.70400 to 0.70533, saving model to /content/drive/My Drive/SMOMI/w-l-4_1new.hdf5
# 439/439 [==============================] - 59s 135ms/step - loss: 0.3024 - categorical_accuracy: 0.7179 - val_loss: 0.3448 - val_categorical_accuracy: 0.7053
# Epoch 93/100
# 439/439 [==============================] - ETA: 0s - loss: 0.3026 - categorical_accuracy: 0.7152
# Epoch 00093: val_categorical_accuracy improved from 0.70533 to 0.70633, saving model to /content/drive/My Drive/SMOMI/w-l-4_1new.hdf5
# 439/439 [==============================] - 59s 135ms/step - loss: 0.3026 - categorical_accuracy: 0.7152 - val_loss: 0.3436 - val_categorical_accuracy: 0.7063
# Epoch 94/100
# 439/439 [==============================] - ETA: 0s - loss: 0.3011 - categorical_accuracy: 0.7155
# Epoch 00094: val_categorical_accuracy improved from 0.70633 to 0.70667, saving model to /content/drive/My Drive/SMOMI/w-l-4_1new.hdf5
# 439/439 [==============================] - 59s 135ms/step - loss: 0.3011 - categorical_accuracy: 0.7155 - val_loss: 0.3426 - val_categorical_accuracy: 0.7067
# Epoch 95/100
# 439/439 [==============================] - ETA: 0s - loss: 0.2979 - categorical_accuracy: 0.7163
# Epoch 00095: val_categorical_accuracy did not improve from 0.70667
# 439/439 [==============================] - 58s 132ms/step - loss: 0.2979 - categorical_accuracy: 0.7163 - val_loss: 0.3420 - val_categorical_accuracy: 0.7067
# Epoch 96/100
# 439/439 [==============================] - ETA: 0s - loss: 0.2961 - categorical_accuracy: 0.7191
# Epoch 00096: val_categorical_accuracy improved from 0.70667 to 0.70767, saving model to /content/drive/My Drive/SMOMI/w-l-4_1new.hdf5
# 439/439 [==============================] - 60s 136ms/step - loss: 0.2961 - categorical_accuracy: 0.7191 - val_loss: 0.3412 - val_categorical_accuracy: 0.7077
# Epoch 97/100
# 439/439 [==============================] - ETA: 0s - loss: 0.2954 - categorical_accuracy: 0.7211
# Epoch 00097: val_categorical_accuracy improved from 0.70767 to 0.70867, saving model to /content/drive/My Drive/SMOMI/w-l-4_1new.hdf5
# 439/439 [==============================] - 60s 136ms/step - loss: 0.2954 - categorical_accuracy: 0.7211 - val_loss: 0.3402 - val_categorical_accuracy: 0.7087
# Epoch 98/100
# 439/439 [==============================] - ETA: 0s - loss: 0.2941 - categorical_accuracy: 0.7187
# Epoch 00098: val_categorical_accuracy did not improve from 0.70867
# 439/439 [==============================] - 58s 132ms/step - loss: 0.2941 - categorical_accuracy: 0.7187 - val_loss: 0.3392 - val_categorical_accuracy: 0.7087
# Epoch 99/100
# 439/439 [==============================] - ETA: 0s - loss: 0.2916 - categorical_accuracy: 0.7222
# Epoch 00099: val_categorical_accuracy did not improve from 0.70867
# 439/439 [==============================] - 58s 132ms/step - loss: 0.2916 - categorical_accuracy: 0.7222 - val_loss: 0.3384 - val_categorical_accuracy: 0.7087
# Epoch 100/100
# 439/439 [==============================] - ETA: 0s - loss: 0.2942 - categorical_accuracy: 0.7221
# Epoch 00100: val_categorical_accuracy improved from 0.70867 to 0.70900, saving model to /content/drive/My Drive/SMOMI/w-l-4_1new.hdf5
# 439/439 [==============================] - 60s 136ms/step - loss: 0.2942 - categorical_accuracy: 0.7221 - val_loss: 0.3372 - val_categorical_accuracy: 0.7090

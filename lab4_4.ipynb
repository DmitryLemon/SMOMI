# %%
__author__ = 'Alexander Soroka, soroka.a.m@gmail.com'
__copyright__ = """Copyright 2020 Alexander Soroka"""


import argparse
import glob
import numpy as np
import tensorflow as tf
import time
from tensorflow.python import keras as keras
from tensorflow.python.keras.callbacks import LearningRateScheduler



LOG_DIR = 'logs'
SHUFFLE_BUFFER = 4
BATCH_SIZE = 32
NUM_CLASSES = 6
PARALLEL_CALLS=4
RESIZE_TO = 224
TRAINSET_SIZE = 14034
VALSET_SIZE = 3000


def parse_proto_example(proto):
    keys_to_features = {
        'image/encoded': tf.io.FixedLenFeature((), tf.string, default_value=''),
        'image/class/label': tf.io.FixedLenFeature([], tf.int64, default_value=tf.zeros([], dtype=tf.int64))
    }
    example = tf.io.parse_single_example(proto, keys_to_features)
    example['image'] = tf.image.decode_jpeg(example['image/encoded'], channels=3)
    example['image'] = tf.image.convert_image_dtype(example['image'], dtype=tf.float32)
    example['image'] = tf.image.resize(example['image'], tf.constant([RESIZE_TO, RESIZE_TO]))
    return example['image'], tf.one_hot(example['image/class/label'], depth=NUM_CLASSES)


def normalize(image, label):
    return tf.image.per_image_standardization(image), label

def resize(image, label):
    return tf.image.resize(image, tf.constant([RESIZE_TO, RESIZE_TO])), label

def augmentation(image, label):
    image = tf.image.convert_image_dtype(image, tf.float32)
    noise_img = image + tf.random.normal(shape=tf.shape(image), mean=0.0, stddev=1.0, dtype=tf.float32)
    noise_img = tf.clip_by_value(noise_img, -1.0, 1.0)
    return noise_img, label

def create_dataset(filenames, batch_size):
    """Create dataset from tfrecords file
    :tfrecords_files: Mask to collect tfrecords file of dataset
    :returns: tf.data.Dataset
    """
    return tf.data.TFRecordDataset(filenames)\
        .map(parse_proto_example)\
        .map(resize)\
        .map(normalize)\
        .batch(batch_size)\
        .prefetch(batch_size)

def create_aug_dataset(filenames, batch_size):
    """Create dataset from tfrecords file
    :tfrecords_files: Mask to collect tfrecords file of dataset
    :returns: tf.data.Dataset
    """
    return tf.data.TFRecordDataset(filenames)\
        .map(parse_proto_example)\
        .map(resize)\
        .map(normalize)\
        .map(augmentation)\
        .shuffle(buffer_size=5 * batch_size)\
        .batch(batch_size)\
        .prefetch(2 * batch_size)


def build_model():
    new_model = tf.keras.applications.MobileNetV2(input_shape=(224,224,3),
						classes = NUM_CLASSES,
            include_top=False,
            weights='imagenet')
    
    new_model.trainable = False
    
    return tf.keras.models.Sequential([
    	new_model,
      tf.keras.layers.GlobalAveragePooling2D(),
      tf.keras.layers.Dropout(0.3),
    	tf.keras.layers.Flatten(),
      tf.keras.layers.Dense(NUM_CLASSES, activation=tf.keras.activations.softmax)
    ])


def main():
    #args = argparse.ArgumentParser()
    #args.add_argument('--train', type=str, help='Glob pattern to collect train tfrecord files')
    #args.add_argument('--test', type=str, help='Glob pattern to collect test tfrecord files')
    #args = args.parse_args()
    train_path = '/content/drive/My Drive/SMOMI/dataset/train*'
    test_path = '/content/drive/My Drive/SMOMI/dataset/val*'

    train_dataset = create_aug_dataset(glob.glob(train_path), BATCH_SIZE)
    validation_dataset = create_dataset(glob.glob(test_path), BATCH_SIZE)

    model = build_model()

    model.compile(
        optimizer=tf.optimizers.Adam(lr=4e-5),
        loss=tf.keras.losses.categorical_crossentropy,
        metrics=[tf.keras.metrics.categorical_accuracy],
    )

    log_dir='/content/drive/My Drive/SMOMI/{}/lab4_4-new/ilcd-{}'.format(LOG_DIR, time.time())
    weights_file = "/content/drive/My Drive/SMOMI/w-l-4_4new.hdf5"
    
    model.fit(
        train_dataset,
        epochs=100,
        validation_data=validation_dataset,
        callbacks=[
            tf.keras.callbacks.TensorBoard(log_dir),
            tf.keras.callbacks.ModelCheckpoint(filepath=weights_file, monitor='val_categorical_accuracy', mode='max', save_best_only=True, save_weights_only=True, verbose=1)
        ]
    )


if __name__ == '__main__':
    main()
# Out:
# Epoch 1/100
#       2/Unknown - 1s 439ms/step - loss: 2.6313 - categorical_accuracy: 0.0625WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1467s vs `on_train_batch_end` time: 0.7362s). Check your callbacks.
#     439/Unknown - 70s 160ms/step - loss: 1.7736 - categorical_accuracy: 0.1832
# Epoch 00001: val_categorical_accuracy improved from -inf to 0.18833, saving model to /content/drive/My Drive/SMOMI/w-l-4_4new.hdf5
# 439/439 [==============================] - 78s 178ms/step - loss: 1.7736 - categorical_accuracy: 0.1832 - val_loss: 1.5774 - val_categorical_accuracy: 0.1883
# Epoch 2/100
# 438/439 [============================>.] - ETA: 0s - loss: 1.4103 - categorical_accuracy: 0.2808
# Epoch 00002: val_categorical_accuracy improved from 0.18833 to 0.35533, saving model to /content/drive/My Drive/SMOMI/w-l-4_4new.hdf5
# 439/439 [==============================] - 76s 174ms/step - loss: 1.4096 - categorical_accuracy: 0.2813 - val_loss: 1.1786 - val_categorical_accuracy: 0.3553
# Epoch 3/100
# 439/439 [==============================] - ETA: 0s - loss: 1.1941 - categorical_accuracy: 0.3593
# Epoch 00003: val_categorical_accuracy improved from 0.35533 to 0.41333, saving model to /content/drive/My Drive/SMOMI/w-l-4_4new.hdf5
# 439/439 [==============================] - 76s 173ms/step - loss: 1.1941 - categorical_accuracy: 0.3593 - val_loss: 1.0572 - val_categorical_accuracy: 0.4133
# Epoch 4/100
# 439/439 [==============================] - ETA: 0s - loss: 1.0605 - categorical_accuracy: 0.4048
# Epoch 00004: val_categorical_accuracy improved from 0.41333 to 0.42400, saving model to /content/drive/My Drive/SMOMI/w-l-4_4new.hdf5
# 439/439 [==============================] - 77s 176ms/step - loss: 1.0605 - categorical_accuracy: 0.4048 - val_loss: 1.0193 - val_categorical_accuracy: 0.4240
# Epoch 5/100
# 438/439 [============================>.] - ETA: 0s - loss: 0.9868 - categorical_accuracy: 0.4328
# Epoch 00005: val_categorical_accuracy did not improve from 0.42400
# 439/439 [==============================] - 75s 172ms/step - loss: 0.9859 - categorical_accuracy: 0.4334 - val_loss: 1.0138 - val_categorical_accuracy: 0.4237
# Epoch 6/100
# 439/439 [==============================] - ETA: 0s - loss: 0.9227 - categorical_accuracy: 0.4617
# Epoch 00006: val_categorical_accuracy improved from 0.42400 to 0.42600, saving model to /content/drive/My Drive/SMOMI/w-l-4_4new.hdf5
# 439/439 [==============================] - 77s 175ms/step - loss: 0.9227 - categorical_accuracy: 0.4617 - val_loss: 1.0225 - val_categorical_accuracy: 0.4260
# Epoch 7/100
# 439/439 [==============================] - ETA: 0s - loss: 0.8695 - categorical_accuracy: 0.4864
# Epoch 00007: val_categorical_accuracy did not improve from 0.42600
# 439/439 [==============================] - 75s 171ms/step - loss: 0.8695 - categorical_accuracy: 0.4864 - val_loss: 1.0352 - val_categorical_accuracy: 0.4217
# Epoch 8/100
# 438/439 [============================>.] - ETA: 0s - loss: 0.8288 - categorical_accuracy: 0.5018
# Epoch 00008: val_categorical_accuracy did not improve from 0.42600
# 439/439 [==============================] - 75s 171ms/step - loss: 0.8282 - categorical_accuracy: 0.5024 - val_loss: 1.0464 - val_categorical_accuracy: 0.4167
# Epoch 9/100
# 439/439 [==============================] - ETA: 0s - loss: 0.8074 - categorical_accuracy: 0.5113
# Epoch 00009: val_categorical_accuracy did not improve from 0.42600
# 439/439 [==============================] - 74s 169ms/step - loss: 0.8074 - categorical_accuracy: 0.5113 - val_loss: 1.0752 - val_categorical_accuracy: 0.4120
# Epoch 10/100
# 439/439 [==============================] - ETA: 0s - loss: 0.7829 - categorical_accuracy: 0.5229
# Epoch 00010: val_categorical_accuracy did not improve from 0.42600
# 439/439 [==============================] - 74s 168ms/step - loss: 0.7829 - categorical_accuracy: 0.5229 - val_loss: 1.1006 - val_categorical_accuracy: 0.4043
# Epoch 11/100
# 438/439 [============================>.] - ETA: 0s - loss: 0.7568 - categorical_accuracy: 0.5362
# Epoch 00011: val_categorical_accuracy did not improve from 0.42600
# 439/439 [==============================] - 74s 170ms/step - loss: 0.7562 - categorical_accuracy: 0.5366 - val_loss: 1.1248 - val_categorical_accuracy: 0.3973
# Epoch 12/100
# 439/439 [==============================] - ETA: 0s - loss: 0.7409 - categorical_accuracy: 0.5440
# Epoch 00012: val_categorical_accuracy did not improve from 0.42600
# 439/439 [==============================] - 74s 170ms/step - loss: 0.7409 - categorical_accuracy: 0.5440 - val_loss: 1.1464 - val_categorical_accuracy: 0.3950
# Epoch 13/100
# 439/439 [==============================] - ETA: 0s - loss: 0.7227 - categorical_accuracy: 0.5475
# Epoch 00013: val_categorical_accuracy did not improve from 0.42600
# 439/439 [==============================] - 76s 173ms/step - loss: 0.7227 - categorical_accuracy: 0.5475 - val_loss: 1.1628 - val_categorical_accuracy: 0.3920
# Epoch 14/100
# 439/439 [==============================] - ETA: 0s - loss: 0.7201 - categorical_accuracy: 0.5487
# Epoch 00014: val_categorical_accuracy did not improve from 0.42600
# 439/439 [==============================] - 76s 172ms/step - loss: 0.7201 - categorical_accuracy: 0.5487 - val_loss: 1.1848 - val_categorical_accuracy: 0.3877
# Epoch 15/100
# 438/439 [============================>.] - ETA: 0s - loss: 0.7066 - categorical_accuracy: 0.5562
# Epoch 00015: val_categorical_accuracy did not improve from 0.42600
# 439/439 [==============================] - 75s 172ms/step - loss: 0.7058 - categorical_accuracy: 0.5566 - val_loss: 1.1867 - val_categorical_accuracy: 0.3877
# Epoch 16/100
# 438/439 [============================>.] - ETA: 0s - loss: 0.7013 - categorical_accuracy: 0.5600
# Epoch 00016: val_categorical_accuracy did not improve from 0.42600
# 439/439 [==============================] - 77s 175ms/step - loss: 0.7009 - categorical_accuracy: 0.5604 - val_loss: 1.2328 - val_categorical_accuracy: 0.3793
# Epoch 17/100
# 439/439 [==============================] - ETA: 0s - loss: 0.6833 - categorical_accuracy: 0.5685
# Epoch 00017: val_categorical_accuracy did not improve from 0.42600
# 439/439 [==============================] - 77s 176ms/step - loss: 0.6833 - categorical_accuracy: 0.5685 - val_loss: 1.2279 - val_categorical_accuracy: 0.3813
# Epoch 18/100
# 438/439 [============================>.] - ETA: 0s - loss: 0.6778 - categorical_accuracy: 0.5698
# Epoch 00018: val_categorical_accuracy did not improve from 0.42600
# 439/439 [==============================] - 76s 173ms/step - loss: 0.6773 - categorical_accuracy: 0.5702 - val_loss: 1.2558 - val_categorical_accuracy: 0.3763
# Epoch 19/100
# 438/439 [============================>.] - ETA: 0s - loss: 0.6591 - categorical_accuracy: 0.5744
# Epoch 00019: val_categorical_accuracy did not improve from 0.42600
# 439/439 [==============================] - 76s 174ms/step - loss: 0.6586 - categorical_accuracy: 0.5749 - val_loss: 1.2645 - val_categorical_accuracy: 0.3730
# Epoch 20/100
# 439/439 [==============================] - ETA: 0s - loss: 0.6572 - categorical_accuracy: 0.5790
# Epoch 00020: val_categorical_accuracy did not improve from 0.42600
# 439/439 [==============================] - 77s 175ms/step - loss: 0.6572 - categorical_accuracy: 0.5790 - val_loss: 1.2736 - val_categorical_accuracy: 0.3720
# Epoch 21/100
# 438/439 [============================>.] - ETA: 0s - loss: 0.6546 - categorical_accuracy: 0.5771
# Epoch 00021: val_categorical_accuracy did not improve from 0.42600
# 439/439 [==============================] - 77s 175ms/step - loss: 0.6541 - categorical_accuracy: 0.5775 - val_loss: 1.2846 - val_categorical_accuracy: 0.3693
# Epoch 22/100
# 439/439 [==============================] - ETA: 0s - loss: 0.6481 - categorical_accuracy: 0.5824
# Epoch 00022: val_categorical_accuracy did not improve from 0.42600
# 439/439 [==============================] - 78s 178ms/step - loss: 0.6481 - categorical_accuracy: 0.5824 - val_loss: 1.3163 - val_categorical_accuracy: 0.3687
# Epoch 23/100
# 438/439 [============================>.] - ETA: 0s - loss: 0.6378 - categorical_accuracy: 0.5847
# Epoch 00023: val_categorical_accuracy did not improve from 0.42600
# 439/439 [==============================] - 77s 175ms/step - loss: 0.6372 - categorical_accuracy: 0.5852 - val_loss: 1.3086 - val_categorical_accuracy: 0.3690
# Epoch 24/100
# 438/439 [============================>.] - ETA: 0s - loss: 0.6308 - categorical_accuracy: 0.5880
# Epoch 00024: val_categorical_accuracy did not improve from 0.42600
# 439/439 [==============================] - 77s 175ms/step - loss: 0.6303 - categorical_accuracy: 0.5884 - val_loss: 1.3254 - val_categorical_accuracy: 0.3690
# Epoch 25/100
# 438/439 [============================>.] - ETA: 0s - loss: 0.6352 - categorical_accuracy: 0.5888
# Epoch 00025: val_categorical_accuracy did not improve from 0.42600
# 439/439 [==============================] - 78s 177ms/step - loss: 0.6348 - categorical_accuracy: 0.5892 - val_loss: 1.3571 - val_categorical_accuracy: 0.3673
# Epoch 26/100
# 439/439 [==============================] - ETA: 0s - loss: 0.6290 - categorical_accuracy: 0.5887
# Epoch 00026: val_categorical_accuracy did not improve from 0.42600
# 439/439 [==============================] - 78s 178ms/step - loss: 0.6290 - categorical_accuracy: 0.5887 - val_loss: 1.3486 - val_categorical_accuracy: 0.3710
# Epoch 27/100
# 439/439 [==============================] - ETA: 0s - loss: 0.6211 - categorical_accuracy: 0.5954
# Epoch 00027: val_categorical_accuracy did not improve from 0.42600
# 439/439 [==============================] - 78s 177ms/step - loss: 0.6211 - categorical_accuracy: 0.5954 - val_loss: 1.3694 - val_categorical_accuracy: 0.3663
# Epoch 28/100
# 439/439 [==============================] - ETA: 0s - loss: 0.6121 - categorical_accuracy: 0.5977
# Epoch 00028: val_categorical_accuracy did not improve from 0.42600
# 439/439 [==============================] - 77s 176ms/step - loss: 0.6121 - categorical_accuracy: 0.5977 - val_loss: 1.3785 - val_categorical_accuracy: 0.3683
# Epoch 29/100
# 439/439 [==============================] - ETA: 0s - loss: 0.6077 - categorical_accuracy: 0.5963
# Epoch 00029: val_categorical_accuracy did not improve from 0.42600
# 439/439 [==============================] - 78s 178ms/step - loss: 0.6077 - categorical_accuracy: 0.5963 - val_loss: 1.3696 - val_categorical_accuracy: 0.3703
# Epoch 30/100
# 438/439 [============================>.] - ETA: 0s - loss: 0.6176 - categorical_accuracy: 0.5914
# Epoch 00030: val_categorical_accuracy did not improve from 0.42600
# 439/439 [==============================] - 78s 178ms/step - loss: 0.6171 - categorical_accuracy: 0.5918 - val_loss: 1.3659 - val_categorical_accuracy: 0.3747
# Epoch 31/100
# 439/439 [==============================] - ETA: 0s - loss: 0.5944 - categorical_accuracy: 0.6027
# Epoch 00031: val_categorical_accuracy did not improve from 0.42600
# 439/439 [==============================] - 77s 176ms/step - loss: 0.5944 - categorical_accuracy: 0.6027 - val_loss: 1.3645 - val_categorical_accuracy: 0.3747
# Epoch 32/100
# 438/439 [============================>.] - ETA: 0s - loss: 0.6041 - categorical_accuracy: 0.6007
# Epoch 00032: val_categorical_accuracy did not improve from 0.42600
# 439/439 [==============================] - 76s 174ms/step - loss: 0.6035 - categorical_accuracy: 0.6012 - val_loss: 1.3593 - val_categorical_accuracy: 0.3743
# Epoch 33/100
# 438/439 [============================>.] - ETA: 0s - loss: 0.5961 - categorical_accuracy: 0.6041
# Epoch 00033: val_categorical_accuracy did not improve from 0.42600
# 439/439 [==============================] - 76s 174ms/step - loss: 0.5959 - categorical_accuracy: 0.6045 - val_loss: 1.3824 - val_categorical_accuracy: 0.3700
# Epoch 34/100
# 439/439 [==============================] - ETA: 0s - loss: 0.5899 - categorical_accuracy: 0.6042
# Epoch 00034: val_categorical_accuracy did not improve from 0.42600
# 439/439 [==============================] - 76s 173ms/step - loss: 0.5899 - categorical_accuracy: 0.6042 - val_loss: 1.3867 - val_categorical_accuracy: 0.3697
# Epoch 35/100
# 438/439 [============================>.] - ETA: 0s - loss: 0.5894 - categorical_accuracy: 0.6034
# Epoch 00035: val_categorical_accuracy did not improve from 0.42600
# 439/439 [==============================] - 75s 171ms/step - loss: 0.5889 - categorical_accuracy: 0.6037 - val_loss: 1.3843 - val_categorical_accuracy: 0.3717
# Epoch 36/100
# 438/439 [============================>.] - ETA: 0s - loss: 0.5907 - categorical_accuracy: 0.6030
# Epoch 00036: val_categorical_accuracy did not improve from 0.42600
# 439/439 [==============================] - 75s 171ms/step - loss: 0.5900 - categorical_accuracy: 0.6035 - val_loss: 1.3714 - val_categorical_accuracy: 0.3750
# Epoch 37/100
# 438/439 [============================>.] - ETA: 0s - loss: 0.5856 - categorical_accuracy: 0.6106
# Epoch 00037: val_categorical_accuracy did not improve from 0.42600
# 439/439 [==============================] - 75s 172ms/step - loss: 0.5856 - categorical_accuracy: 0.6108 - val_loss: 1.3840 - val_categorical_accuracy: 0.3740
# Epoch 38/100
# 438/439 [============================>.] - ETA: 0s - loss: 0.5831 - categorical_accuracy: 0.6108
# Epoch 00038: val_categorical_accuracy did not improve from 0.42600
# 439/439 [==============================] - 75s 171ms/step - loss: 0.5825 - categorical_accuracy: 0.6112 - val_loss: 1.3830 - val_categorical_accuracy: 0.3757
# Epoch 39/100
# 438/439 [============================>.] - ETA: 0s - loss: 0.5799 - categorical_accuracy: 0.6094
# Epoch 00039: val_categorical_accuracy did not improve from 0.42600
# 439/439 [==============================] - 75s 170ms/step - loss: 0.5793 - categorical_accuracy: 0.6099 - val_loss: 1.3911 - val_categorical_accuracy: 0.3763
# Epoch 40/100
# 439/439 [==============================] - ETA: 0s - loss: 0.5799 - categorical_accuracy: 0.6072
# Epoch 00040: val_categorical_accuracy did not improve from 0.42600
# 439/439 [==============================] - 76s 174ms/step - loss: 0.5799 - categorical_accuracy: 0.6072 - val_loss: 1.3993 - val_categorical_accuracy: 0.3767
# Epoch 41/100
# 438/439 [============================>.] - ETA: 0s - loss: 0.5765 - categorical_accuracy: 0.6122
# Epoch 00041: val_categorical_accuracy did not improve from 0.42600
# 439/439 [==============================] - 76s 172ms/step - loss: 0.5759 - categorical_accuracy: 0.6127 - val_loss: 1.4102 - val_categorical_accuracy: 0.3760
# Epoch 42/100
# 438/439 [============================>.] - ETA: 0s - loss: 0.5766 - categorical_accuracy: 0.6124
# Epoch 00042: val_categorical_accuracy did not improve from 0.42600
# 439/439 [==============================] - 75s 171ms/step - loss: 0.5762 - categorical_accuracy: 0.6127 - val_loss: 1.3976 - val_categorical_accuracy: 0.3783
# Epoch 43/100
# 439/439 [==============================] - ETA: 0s - loss: 0.5742 - categorical_accuracy: 0.6146
# Epoch 00043: val_categorical_accuracy did not improve from 0.42600
# 439/439 [==============================] - 75s 171ms/step - loss: 0.5742 - categorical_accuracy: 0.6146 - val_loss: 1.4162 - val_categorical_accuracy: 0.3757
# Epoch 44/100
# 438/439 [============================>.] - ETA: 0s - loss: 0.5729 - categorical_accuracy: 0.6160
# Epoch 00044: val_categorical_accuracy did not improve from 0.42600
# 439/439 [==============================] - 76s 173ms/step - loss: 0.5722 - categorical_accuracy: 0.6165 - val_loss: 1.3953 - val_categorical_accuracy: 0.3807
# Epoch 45/100
# 439/439 [==============================] - ETA: 0s - loss: 0.5729 - categorical_accuracy: 0.6149
# Epoch 00045: val_categorical_accuracy did not improve from 0.42600
# 439/439 [==============================] - 77s 175ms/step - loss: 0.5729 - categorical_accuracy: 0.6149 - val_loss: 1.4148 - val_categorical_accuracy: 0.3790
# Epoch 46/100
# 438/439 [============================>.] - ETA: 0s - loss: 0.5659 - categorical_accuracy: 0.6171
# Epoch 00046: val_categorical_accuracy did not improve from 0.42600
# 439/439 [==============================] - 78s 177ms/step - loss: 0.5652 - categorical_accuracy: 0.6176 - val_loss: 1.3878 - val_categorical_accuracy: 0.3857
# Epoch 47/100
# 438/439 [============================>.] - ETA: 0s - loss: 0.5635 - categorical_accuracy: 0.6165
# Epoch 00047: val_categorical_accuracy did not improve from 0.42600
# 439/439 [==============================] - 77s 175ms/step - loss: 0.5629 - categorical_accuracy: 0.6170 - val_loss: 1.4042 - val_categorical_accuracy: 0.3837
# Epoch 48/100
# 438/439 [============================>.] - ETA: 0s - loss: 0.5645 - categorical_accuracy: 0.6171
# Epoch 00048: val_categorical_accuracy did not improve from 0.42600
# 439/439 [==============================] - 77s 176ms/step - loss: 0.5639 - categorical_accuracy: 0.6175 - val_loss: 1.4147 - val_categorical_accuracy: 0.3847
# Epoch 49/100
# 438/439 [============================>.] - ETA: 0s - loss: 0.5583 - categorical_accuracy: 0.6177
# Epoch 00049: val_categorical_accuracy did not improve from 0.42600
# 439/439 [==============================] - 77s 175ms/step - loss: 0.5578 - categorical_accuracy: 0.6182 - val_loss: 1.4144 - val_categorical_accuracy: 0.3843
# Epoch 50/100
# 439/439 [==============================] - ETA: 0s - loss: 0.5553 - categorical_accuracy: 0.6203
# Epoch 00050: val_categorical_accuracy did not improve from 0.42600
# 439/439 [==============================] - 77s 175ms/step - loss: 0.5553 - categorical_accuracy: 0.6203 - val_loss: 1.3856 - val_categorical_accuracy: 0.3877
# Epoch 51/100
# 439/439 [==============================] - ETA: 0s - loss: 0.5563 - categorical_accuracy: 0.6218
# Epoch 00051: val_categorical_accuracy did not improve from 0.42600
# 439/439 [==============================] - 78s 177ms/step - loss: 0.5563 - categorical_accuracy: 0.6218 - val_loss: 1.3921 - val_categorical_accuracy: 0.3873
# Epoch 52/100
# 439/439 [==============================] - ETA: 0s - loss: 0.5566 - categorical_accuracy: 0.6232
# Epoch 00052: val_categorical_accuracy did not improve from 0.42600
# 439/439 [==============================] - 78s 177ms/step - loss: 0.5566 - categorical_accuracy: 0.6232 - val_loss: 1.3888 - val_categorical_accuracy: 0.3900
# Epoch 53/100
# 439/439 [==============================] - ETA: 0s - loss: 0.5513 - categorical_accuracy: 0.6197
# Epoch 00053: val_categorical_accuracy did not improve from 0.42600
# 439/439 [==============================] - 78s 178ms/step - loss: 0.5513 - categorical_accuracy: 0.6197 - val_loss: 1.4042 - val_categorical_accuracy: 0.3870
# Epoch 54/100
# 439/439 [==============================] - ETA: 0s - loss: 0.5520 - categorical_accuracy: 0.6237
# Epoch 00054: val_categorical_accuracy did not improve from 0.42600
# 439/439 [==============================] - 77s 175ms/step - loss: 0.5520 - categorical_accuracy: 0.6237 - val_loss: 1.4099 - val_categorical_accuracy: 0.3883
# Epoch 55/100
# 438/439 [============================>.] - ETA: 0s - loss: 0.5550 - categorical_accuracy: 0.6226
# Epoch 00055: val_categorical_accuracy did not improve from 0.42600
# 439/439 [==============================] - 76s 174ms/step - loss: 0.5545 - categorical_accuracy: 0.6230 - val_loss: 1.4182 - val_categorical_accuracy: 0.3880
# Epoch 56/100
# 438/439 [============================>.] - ETA: 0s - loss: 0.5457 - categorical_accuracy: 0.6296
# Epoch 00056: val_categorical_accuracy did not improve from 0.42600
# 439/439 [==============================] - 77s 176ms/step - loss: 0.5454 - categorical_accuracy: 0.6298 - val_loss: 1.4267 - val_categorical_accuracy: 0.3897
# Epoch 57/100
# 439/439 [==============================] - ETA: 0s - loss: 0.5463 - categorical_accuracy: 0.6226
# Epoch 00057: val_categorical_accuracy did not improve from 0.42600
# 439/439 [==============================] - 77s 176ms/step - loss: 0.5463 - categorical_accuracy: 0.6226 - val_loss: 1.4195 - val_categorical_accuracy: 0.3930
# Epoch 58/100
# 438/439 [============================>.] - ETA: 0s - loss: 0.5454 - categorical_accuracy: 0.6240
# Epoch 00058: val_categorical_accuracy did not improve from 0.42600
# 439/439 [==============================] - 77s 175ms/step - loss: 0.5452 - categorical_accuracy: 0.6244 - val_loss: 1.4288 - val_categorical_accuracy: 0.3933
# Epoch 59/100
# 438/439 [============================>.] - ETA: 0s - loss: 0.5411 - categorical_accuracy: 0.6266
# Epoch 00059: val_categorical_accuracy did not improve from 0.42600
# 439/439 [==============================] - 77s 174ms/step - loss: 0.5408 - categorical_accuracy: 0.6270 - val_loss: 1.4191 - val_categorical_accuracy: 0.3973
# Epoch 60/100
# 438/439 [============================>.] - ETA: 0s - loss: 0.5493 - categorical_accuracy: 0.6224
# Epoch 00060: val_categorical_accuracy did not improve from 0.42600
# 439/439 [==============================] - 76s 174ms/step - loss: 0.5487 - categorical_accuracy: 0.6228 - val_loss: 1.4406 - val_categorical_accuracy: 0.3957
# Epoch 61/100
# 438/439 [============================>.] - ETA: 0s - loss: 0.5417 - categorical_accuracy: 0.6282
# Epoch 00061: val_categorical_accuracy did not improve from 0.42600
# 439/439 [==============================] - 77s 176ms/step - loss: 0.5411 - categorical_accuracy: 0.6287 - val_loss: 1.4287 - val_categorical_accuracy: 0.3997
# Epoch 62/100
# 438/439 [============================>.] - ETA: 0s - loss: 0.5380 - categorical_accuracy: 0.6283
# Epoch 00062: val_categorical_accuracy did not improve from 0.42600
# 439/439 [==============================] - 76s 174ms/step - loss: 0.5377 - categorical_accuracy: 0.6286 - val_loss: 1.4456 - val_categorical_accuracy: 0.3983
# Epoch 63/100
# 438/439 [============================>.] - ETA: 0s - loss: 0.5387 - categorical_accuracy: 0.6277
# Epoch 00063: val_categorical_accuracy did not improve from 0.42600
# 439/439 [==============================] - 77s 175ms/step - loss: 0.5387 - categorical_accuracy: 0.6280 - val_loss: 1.4503 - val_categorical_accuracy: 0.4017
# Epoch 64/100
# 439/439 [==============================] - ETA: 0s - loss: 0.5373 - categorical_accuracy: 0.6290
# Epoch 00064: val_categorical_accuracy did not improve from 0.42600
# 439/439 [==============================] - 76s 174ms/step - loss: 0.5373 - categorical_accuracy: 0.6290 - val_loss: 1.4634 - val_categorical_accuracy: 0.4050
# Epoch 65/100
# 118/439 [=======>......................] - ETA: 52s - loss: 0.7420 - categorical_accuracy: 0.7217
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-644766fbdb88> in <module>()
#     113
#     114 if __name__ == '__main__':
# --> 115     main()
#
# <ipython-input-2-644766fbdb88> in main()
#     107         callbacks=[
#     108             tf.keras.callbacks.TensorBoard(log_dir),
# --> 109             tf.keras.callbacks.ModelCheckpoint(filepath=weights_file, monitor='val_categorical_accuracy', mode='max', save_best_only=True, save_weights_only=True, verbose=1)
#     110         ]
#     111     )
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py in _method_wrapper(self, *args, **kwargs)
#     106   def _method_wrapper(self, *args, **kwargs):
#     107     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# --> 108       return method(self, *args, **kwargs)
#     109
#     110     # Running inside `run_distribute_coordinator` already.
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1096                 batch_size=batch_size):
#    1097               callbacks.on_train_batch_begin(step)
# -> 1098               tmp_logs = train_function(iterator)
#    1099               if data_handler.should_sync:
#    1100                 context.async_wait()
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     778       else:
#     779         compiler = "nonXla"
# --> 780         result = self._call(*args, **kwds)
#     781
#     782       new_tracing_count = self._get_tracing_count()
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     805       # In this case we have created variables on the first call, so we run the
#     806       # defunned version which is guaranteed to never create variables.
# --> 807       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     808     elif self._stateful_fn is not None:
#     809       # Release the lock early so that multiple threads can perform the call
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2827     with self._lock:
#    2828       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 2829     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2830
#    2831   @property
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in _filtered_call(self, args, kwargs, cancellation_manager)
#    1846                            resource_variable_ops.BaseResourceVariable))],
#    1847         captured_inputs=self.captured_inputs,
# -> 1848         cancellation_manager=cancellation_manager)
#    1849
#    1850   def _call_flat(self, args, captured_inputs, cancellation_manager=None):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1922       # No tape is watching; skip to running the function.
#    1923       return self._build_call_outputs(self._inference_function.call(
# -> 1924           ctx, args, cancellation_manager=cancellation_manager))
#    1925     forward_backward = self._select_forward_and_backward_functions(
#    1926         args,
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     548               inputs=args,
#     549               attrs=attrs,
# --> 550               ctx=ctx)
#     551         else:
#     552           outputs = execute.execute_with_cancellation(
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# KeyboardInterrupt:

# %%
__author__ = 'Alexander Soroka, soroka.a.m@gmail.com'
__copyright__ = """Copyright 2020 Alexander Soroka"""


import argparse
import glob
import numpy as np
import tensorflow as tf
import time
from tensorflow.python import keras as keras
from tensorflow.python.keras.callbacks import LearningRateScheduler

import tensorflow_addons as tfa


LOG_DIR = 'logs'
SHUFFLE_BUFFER = 4
BATCH_SIZE = 64
NUM_CLASSES = 6
PARALLEL_CALLS=4
RESIZE_TO = 224
TRAINSET_SIZE = 14034
VALSET_SIZE = 3000


def parse_proto_example(proto):
    keys_to_features = {
        'image/encoded': tf.io.FixedLenFeature((), tf.string, default_value=''),
        'image/class/label': tf.io.FixedLenFeature([], tf.int64, default_value=tf.zeros([], dtype=tf.int64))
    }
    example = tf.io.parse_single_example(proto, keys_to_features)
    example['image'] = tf.image.decode_jpeg(example['image/encoded'], channels=3)
    example['image'] = tf.image.convert_image_dtype(example['image'], dtype=tf.float32)
    example['image'] = tf.image.resize(example['image'], tf.constant([RESIZE_TO, RESIZE_TO]))
    return example['image'], tf.one_hot(example['image/class/label'], depth=NUM_CLASSES)


def normalize(image, label):
    return tf.image.per_image_standardization(image), label

def resize(image, label):
    return tf.image.resize(image, tf.constant([RESIZE_TO, RESIZE_TO])), label

def augmentation(image,label):
    with tf.name_scope('Add_gaussian_noise'):
        noise_img = image + tf.random.normal(shape=tf.shape(image), mean=0.0, stddev=1.0, dtype=tf.float32)
        noise_img = tf.clip_by_value(noise_img, 0.0, 1.0)
    return noise_img,label

def create_dataset(filenames, batch_size):
    """Create dataset from tfrecords file
    :tfrecords_files: Mask to collect tfrecords file of dataset
    :returns: tf.data.Dataset
    """
    return tf.data.TFRecordDataset(filenames)\
        .map(parse_proto_example)\
        .map(resize)\
        .map(normalize)\
        .batch(batch_size)\
        .prefetch(batch_size)

def create_aug_dataset(filenames, batch_size):
    """Create dataset from tfrecords file
    :tfrecords_files: Mask to collect tfrecords file of dataset
    :returns: tf.data.Dataset
    """
    return tf.data.TFRecordDataset(filenames)\
        .map(parse_proto_example)\
        .map(resize)\
        .map(normalize)\
        .map(augmentation)\
        .shuffle(buffer_size=5 * batch_size)\
        .batch(batch_size)\
        .prefetch(2 * batch_size)


def build_model():
    new_model = tf.keras.applications.MobileNetV2(input_shape=(224,224,3),
						classes = NUM_CLASSES,
            include_top=False,
            weights='imagenet')
    
    return tf.keras.models.Sequential([
    	new_model,
    	tf.keras.layers.Flatten(),
      tf.keras.layers.Dense(NUM_CLASSES, activation=tf.keras.activations.softmax)
    ])


def main():
    #args = argparse.ArgumentParser()
    #args.add_argument('--train', type=str, help='Glob pattern to collect train tfrecord files')
    #args.add_argument('--test', type=str, help='Glob pattern to collect test tfrecord files')
    #args = args.parse_args()
    train_path = '/content/drive/My Drive/SMOMI/dataset/train*'
    test_path = '/content/drive/My Drive/SMOMI/dataset/val*'

    train_dataset = create_aug_dataset(glob.glob(train_path), BATCH_SIZE)
    validation_dataset = create_dataset(glob.glob(test_path), BATCH_SIZE)

    model = build_model()

    model.compile(
        optimizer=tf.optimizers.SGD(lr=0.000001, momentum=0.9),
        loss=tf.keras.losses.categorical_crossentropy,
        metrics=[tf.keras.metrics.categorical_accuracy],
    )

    log_dir='/content/drive/My Drive/SMOMI/{}/lab4_4/ilcd-{}'.format(LOG_DIR, time.time())
    model.fit(
        train_dataset,
        epochs=100,
        validation_data=validation_dataset,
        callbacks=[
            tf.keras.callbacks.TensorBoard(log_dir),
        ]
    )


if __name__ == '__main__':
    main()
# Out:
# Epoch 1/100
#       2/Unknown - 2s 789ms/step - loss: 4.0638 - categorical_accuracy: 0.0625WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1052s vs `on_train_batch_end` time: 1.2041s). Check your callbacks.
# 220/220 [==============================] - 98s 444ms/step - loss: 2.2193 - categorical_accuracy: 0.1771 - val_loss: 1.9514 - val_categorical_accuracy: 0.1740
# Epoch 2/100
# 220/220 [==============================] - 98s 445ms/step - loss: 2.0865 - categorical_accuracy: 0.1985 - val_loss: 1.8341 - val_categorical_accuracy: 0.2073
# Epoch 3/100
# 220/220 [==============================] - 97s 443ms/step - loss: 2.0235 - categorical_accuracy: 0.2075 - val_loss: 1.7680 - val_categorical_accuracy: 0.2230
# Epoch 4/100
# 220/220 [==============================] - 97s 442ms/step - loss: 1.9462 - categorical_accuracy: 0.2223 - val_loss: 1.7307 - val_categorical_accuracy: 0.2317
# Epoch 5/100
# 220/220 [==============================] - 98s 447ms/step - loss: 1.8882 - categorical_accuracy: 0.2351 - val_loss: 1.7615 - val_categorical_accuracy: 0.2400
# Epoch 6/100
# 220/220 [==============================] - 98s 446ms/step - loss: 1.8634 - categorical_accuracy: 0.2419 - val_loss: 1.7802 - val_categorical_accuracy: 0.2403
# Epoch 7/100
# 220/220 [==============================] - 98s 447ms/step - loss: 1.8085 - categorical_accuracy: 0.2528 - val_loss: 1.8080 - val_categorical_accuracy: 0.2437
# Epoch 8/100
# 220/220 [==============================] - 98s 446ms/step - loss: 1.7828 - categorical_accuracy: 0.2585 - val_loss: 1.8455 - val_categorical_accuracy: 0.2303
# Epoch 9/100
# 220/220 [==============================] - 98s 446ms/step - loss: 1.7546 - categorical_accuracy: 0.2639 - val_loss: 1.8654 - val_categorical_accuracy: 0.2323
# Epoch 10/100
# 220/220 [==============================] - 98s 446ms/step - loss: 1.7114 - categorical_accuracy: 0.2758 - val_loss: 1.8755 - val_categorical_accuracy: 0.2363
# Epoch 11/100
# 220/220 [==============================] - 98s 448ms/step - loss: 1.6828 - categorical_accuracy: 0.2793 - val_loss: 1.8818 - val_categorical_accuracy: 0.2323
# Epoch 12/100
# 220/220 [==============================] - 99s 449ms/step - loss: 1.6621 - categorical_accuracy: 0.2847 - val_loss: 1.8786 - val_categorical_accuracy: 0.2370
# Epoch 13/100
# 220/220 [==============================] - 99s 450ms/step - loss: 1.6422 - categorical_accuracy: 0.2888 - val_loss: 1.8902 - val_categorical_accuracy: 0.2393
# Epoch 14/100
# 220/220 [==============================] - 99s 450ms/step - loss: 1.6224 - categorical_accuracy: 0.2981 - val_loss: 1.8868 - val_categorical_accuracy: 0.2343
# Epoch 15/100
# 220/220 [==============================] - 98s 445ms/step - loss: 1.5995 - categorical_accuracy: 0.2996 - val_loss: 1.8895 - val_categorical_accuracy: 0.2323
# Epoch 16/100
# 220/220 [==============================] - 98s 446ms/step - loss: 1.5847 - categorical_accuracy: 0.3072 - val_loss: 1.8793 - val_categorical_accuracy: 0.2350
# Epoch 17/100
# 220/220 [==============================] - 98s 446ms/step - loss: 1.5659 - categorical_accuracy: 0.3121 - val_loss: 1.8764 - val_categorical_accuracy: 0.2367
# Epoch 18/100
# 220/220 [==============================] - 98s 447ms/step - loss: 1.5462 - categorical_accuracy: 0.3217 - val_loss: 1.8705 - val_categorical_accuracy: 0.2340
# Epoch 19/100
# 220/220 [==============================] - 98s 445ms/step - loss: 1.5442 - categorical_accuracy: 0.3185 - val_loss: 1.8625 - val_categorical_accuracy: 0.2340
# Epoch 20/100
# 220/220 [==============================] - 99s 448ms/step - loss: 1.5081 - categorical_accuracy: 0.3286 - val_loss: 1.8579 - val_categorical_accuracy: 0.2343
# Epoch 21/100
# 220/220 [==============================] - 98s 446ms/step - loss: 1.5001 - categorical_accuracy: 0.3319 - val_loss: 1.8576 - val_categorical_accuracy: 0.2347
# Epoch 22/100
# 220/220 [==============================] - 98s 448ms/step - loss: 1.4777 - categorical_accuracy: 0.3340 - val_loss: 1.8509 - val_categorical_accuracy: 0.2357
# Epoch 23/100
# 220/220 [==============================] - 98s 445ms/step - loss: 1.4655 - categorical_accuracy: 0.3413 - val_loss: 1.8396 - val_categorical_accuracy: 0.2360
# Epoch 24/100
# 220/220 [==============================] - 98s 446ms/step - loss: 1.4645 - categorical_accuracy: 0.3437 - val_loss: 1.8379 - val_categorical_accuracy: 0.2357
# Epoch 25/100
# 220/220 [==============================] - 99s 448ms/step - loss: 1.4491 - categorical_accuracy: 0.3501 - val_loss: 1.8388 - val_categorical_accuracy: 0.2373
# Epoch 26/100
# 220/220 [==============================] - 98s 447ms/step - loss: 1.4539 - categorical_accuracy: 0.3489 - val_loss: 1.8349 - val_categorical_accuracy: 0.2390
# Epoch 27/100
# 220/220 [==============================] - 98s 447ms/step - loss: 1.4070 - categorical_accuracy: 0.3539 - val_loss: 1.8321 - val_categorical_accuracy: 0.2407
# Epoch 28/100
# 220/220 [==============================] - 98s 447ms/step - loss: 1.4193 - categorical_accuracy: 0.3556 - val_loss: 1.8262 - val_categorical_accuracy: 0.2450
# Epoch 29/100
# 220/220 [==============================] - 98s 447ms/step - loss: 1.3871 - categorical_accuracy: 0.3654 - val_loss: 1.8229 - val_categorical_accuracy: 0.2463
# Epoch 30/100
# 220/220 [==============================] - 98s 446ms/step - loss: 1.3885 - categorical_accuracy: 0.3673 - val_loss: 1.8200 - val_categorical_accuracy: 0.2490
# Epoch 31/100
# 220/220 [==============================] - 98s 446ms/step - loss: 1.3807 - categorical_accuracy: 0.3655 - val_loss: 1.8218 - val_categorical_accuracy: 0.2507
# Epoch 32/100
# 220/220 [==============================] - 98s 446ms/step - loss: 1.3697 - categorical_accuracy: 0.3722 - val_loss: 1.8227 - val_categorical_accuracy: 0.2487
# Epoch 33/100
# 220/220 [==============================] - 98s 447ms/step - loss: 1.3514 - categorical_accuracy: 0.3776 - val_loss: 1.8221 - val_categorical_accuracy: 0.2510
# Epoch 34/100
# 220/220 [==============================] - 98s 446ms/step - loss: 1.3500 - categorical_accuracy: 0.3801 - val_loss: 1.8205 - val_categorical_accuracy: 0.2520
# Epoch 35/100
# 220/220 [==============================] - 98s 447ms/step - loss: 1.3451 - categorical_accuracy: 0.3787 - val_loss: 1.8121 - val_categorical_accuracy: 0.2553
# Epoch 36/100
# 220/220 [==============================] - 98s 444ms/step - loss: 1.3227 - categorical_accuracy: 0.3899 - val_loss: 1.7993 - val_categorical_accuracy: 0.2593
# Epoch 37/100
# 220/220 [==============================] - 98s 445ms/step - loss: 1.3312 - categorical_accuracy: 0.3815 - val_loss: 1.7970 - val_categorical_accuracy: 0.2613
# Epoch 38/100
# 220/220 [==============================] - 98s 447ms/step - loss: 1.3198 - categorical_accuracy: 0.3871 - val_loss: 1.7957 - val_categorical_accuracy: 0.2617
# Epoch 39/100
# 220/220 [==============================] - 98s 445ms/step - loss: 1.2995 - categorical_accuracy: 0.3912 - val_loss: 1.7866 - val_categorical_accuracy: 0.2613
# Epoch 40/100
# 220/220 [==============================] - 98s 446ms/step - loss: 1.3006 - categorical_accuracy: 0.3918 - val_loss: 1.7825 - val_categorical_accuracy: 0.2633
# Epoch 41/100
# 220/220 [==============================] - 99s 448ms/step - loss: 1.2919 - categorical_accuracy: 0.3970 - val_loss: 1.7753 - val_categorical_accuracy: 0.2617
# Epoch 42/100
# 220/220 [==============================] - 98s 448ms/step - loss: 1.2751 - categorical_accuracy: 0.3989 - val_loss: 1.7658 - val_categorical_accuracy: 0.2617
# Epoch 43/100
# 220/220 [==============================] - 98s 445ms/step - loss: 1.2925 - categorical_accuracy: 0.4032 - val_loss: 1.7626 - val_categorical_accuracy: 0.2623
# Epoch 44/100
# 220/220 [==============================] - 98s 445ms/step - loss: 1.2590 - categorical_accuracy: 0.4049 - val_loss: 1.7574 - val_categorical_accuracy: 0.2650
# Epoch 45/100
# 220/220 [==============================] - 98s 447ms/step - loss: 1.2717 - categorical_accuracy: 0.4053 - val_loss: 1.7539 - val_categorical_accuracy: 0.2650
# Epoch 46/100
# 146/220 [==================>...........] - ETA: 31s - loss: 1.5708 - categorical_accuracy: 0.4693

# %%
__author__ = 'Alexander Soroka, soroka.a.m@gmail.com'
__copyright__ = """Copyright 2020 Alexander Soroka"""


import argparse
import glob
import numpy as np
import tensorflow as tf
import time
from tensorflow.python import keras as keras
from tensorflow.python.keras.callbacks import LearningRateScheduler


LOG_DIR = 'logs'
SHUFFLE_BUFFER = 4
BATCH_SIZE = 64
NUM_CLASSES = 6
PARALLEL_CALLS=4
RESIZE_TO = 224
TRAINSET_SIZE = 14034
VALSET_SIZE = 3000


def parse_proto_example(proto):
    keys_to_features = {
        'image/encoded': tf.io.FixedLenFeature((), tf.string, default_value=''),
        'image/class/label': tf.io.FixedLenFeature([], tf.int64, default_value=tf.zeros([], dtype=tf.int64))
    }
    example = tf.io.parse_single_example(proto, keys_to_features)
    example['image'] = tf.image.decode_jpeg(example['image/encoded'], channels=3)
    example['image'] = tf.image.convert_image_dtype(example['image'], dtype=tf.float32)
    example['image'] = tf.image.resize(example['image'], tf.constant([RESIZE_TO, RESIZE_TO]))
    return example['image'], tf.one_hot(example['image/class/label'], depth=NUM_CLASSES)


def normalize(image, label):
    return tf.image.per_image_standardization(image), label

def resize(image, label):
    return tf.image.resize(image, tf.constant([RESIZE_TO, RESIZE_TO])), label

def create_dataset(filenames, batch_size):
    """Create dataset from tfrecords file
    :tfrecords_files: Mask to collect tfrecords file of dataset
    :returns: tf.data.Dataset
    """
    return tf.data.TFRecordDataset(filenames)\
        .map(parse_proto_example)\
        .map(resize)\
        .map(normalize)\
        .batch(batch_size)\
        .prefetch(batch_size)


def build_model():
    return tf.keras.applications.MobileNetV2(
        input_shape=(224,224,3),
        classes = NUM_CLASSES,
        include_top=True,
        weights=None
        )


def main():
    #args = argparse.ArgumentParser()
    #args.add_argument('--train', type=str, help='Glob pattern to collect train tfrecord files')
    #args.add_argument('--test', type=str, help='Glob pattern to collect test tfrecord files')
    #args = args.parse_args()
    train_path = '/content/drive/My Drive/SMOMI/dataset/train*'
    test_path = '/content/drive/My Drive/SMOMI/dataset/val*'

    train_dataset = create_dataset(glob.glob(train_path), BATCH_SIZE)
    validation_dataset = create_dataset(glob.glob(test_path), BATCH_SIZE)

    model = build_model()

    model.compile(
        optimizer=tf.optimizers.SGD(lr=0.0003, momentum=0.9),
        loss=tf.keras.losses.categorical_crossentropy,
        metrics=[tf.keras.metrics.categorical_accuracy],
    )

    log_dir='/content/drive/My Drive/SMOMI/{}/lab3_1-2/ilcd-{}'.format(LOG_DIR, time.time())
    model.fit(
        train_dataset,
        epochs=300,
        validation_data=validation_dataset,
        callbacks=[
            tf.keras.callbacks.TensorBoard(log_dir),
        ]
    )


if __name__ == '__main__':
    main()
# Out:
# Epoch 1/300
#       2/Unknown - 1s 691ms/step - loss: 2.2928 - categorical_accuracy: 0.0000e+00WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1123s vs `on_train_batch_end` time: 1.0092s). Check your callbacks.
# 220/220 [==============================] - 109s 494ms/step - loss: 1.3862 - categorical_accuracy: 0.5482 - val_loss: 1.4917 - val_categorical_accuracy: 0.1457
# Epoch 2/300
# 220/220 [==============================] - 94s 429ms/step - loss: 1.3713 - categorical_accuracy: 0.5437 - val_loss: 1.4858 - val_categorical_accuracy: 0.1457
# Epoch 3/300
# 220/220 [==============================] - 95s 433ms/step - loss: 1.3506 - categorical_accuracy: 0.5288 - val_loss: 1.4786 - val_categorical_accuracy: 0.1457
# Epoch 4/300
# 220/220 [==============================] - 97s 439ms/step - loss: 1.3440 - categorical_accuracy: 0.5301 - val_loss: 1.4764 - val_categorical_accuracy: 0.1457
# Epoch 5/300
# 220/220 [==============================] - 96s 436ms/step - loss: 1.3381 - categorical_accuracy: 0.5499 - val_loss: 1.4787 - val_categorical_accuracy: 0.1457
# Epoch 6/300
# 220/220 [==============================] - 96s 436ms/step - loss: 1.3472 - categorical_accuracy: 0.5716 - val_loss: 1.4840 - val_categorical_accuracy: 0.1457
# Epoch 7/300
# 220/220 [==============================] - 97s 439ms/step - loss: 1.3572 - categorical_accuracy: 0.5896 - val_loss: 1.4914 - val_categorical_accuracy: 0.1457
# Epoch 8/300
# 220/220 [==============================] - 96s 437ms/step - loss: 1.3628 - categorical_accuracy: 0.5947 - val_loss: 1.5003 - val_categorical_accuracy: 0.1457
# Epoch 9/300
# 220/220 [==============================] - 96s 437ms/step - loss: 1.3710 - categorical_accuracy: 0.6012 - val_loss: 1.5110 - val_categorical_accuracy: 0.1457
# Epoch 10/300
# 220/220 [==============================] - 96s 435ms/step - loss: 1.3812 - categorical_accuracy: 0.6070 - val_loss: 1.5223 - val_categorical_accuracy: 0.1457
# Epoch 11/300
# 220/220 [==============================] - 96s 435ms/step - loss: 1.3860 - categorical_accuracy: 0.6095 - val_loss: 1.5341 - val_categorical_accuracy: 0.1457
# Epoch 12/300
# 220/220 [==============================] - 95s 432ms/step - loss: 1.3960 - categorical_accuracy: 0.6147 - val_loss: 1.5465 - val_categorical_accuracy: 0.1457
# Epoch 13/300
# 220/220 [==============================] - 95s 434ms/step - loss: 1.4094 - categorical_accuracy: 0.6199 - val_loss: 1.5572 - val_categorical_accuracy: 0.1457
# Epoch 14/300
# 220/220 [==============================] - 95s 433ms/step - loss: 1.4263 - categorical_accuracy: 0.6238 - val_loss: 1.5706 - val_categorical_accuracy: 0.1457
# Epoch 15/300
# 220/220 [==============================] - 96s 435ms/step - loss: 1.4544 - categorical_accuracy: 0.6308 - val_loss: 1.5894 - val_categorical_accuracy: 0.1457
# Epoch 16/300
# 220/220 [==============================] - 95s 434ms/step - loss: 1.4887 - categorical_accuracy: 0.6340 - val_loss: 1.6182 - val_categorical_accuracy: 0.1750
# Epoch 17/300
# 220/220 [==============================] - 96s 435ms/step - loss: 1.5324 - categorical_accuracy: 0.6362 - val_loss: 1.6461 - val_categorical_accuracy: 0.1750
# Epoch 18/300
# 220/220 [==============================] - 96s 436ms/step - loss: 1.5722 - categorical_accuracy: 0.6392 - val_loss: 1.6791 - val_categorical_accuracy: 0.1750
# Epoch 19/300
# 220/220 [==============================] - 96s 436ms/step - loss: 1.6127 - categorical_accuracy: 0.6406 - val_loss: 1.7110 - val_categorical_accuracy: 0.1750
# Epoch 20/300
# 220/220 [==============================] - 95s 434ms/step - loss: 1.6526 - categorical_accuracy: 0.6418 - val_loss: 1.7384 - val_categorical_accuracy: 0.1750
# Epoch 21/300
# 220/220 [==============================] - 96s 439ms/step - loss: 1.6922 - categorical_accuracy: 0.6437 - val_loss: 1.7724 - val_categorical_accuracy: 0.1750
# Epoch 22/300
# 220/220 [==============================] - 96s 434ms/step - loss: 1.7426 - categorical_accuracy: 0.6482 - val_loss: 1.8196 - val_categorical_accuracy: 0.1750
# Epoch 23/300
# 220/220 [==============================] - 95s 432ms/step - loss: 1.7934 - categorical_accuracy: 0.6507 - val_loss: 1.8663 - val_categorical_accuracy: 0.1750
# Epoch 24/300
# 220/220 [==============================] - 96s 435ms/step - loss: 1.8295 - categorical_accuracy: 0.6490 - val_loss: 1.9076 - val_categorical_accuracy: 0.1750
# Epoch 25/300
# 220/220 [==============================] - 95s 432ms/step - loss: 1.8626 - categorical_accuracy: 0.6473 - val_loss: 1.9432 - val_categorical_accuracy: 0.1750
# Epoch 26/300
# 220/220 [==============================] - 95s 433ms/step - loss: 1.8948 - categorical_accuracy: 0.6479 - val_loss: 1.9754 - val_categorical_accuracy: 0.1750
# Epoch 27/300
# 220/220 [==============================] - 95s 432ms/step - loss: 1.9221 - categorical_accuracy: 0.6486 - val_loss: 1.9995 - val_categorical_accuracy: 0.1750
# Epoch 28/300
# 220/220 [==============================] - 96s 436ms/step - loss: 1.9535 - categorical_accuracy: 0.6529 - val_loss: 2.0201 - val_categorical_accuracy: 0.1750
# Epoch 29/300
# 220/220 [==============================] - 96s 436ms/step - loss: 1.9804 - categorical_accuracy: 0.6557 - val_loss: 2.0117 - val_categorical_accuracy: 0.1750
# Epoch 30/300
# 220/220 [==============================] - 96s 434ms/step - loss: 2.0120 - categorical_accuracy: 0.6618 - val_loss: 2.0415 - val_categorical_accuracy: 0.1703
# Epoch 31/300
# 220/220 [==============================] - 96s 435ms/step - loss: 2.0521 - categorical_accuracy: 0.6592 - val_loss: 2.0610 - val_categorical_accuracy: 0.1790
# Epoch 32/300
# 220/220 [==============================] - 95s 433ms/step - loss: 2.1334 - categorical_accuracy: 0.6641 - val_loss: 2.1469 - val_categorical_accuracy: 0.1813
# Epoch 33/300
# 220/220 [==============================] - 96s 436ms/step - loss: 2.2365 - categorical_accuracy: 0.6648 - val_loss: 2.1781 - val_categorical_accuracy: 0.1590
# Epoch 34/300
# 220/220 [==============================] - 96s 435ms/step - loss: 2.2374 - categorical_accuracy: 0.6607 - val_loss: 2.4054 - val_categorical_accuracy: 0.1680
# Epoch 35/300
# 220/220 [==============================] - 96s 435ms/step - loss: 2.3288 - categorical_accuracy: 0.6623 - val_loss: 2.3784 - val_categorical_accuracy: 0.1833
# Epoch 36/300
# 220/220 [==============================] - 96s 436ms/step - loss: 2.3427 - categorical_accuracy: 0.6672 - val_loss: 2.6587 - val_categorical_accuracy: 0.1457
# Epoch 37/300
# 220/220 [==============================] - 95s 433ms/step - loss: 2.3967 - categorical_accuracy: 0.6704 - val_loss: 2.6131 - val_categorical_accuracy: 0.1457
# Epoch 38/300
# 220/220 [==============================] - 96s 434ms/step - loss: 2.3644 - categorical_accuracy: 0.6692 - val_loss: 2.8454 - val_categorical_accuracy: 0.1457
# Epoch 39/300
# 220/220 [==============================] - 95s 434ms/step - loss: 2.5143 - categorical_accuracy: 0.6771 - val_loss: 2.9358 - val_categorical_accuracy: 0.1453
# Epoch 40/300
# 220/220 [==============================] - 96s 435ms/step - loss: 2.6501 - categorical_accuracy: 0.6786 - val_loss: 3.3087 - val_categorical_accuracy: 0.1417
# Epoch 41/300
# 220/220 [==============================] - 95s 432ms/step - loss: 2.6628 - categorical_accuracy: 0.6686 - val_loss: 3.0262 - val_categorical_accuracy: 0.1457
# Epoch 42/300
# 220/220 [==============================] - 96s 436ms/step - loss: 2.8268 - categorical_accuracy: 0.6834 - val_loss: 2.9298 - val_categorical_accuracy: 0.1457
# Epoch 43/300
# 220/220 [==============================] - 96s 436ms/step - loss: 2.9755 - categorical_accuracy: 0.6769 - val_loss: 3.5434 - val_categorical_accuracy: 0.1457
# Epoch 44/300
# 220/220 [==============================] - 94s 429ms/step - loss: 3.2262 - categorical_accuracy: 0.6848 - val_loss: 3.2945 - val_categorical_accuracy: 0.1490
# Epoch 45/300
# 220/220 [==============================] - 96s 436ms/step - loss: 3.1572 - categorical_accuracy: 0.6837 - val_loss: 4.0384 - val_categorical_accuracy: 0.1007
# Epoch 46/300
# 220/220 [==============================] - 95s 434ms/step - loss: 3.3890 - categorical_accuracy: 0.6825 - val_loss: 3.1834 - val_categorical_accuracy: 0.1457
# Epoch 47/300
# 220/220 [==============================] - 96s 434ms/step - loss: 3.4727 - categorical_accuracy: 0.6884 - val_loss: 3.4768 - val_categorical_accuracy: 0.1457
# Epoch 48/300
# 220/220 [==============================] - 96s 437ms/step - loss: 3.6884 - categorical_accuracy: 0.6836 - val_loss: 4.0076 - val_categorical_accuracy: 0.1757
# Epoch 49/300
# 220/220 [==============================] - 96s 435ms/step - loss: 3.9481 - categorical_accuracy: 0.6836 - val_loss: 3.9968 - val_categorical_accuracy: 0.1803
# Epoch 50/300
# 220/220 [==============================] - 96s 437ms/step - loss: 4.0421 - categorical_accuracy: 0.6841 - val_loss: 4.6164 - val_categorical_accuracy: 0.1803
# Epoch 51/300
# 220/220 [==============================] - 96s 434ms/step - loss: 4.3213 - categorical_accuracy: 0.6821 - val_loss: 4.6943 - val_categorical_accuracy: 0.1910
# Epoch 52/300
# 220/220 [==============================] - 96s 434ms/step - loss: 4.3438 - categorical_accuracy: 0.6937 - val_loss: 5.6703 - val_categorical_accuracy: 0.1540
# Epoch 53/300
# 220/220 [==============================] - 96s 435ms/step - loss: 4.2087 - categorical_accuracy: 0.6947 - val_loss: 4.6837 - val_categorical_accuracy: 0.1870
# Epoch 54/300
# 220/220 [==============================] - 96s 436ms/step - loss: 5.0812 - categorical_accuracy: 0.6852 - val_loss: 4.9861 - val_categorical_accuracy: 0.1457
# Epoch 55/300
# 220/220 [==============================] - 95s 432ms/step - loss: 4.5055 - categorical_accuracy: 0.7015 - val_loss: 5.9775 - val_categorical_accuracy: 0.1757
# Epoch 56/300
# 220/220 [==============================] - 96s 437ms/step - loss: 5.9081 - categorical_accuracy: 0.6905 - val_loss: 5.5343 - val_categorical_accuracy: 0.1750
# Epoch 57/300
# 220/220 [==============================] - 95s 433ms/step - loss: 5.6523 - categorical_accuracy: 0.6863 - val_loss: 7.6775 - val_categorical_accuracy: 0.1700
# Epoch 58/300
# 220/220 [==============================] - 96s 435ms/step - loss: 6.1265 - categorical_accuracy: 0.6980 - val_loss: 5.4672 - val_categorical_accuracy: 0.1900
# Epoch 59/300
# 220/220 [==============================] - 95s 433ms/step - loss: 5.9161 - categorical_accuracy: 0.6867 - val_loss: 8.3857 - val_categorical_accuracy: 0.1927
# Epoch 60/300
# 220/220 [==============================] - 95s 433ms/step - loss: 7.0789 - categorical_accuracy: 0.7047 - val_loss: 5.7413 - val_categorical_accuracy: 0.1703
# Epoch 61/300
# 220/220 [==============================] - 95s 433ms/step - loss: 7.5511 - categorical_accuracy: 0.6650 - val_loss: 9.6456 - val_categorical_accuracy: 0.1727
# Epoch 62/300
# 220/220 [==============================] - 96s 437ms/step - loss: 8.3751 - categorical_accuracy: 0.6865 - val_loss: 8.0566 - val_categorical_accuracy: 0.2080
# Epoch 63/300
# 220/220 [==============================] - 96s 434ms/step - loss: 9.7188 - categorical_accuracy: 0.6632 - val_loss: 10.3939 - val_categorical_accuracy: 0.1457
# Epoch 64/300
# 220/220 [==============================] - 96s 435ms/step - loss: 7.7753 - categorical_accuracy: 0.7128 - val_loss: 9.2218 - val_categorical_accuracy: 0.2417
# Epoch 65/300
# 220/220 [==============================] - 95s 431ms/step - loss: 11.0665 - categorical_accuracy: 0.6684 - val_loss: 10.1332 - val_categorical_accuracy: 0.1780
# Epoch 66/300
# 220/220 [==============================] - 96s 435ms/step - loss: 7.1434 - categorical_accuracy: 0.7168 - val_loss: 9.6082 - val_categorical_accuracy: 0.2730
# Epoch 67/300
# 220/220 [==============================] - 95s 434ms/step - loss: 12.1149 - categorical_accuracy: 0.6764 - val_loss: 10.6433 - val_categorical_accuracy: 0.1457
# Epoch 68/300
# 220/220 [==============================] - 96s 435ms/step - loss: 9.0908 - categorical_accuracy: 0.7062 - val_loss: 13.0414 - val_categorical_accuracy: 0.2060
# Epoch 69/300
# 220/220 [==============================] - 95s 434ms/step - loss: 12.1257 - categorical_accuracy: 0.7058 - val_loss: 8.7361 - val_categorical_accuracy: 0.2183
# Epoch 70/300
# 220/220 [==============================] - 96s 436ms/step - loss: 12.6812 - categorical_accuracy: 0.6761 - val_loss: 18.2784 - val_categorical_accuracy: 0.1833
# Epoch 71/300
# 220/220 [==============================] - 95s 432ms/step - loss: 13.6162 - categorical_accuracy: 0.6991 - val_loss: 13.8137 - val_categorical_accuracy: 0.1743
# Epoch 72/300
# 220/220 [==============================] - 95s 430ms/step - loss: 11.8629 - categorical_accuracy: 0.7090 - val_loss: 15.6031 - val_categorical_accuracy: 0.1843
# Epoch 73/300
# 220/220 [==============================] - 96s 435ms/step - loss: 13.2153 - categorical_accuracy: 0.7105 - val_loss: 20.3785 - val_categorical_accuracy: 0.1750
# Epoch 74/300
# 220/220 [==============================] - 95s 430ms/step - loss: 14.3319 - categorical_accuracy: 0.7170 - val_loss: 15.8180 - val_categorical_accuracy: 0.1840
# Epoch 75/300
# 220/220 [==============================] - 95s 431ms/step - loss: 10.8217 - categorical_accuracy: 0.7339 - val_loss: 16.3997 - val_categorical_accuracy: 0.1457
# Epoch 76/300
# 220/220 [==============================] - 95s 431ms/step - loss: 13.2799 - categorical_accuracy: 0.7318 - val_loss: 17.7417 - val_categorical_accuracy: 0.1457
# Epoch 77/300
# 220/220 [==============================] - 95s 431ms/step - loss: 15.9273 - categorical_accuracy: 0.7152 - val_loss: 20.1122 - val_categorical_accuracy: 0.1580
# Epoch 78/300
# 220/220 [==============================] - 94s 429ms/step - loss: 24.9598 - categorical_accuracy: 0.6698 - val_loss: 21.3434 - val_categorical_accuracy: 0.1843
# Epoch 79/300
# 220/220 [==============================] - 94s 426ms/step - loss: 28.0244 - categorical_accuracy: 0.6741 - val_loss: 24.2122 - val_categorical_accuracy: 0.1580
# Epoch 80/300
# 220/220 [==============================] - 94s 429ms/step - loss: 28.4833 - categorical_accuracy: 0.6709 - val_loss: 5.3039 - val_categorical_accuracy: 0.1580
# Epoch 81/300
# 220/220 [==============================] - 94s 428ms/step - loss: 32.0672 - categorical_accuracy: 0.6709 - val_loss: 10.4072 - val_categorical_accuracy: 0.1457
# Epoch 82/300
# 220/220 [==============================] - 95s 430ms/step - loss: 27.0369 - categorical_accuracy: 0.7243 - val_loss: 23.4080 - val_categorical_accuracy: 0.1580
# Epoch 83/300
# 220/220 [==============================] - 94s 427ms/step - loss: 50.5085 - categorical_accuracy: 0.6650 - val_loss: 30.4990 - val_categorical_accuracy: 0.1457
# Epoch 84/300
# 220/220 [==============================] - 95s 430ms/step - loss: 44.2505 - categorical_accuracy: 0.6833 - val_loss: 47.0309 - val_categorical_accuracy: 0.1457
# Epoch 85/300
# 220/220 [==============================] - 94s 426ms/step - loss: 27.2016 - categorical_accuracy: 0.7517 - val_loss: 31.0871 - val_categorical_accuracy: 0.1457
# Epoch 86/300
# 220/220 [==============================] - 94s 429ms/step - loss: 43.4244 - categorical_accuracy: 0.6925 - val_loss: 61.1029 - val_categorical_accuracy: 0.1580
# Epoch 87/300
# 220/220 [==============================] - 94s 426ms/step - loss: 63.3836 - categorical_accuracy: 0.6924 - val_loss: 26.7360 - val_categorical_accuracy: 0.1690
# Epoch 88/300
# 220/220 [==============================] - 94s 428ms/step - loss: 54.9899 - categorical_accuracy: 0.6750 - val_loss: 60.2121 - val_categorical_accuracy: 0.1670
# Epoch 89/300
# 220/220 [==============================] - 94s 425ms/step - loss: 97.4113 - categorical_accuracy: 0.6149 - val_loss: 71.2524 - val_categorical_accuracy: 0.1457
# Epoch 90/300
# 220/220 [==============================] - 94s 427ms/step - loss: 76.1949 - categorical_accuracy: 0.7015 - val_loss: 31.2446 - val_categorical_accuracy: 0.1457
# Epoch 91/300
# 220/220 [==============================] - 93s 424ms/step - loss: 49.5035 - categorical_accuracy: 0.6924 - val_loss: 72.7894 - val_categorical_accuracy: 0.1750
# Epoch 92/300
# 220/220 [==============================] - 94s 428ms/step - loss: 96.2155 - categorical_accuracy: 0.6650 - val_loss: 52.7308 - val_categorical_accuracy: 0.1750
# Epoch 93/300
# 220/220 [==============================] - 93s 424ms/step - loss: 58.5520 - categorical_accuracy: 0.6970 - val_loss: 68.4406 - val_categorical_accuracy: 0.1750
# Epoch 94/300
# 220/220 [==============================] - 93s 424ms/step - loss: 84.8192 - categorical_accuracy: 0.6787 - val_loss: 72.6289 - val_categorical_accuracy: 0.1580
# Epoch 95/300
# 220/220 [==============================] - 94s 425ms/step - loss: 81.8138 - categorical_accuracy: 0.6924 - val_loss: 67.5020 - val_categorical_accuracy: 0.1750
# Epoch 96/300
# 220/220 [==============================] - 93s 421ms/step - loss: 91.2637 - categorical_accuracy: 0.6650 - val_loss: 72.7809 - val_categorical_accuracy: 0.1750
# Epoch 97/300
# 220/220 [==============================] - 94s 426ms/step - loss: 49.8344 - categorical_accuracy: 0.7334 - val_loss: 34.9509 - val_categorical_accuracy: 0.1580
# Epoch 98/300
# 220/220 [==============================] - 94s 428ms/step - loss: 97.3888 - categorical_accuracy: 0.6605 - val_loss: 70.9855 - val_categorical_accuracy: 0.1580
# Epoch 99/300
# 220/220 [==============================] - 94s 426ms/step - loss: 105.9050 - categorical_accuracy: 0.6422 - val_loss: 83.3894 - val_categorical_accuracy: 0.1580
# Epoch 100/300
# 220/220 [==============================] - 94s 427ms/step - loss: 103.6698 - categorical_accuracy: 0.6650 - val_loss: 65.6895 - val_categorical_accuracy: 0.1750
# Epoch 101/300
# 220/220 [==============================] - 93s 421ms/step - loss: 85.2428 - categorical_accuracy: 0.6696 - val_loss: 75.7768 - val_categorical_accuracy: 0.1580
# Epoch 102/300
# 220/220 [==============================] - 95s 431ms/step - loss: 96.1943 - categorical_accuracy: 0.6787 - val_loss: 56.6827 - val_categorical_accuracy: 0.1750
# Epoch 103/300
# 220/220 [==============================] - 94s 426ms/step - loss: 79.5495 - categorical_accuracy: 0.6696 - val_loss: 93.9543 - val_categorical_accuracy: 0.1843
# Epoch 104/300
# 220/220 [==============================] - 94s 428ms/step - loss: 78.8587 - categorical_accuracy: 0.6970 - val_loss: 73.1021 - val_categorical_accuracy: 0.1580
# Epoch 105/300
# 220/220 [==============================] - 94s 427ms/step - loss: 94.9910 - categorical_accuracy: 0.6696 - val_loss: 48.5781 - val_categorical_accuracy: 0.1457
# Epoch 106/300
# 220/220 [==============================] - 94s 429ms/step - loss: 57.8056 - categorical_accuracy: 0.6970 - val_loss: 79.1368 - val_categorical_accuracy: 0.1580
# Epoch 107/300
# 220/220 [==============================] - 93s 424ms/step - loss: 92.0257 - categorical_accuracy: 0.6878 - val_loss: 47.9717 - val_categorical_accuracy: 0.1750
# Epoch 108/300
# 220/220 [==============================] - 93s 421ms/step - loss: 77.7364 - categorical_accuracy: 0.6650 - val_loss: 98.9961 - val_categorical_accuracy: 0.1457
# Epoch 109/300
# 220/220 [==============================] - 94s 427ms/step - loss: 81.8467 - categorical_accuracy: 0.6833 - val_loss: 81.2110 - val_categorical_accuracy: 0.1843
# Epoch 110/300
# 220/220 [==============================] - 95s 431ms/step - loss: 102.8550 - categorical_accuracy: 0.6468 - val_loss: 92.6004 - val_categorical_accuracy: 0.1457
# Epoch 111/300
# 220/220 [==============================] - 94s 428ms/step - loss: 75.9418 - categorical_accuracy: 0.7106 - val_loss: 57.7205 - val_categorical_accuracy: 0.1750
# Epoch 112/300
# 220/220 [==============================] - 93s 423ms/step - loss: 85.1475 - categorical_accuracy: 0.6650 - val_loss: 79.7134 - val_categorical_accuracy: 0.1750
# Epoch 113/300
# 149/220 [===================>..........] - ETA: 28s - loss: 85.7800 - categorical_accuracy: 0.8105
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-1a620428329a> in <module>()
#      88
#      89 if __name__ == '__main__':
# ---> 90     main()
#
# <ipython-input-2-1a620428329a> in main()
#      82         validation_data=validation_dataset,
#      83         callbacks=[
# ---> 84             tf.keras.callbacks.TensorBoard(log_dir),
#      85         ]
#      86     )
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py in _method_wrapper(self, *args, **kwargs)
#     106   def _method_wrapper(self, *args, **kwargs):
#     107     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# --> 108       return method(self, *args, **kwargs)
#     109
#     110     # Running inside `run_distribute_coordinator` already.
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1101               logs = tmp_logs  # No error, now safe to assign to logs.
#    1102               end_step = step + data_handler.step_increment
# -> 1103               callbacks.on_train_batch_end(end_step, logs)
#    1104         epoch_logs = copy.copy(logs)
#    1105
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/callbacks.py in on_train_batch_end(self, batch, logs)
#     438     """
#     439     if self._should_call_train_batch_hooks:
# --> 440       self._call_batch_hook(ModeKeys.TRAIN, 'end', batch, logs=logs)
#     441
#     442   def on_test_batch_begin(self, batch, logs=None):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/callbacks.py in _call_batch_hook(self, mode, hook, batch, logs)
#     287       self._call_batch_begin_hook(mode, batch, logs)
#     288     elif hook == 'end':
# --> 289       self._call_batch_end_hook(mode, batch, logs)
#     290     else:
#     291       raise ValueError('Unrecognized hook: {}'.format(hook))
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/callbacks.py in _call_batch_end_hook(self, mode, batch, logs)
#     307       batch_time = time.time() - self._batch_start_time
#     308
# --> 309     self._call_batch_hook_helper(hook_name, batch, logs)
#     310
#     311     if self._check_timing:
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/callbacks.py in _call_batch_hook_helper(self, hook_name, batch, logs)
#     340       hook = getattr(callback, hook_name)
#     341       if getattr(callback, '_supports_tf_logs', False):
# --> 342         hook(batch, logs)
#     343       else:
#     344         if numpy_logs is None:  # Only convert once.
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/callbacks.py in on_train_batch_end(self, batch, logs)
#     959
#     960   def on_train_batch_end(self, batch, logs=None):
# --> 961     self._batch_update_progbar(batch, logs)
#     962
#     963   def on_test_batch_end(self, batch, logs=None):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/callbacks.py in _batch_update_progbar(self, batch, logs)
#    1014     if self.verbose == 1:
#    1015       # Only block async when verbose = 1.
# -> 1016       logs = tf_utils.to_numpy_or_python_type(logs)
#    1017       self.progbar.update(self.seen, list(logs.items()), finalize=False)
#    1018
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/utils/tf_utils.py in to_numpy_or_python_type(tensors)
#     535     return t  # Don't turn ragged or sparse tensors to NumPy.
#     536
# --> 537   return nest.map_structure(_to_single_numpy_or_python_type, tensors)
#     538
#     539
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/util/nest.py in map_structure(func, *structure, **kwargs)
#     633
#     634   return pack_sequence_as(
# --> 635       structure[0], [func(*x) for x in entries],
#     636       expand_composites=expand_composites)
#     637
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/util/nest.py in <listcomp>(.0)
#     633
#     634   return pack_sequence_as(
# --> 635       structure[0], [func(*x) for x in entries],
#     636       expand_composites=expand_composites)
#     637
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/utils/tf_utils.py in _to_single_numpy_or_python_type(t)
#     531   def _to_single_numpy_or_python_type(t):
#     532     if isinstance(t, ops.Tensor):
# --> 533       x = t.numpy()
#     534       return x.item() if np.ndim(x) == 0 else x
#     535     return t  # Don't turn ragged or sparse tensors to NumPy.
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/ops.py in numpy(self)
#    1061     """
#    1062     # TODO(slebedev): Consider avoiding a copy for non-CPU or remote tensors.
# -> 1063     maybe_arr = self._numpy()  # pylint: disable=protected-access
#    1064     return maybe_arr.copy() if isinstance(maybe_arr, np.ndarray) else maybe_arr
#    1065
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/ops.py in _numpy(self)
#    1027   def _numpy(self):
#    1028     try:
# -> 1029       return self._numpy_internal()
#    1030     except core._NotOkStatusException as e:  # pylint: disable=protected-access
#    1031       six.raise_from(core._status_to_exception(e.code, e.message), None)  # pylint: disable=protected-access
#
# KeyboardInterrupt:

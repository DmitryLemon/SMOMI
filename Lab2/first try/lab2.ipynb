# %%
# !pip3 uninstall tensorflow 
# !pip3 install tensorflow-gpu==1.14
# Out:
# Uninstalling tensorflow-2.2.0:
#   Would remove:
#     /usr/local/bin/estimator_ckpt_converter
#     /usr/local/bin/saved_model_cli
#     /usr/local/bin/tensorboard
#     /usr/local/bin/tf_upgrade_v2
#     /usr/local/bin/tflite_convert
#     /usr/local/bin/toco
#     /usr/local/bin/toco_from_protos
#     /usr/local/lib/python3.6/dist-packages/tensorflow-2.2.0.dist-info/*
#     /usr/local/lib/python3.6/dist-packages/tensorflow/*
# Proceed (y/n)? y
#   Successfully uninstalled tensorflow-2.2.0
# Collecting tensorflow-gpu==1.14
#   Downloading https://files.pythonhosted.org/packages/76/04/43153bfdfcf6c9a4c38ecdb971ca9a75b9a791bb69a764d652c359aca504/tensorflow_gpu-1.14.0-cp36-cp36m-manylinux1_x86_64.whl (377.0MB)
#      |████████████████████████████████| 377.0MB 43kB/s
# Collecting tensorflow-estimator<1.15.0rc0,>=1.14.0rc0
#   Downloading https://files.pythonhosted.org/packages/3c/d5/21860a5b11caf0678fbc8319341b0ae21a07156911132e0e71bffed0510d/tensorflow_estimator-1.14.0-py2.py3-none-any.whl (488kB)
#      |████████████████████████████████| 491kB 81kB/s
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.14) (1.12.1)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.14) (3.10.0)
# Requirement already satisfied: keras-applications>=1.0.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.14) (1.0.8)
# Collecting tensorboard<1.15.0,>=1.14.0
#   Downloading https://files.pythonhosted.org/packages/91/2d/2ed263449a078cd9c8a9ba50ebd50123adf1f8cfbea1492f9084169b89d9/tensorboard-1.14.0-py3-none-any.whl (3.1MB)
#      |████████████████████████████████| 3.2MB 38.2MB/s
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.14) (0.9.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.14) (1.1.0)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.14) (0.8.1)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.14) (1.29.0)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.14) (1.1.2)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.14) (0.34.2)
# Requirement already satisfied: numpy<2.0,>=1.14.5 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.14) (1.18.5)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.14) (1.12.0)
# Requirement already satisfied: google-pasta>=0.1.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.14) (0.2.0)
# Requirement already satisfied: gast>=0.2.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.14) (0.3.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.6.1->tensorflow-gpu==1.14) (47.3.1)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras-applications>=1.0.6->tensorflow-gpu==1.14) (2.10.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.15.0,>=1.14.0->tensorflow-gpu==1.14) (3.2.2)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.15.0,>=1.14.0->tensorflow-gpu==1.14) (1.0.1)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from markdown>=2.6.8->tensorboard<1.15.0,>=1.14.0->tensorflow-gpu==1.14) (1.6.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard<1.15.0,>=1.14.0->tensorflow-gpu==1.14) (3.1.0)
# Installing collected packages: tensorflow-estimator, tensorboard, tensorflow-gpu
#   Found existing installation: tensorflow-estimator 2.2.0
#     Uninstalling tensorflow-estimator-2.2.0:
#       Successfully uninstalled tensorflow-estimator-2.2.0
#   Found existing installation: tensorboard 2.2.2
#     Uninstalling tensorboard-2.2.2:
#       Successfully uninstalled tensorboard-2.2.2
# Successfully installed tensorboard-1.14.0 tensorflow-estimator-1.14.0 tensorflow-gpu-1.14.0

# %%
import os
os.chdir("/content/drive/My Drive/SMOMI/Laba2/shag1")
# !ls
# Out:
# logs  xray

# %%
!

# %%
__author__ = 'Alexander Soroka, soroka.a.m@gmail.com'
__copyright__ = """Copyright 2020 Alexander Soroka"""


import argparse
import glob
import numpy as np
import tensorflow as tf
import time
from tensorflow.python import keras as keras
from tensorflow.python.keras.callbacks import LearningRateScheduler

LOG_DIR = 'logs'
SHUFFLE_BUFFER = 10
BATCH_SIZE = 8
NUM_CLASSES = 2
PARALLEL_CALLS=4
RESIZE_TO = 224
TRAINSET_SIZE = 5216
VALSET_SIZE=624


def parse_proto_example(proto):
    keys_to_features = {
        'image/encoded': tf.FixedLenFeature((), tf.string, default_value=''),
        'image/class/label': tf.FixedLenFeature([], tf.int64, default_value=tf.zeros([], dtype=tf.int64))
    }
    example = tf.parse_single_example(proto, keys_to_features)
    example['image'] = tf.image.decode_jpeg(example['image/encoded'], channels=3)
    example['image'] = tf.image.convert_image_dtype(example['image'], dtype=tf.float32)
    example['image'] = tf.image.resize_images(example['image'], tf.constant([RESIZE_TO, RESIZE_TO]))
    return example['image'], example['image/class/label']


def normalize(image, label):
    return tf.image.per_image_standardization(image), label

def resize(image, label):
    return tf.image.resize_images(image, tf.constant([RESIZE_TO, RESIZE_TO])), label

def create_dataset(filenames, batch_size):
    """Create dataset from tfrecords file
    :tfrecords_files: Mask to collect tfrecords file of dataset
    :returns: tf.data.Dataset
    """
    return tf.data.TFRecordDataset(filenames)\
        .map(parse_proto_example)\
        .map(resize)\
        .map(normalize)\
        .shuffle(buffer_size=5 * batch_size)\
        .repeat()\
        .batch(batch_size)\
        .prefetch(2 * batch_size)


class Validation(tf.keras.callbacks.Callback):
    def __init__(self, log_dir, validation_files, batch_size):
        self.log_dir = log_dir
        self.validation_files = validation_files
        self.batch_size = batch_size

    def on_epoch_end(self, epoch, logs=None):
        print('The average loss for epoch {} is {:7.2f} '.format(
            epoch, logs['loss']
        ))

        validation_dataset = create_dataset(self.validation_files, self.batch_size)
        validation_images, validation_labels = validation_dataset.make_one_shot_iterator().get_next()
        validation_labels = tf.one_hot(validation_labels, NUM_CLASSES)

        result = self.model.evaluate(
            validation_images,
            validation_labels,
            steps=int(np.ceil(VALSET_SIZE / float(BATCH_SIZE)))
        )
        callback = tf.keras.callbacks.TensorBoard(log_dir=self.log_dir, update_freq='epoch', batch_size=self.batch_size)

        callback.set_model(self.model)
        callback.on_epoch_end(epoch, {
            'val_' + self.model.metrics_names[i]: v for i, v in enumerate(result)
        })


def build_model():
    return tf.keras.models.Sequential([
        tf.keras.layers.Input(shape=(224,224,3)),
        tf.keras.layers.Conv2D(filters=8, kernel_size=3),
        tf.keras.layers.MaxPool2D(),
        tf.keras.layers.Conv2D(filters=16, kernel_size=3),
        tf.keras.layers.MaxPool2D(),
        tf.keras.layers.Conv2D(filters=32, kernel_size=3),
        tf.keras.layers.MaxPool2D(),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(NUM_CLASSES, activation=tf.keras.activations.softmax)
    ])



def main():
    train_path = './xray/train*'
    test_path = './xray/test*'

    train_dataset = create_dataset(glob.glob(train_path), BATCH_SIZE)
    train_images, train_labels = train_dataset.make_one_shot_iterator().get_next()
    train_labels = tf.one_hot(train_labels, NUM_CLASSES)

    model = build_model()

    model.compile(
        optimizer=keras.optimizers.sgd(lr=0.000001, momentum=0.9),
        loss=tf.keras.losses.categorical_crossentropy,
        metrics=[tf.keras.metrics.categorical_accuracy],
        target_tensors=[train_labels]
    )

    log_dir='{}/xray-{}'.format(LOG_DIR, time.time())
    model.fit(
        (train_images, train_labels),
        epochs=100,
        steps_per_epoch=int(np.ceil(TRAINSET_SIZE / float(BATCH_SIZE))),
        callbacks=[
            tf.keras.callbacks.TensorBoard(log_dir),
            Validation(log_dir, validation_files=glob.glob(test_path), batch_size=BATCH_SIZE)
        ]
    )


if __name__ == '__main__':
    main()
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/image_ops_impl.py:1514: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# WARNING:tensorflow:From <ipython-input-2-c8014eaf4a3f>:97: DatasetV1.make_one_shot_iterator (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `for ... in dataset:` to iterate over a dataset. If using `tf.estimator`, return the `Dataset` object directly from your input function. As a last resort, you can use `tf.compat.v1.data.make_one_shot_iterator(dataset)`.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Epoch 1/100
# 651/652 [============================>.] - ETA: 0s - loss: 0.0801 - categorical_accuracy: 0.5394The average loss for epoch 0 is    0.08
# 78/78 [==============================] - 35s 451ms/step - loss: 0.0991 - categorical_accuracy: 0.3894
# 652/652 [==============================] - 171s 263ms/step - loss: 0.0800 - categorical_accuracy: 0.5395
# Epoch 2/100
# 651/652 [============================>.] - ETA: 0s - loss: nan - categorical_accuracy: 0.6496The average loss for epoch 1 is     nan
# 78/78 [==============================] - 25s 316ms/step - loss: nan - categorical_accuracy: 0.3301
# 652/652 [==============================] - 127s 195ms/step - loss: nan - categorical_accuracy: 0.6486
# Epoch 3/100
# 651/652 [============================>.] - ETA: 0s - loss: nan - categorical_accuracy: 0.7425The average loss for epoch 2 is     nan
# 78/78 [==============================] - 19s 246ms/step - loss: nan - categorical_accuracy: 1.0000
# 652/652 [==============================] - 122s 188ms/step - loss: nan - categorical_accuracy: 0.7429
# Epoch 4/100
# 651/652 [============================>.] - ETA: 0s - loss: nan - categorical_accuracy: 0.7425The average loss for epoch 3 is     nan
# 78/78 [==============================] - 29s 374ms/step - loss: nan - categorical_accuracy: 0.3413
# 652/652 [==============================] - 130s 199ms/step - loss: nan - categorical_accuracy: 0.7429
# Epoch 5/100
# 651/652 [============================>.] - ETA: 0s - loss: nan - categorical_accuracy: 0.7440The average loss for epoch 4 is     nan
# 78/78 [==============================] - 21s 266ms/step - loss: nan - categorical_accuracy: 0.8221
# 652/652 [==============================] - 124s 190ms/step - loss: nan - categorical_accuracy: 0.7429
# Epoch 6/100
# 651/652 [============================>.] - ETA: 0s - loss: nan - categorical_accuracy: 0.7425The average loss for epoch 5 is     nan
# 78/78 [==============================] - 20s 258ms/step - loss: nan - categorical_accuracy: 0.8494
# 652/652 [==============================] - 120s 184ms/step - loss: nan - categorical_accuracy: 0.7429
# Epoch 7/100
# 651/652 [============================>.] - ETA: 0s - loss: nan - categorical_accuracy: 0.7440The average loss for epoch 6 is     nan
# 78/78 [==============================] - 22s 278ms/step - loss: nan - categorical_accuracy: 0.6731
# 652/652 [==============================] - 125s 192ms/step - loss: nan - categorical_accuracy: 0.7429
# Epoch 8/100
# 651/652 [============================>.] - ETA: 0s - loss: nan - categorical_accuracy: 0.7425The average loss for epoch 7 is     nan
# 78/78 [==============================] - 19s 247ms/step - loss: nan - categorical_accuracy: 1.0000
# 652/652 [==============================] - 122s 188ms/step - loss: nan - categorical_accuracy: 0.7429
# Epoch 9/100
# 651/652 [============================>.] - ETA: 0s - loss: nan - categorical_accuracy: 0.7425The average loss for epoch 8 is     nan
# 78/78 [==============================] - 19s 245ms/step - loss: nan - categorical_accuracy: 1.0000
# 652/652 [==============================] - 119s 183ms/step - loss: nan - categorical_accuracy: 0.7429
# Epoch 10/100
# 651/652 [============================>.] - ETA: 0s - loss: nan - categorical_accuracy: 0.7425The average loss for epoch 9 is     nan
# 78/78 [==============================] - 28s 354ms/step - loss: nan - categorical_accuracy: 0.2003
# 652/652 [==============================] - 128s 196ms/step - loss: nan - categorical_accuracy: 0.7429
# Epoch 11/100
# 651/652 [============================>.] - ETA: 0s - loss: nan - categorical_accuracy: 0.7439The average loss for epoch 10 is     nan
# 78/78 [==============================] - 19s 250ms/step - loss: nan - categorical_accuracy: 0.9647
# 652/652 [==============================] - 121s 185ms/step - loss: nan - categorical_accuracy: 0.7429
# Epoch 12/100
# 651/652 [============================>.] - ETA: 0s - loss: nan - categorical_accuracy: 0.7425The average loss for epoch 11 is     nan
# 78/78 [==============================] - 23s 289ms/step - loss: nan - categorical_accuracy: 0.7003
# 652/652 [==============================] - 126s 193ms/step - loss: nan - categorical_accuracy: 0.7429
# Epoch 13/100
# 651/652 [============================>.] - ETA: 0s - loss: nan - categorical_accuracy: 0.7440The average loss for epoch 12 is     nan
# 78/78 [==============================] - 26s 332ms/step - loss: nan - categorical_accuracy: 0.4631
# 652/652 [==============================] - 131s 200ms/step - loss: nan - categorical_accuracy: 0.7429
# Epoch 14/100
# 651/652 [============================>.] - ETA: 0s - loss: nan - categorical_accuracy: 0.7425The average loss for epoch 13 is     nan
# 78/78 [==============================] - 20s 262ms/step - loss: nan - categorical_accuracy: 1.0000
# 652/652 [==============================] - 123s 189ms/step - loss: nan - categorical_accuracy: 0.7429
# Epoch 15/100
# 651/652 [============================>.] - ETA: 0s - loss: nan - categorical_accuracy: 0.7425The average loss for epoch 14 is     nan
# 78/78 [==============================] - 23s 301ms/step - loss: nan - categorical_accuracy: 0.5224
# 652/652 [==============================] - 126s 194ms/step - loss: nan - categorical_accuracy: 0.7429
# Epoch 16/100
# 651/652 [============================>.] - ETA: 0s - loss: nan - categorical_accuracy: 0.7425The average loss for epoch 15 is     nan
# 78/78 [==============================] - 19s 249ms/step - loss: nan - categorical_accuracy: 1.0000
# 652/652 [==============================] - 129s 197ms/step - loss: nan - categorical_accuracy: 0.7429
# Epoch 17/100
# 651/652 [============================>.] - ETA: 0s - loss: nan - categorical_accuracy: 0.7425The average loss for epoch 16 is     nan
# 78/78 [==============================] - 19s 238ms/step - loss: nan - categorical_accuracy: 1.0000
# 652/652 [==============================] - 116s 179ms/step - loss: nan - categorical_accuracy: 0.7429
# Epoch 18/100
# 651/652 [============================>.] - ETA: 0s - loss: nan - categorical_accuracy: 0.7425The average loss for epoch 17 is     nan
# 78/78 [==============================] - 24s 310ms/step - loss: nan - categorical_accuracy: 0.5529
# 652/652 [==============================] - 121s 186ms/step - loss: nan - categorical_accuracy: 0.7429
# Epoch 19/100
# 651/652 [============================>.] - ETA: 0s - loss: nan - categorical_accuracy: 0.7440The average loss for epoch 18 is     nan
# 78/78 [==============================] - 20s 261ms/step - loss: nan - categorical_accuracy: 0.6122
# 652/652 [==============================] - 117s 180ms/step - loss: nan - categorical_accuracy: 0.7429
# Epoch 20/100
# 651/652 [============================>.] - ETA: 0s - loss: nan - categorical_accuracy: 0.7425The average loss for epoch 19 is     nan
# 78/78 [==============================] - 19s 243ms/step - loss: nan - categorical_accuracy: 1.0000
# 652/652 [==============================] - 119s 182ms/step - loss: nan - categorical_accuracy: 0.7429
# Epoch 21/100
# 651/652 [============================>.] - ETA: 0s - loss: nan - categorical_accuracy: 0.7425The average loss for epoch 20 is     nan
# 78/78 [==============================] - 30s 382ms/step - loss: nan - categorical_accuracy: 0.1667
# 652/652 [==============================] - 131s 200ms/step - loss: nan - categorical_accuracy: 0.7429
# Epoch 22/100
# 651/652 [============================>.] - ETA: 0s - loss: nan - categorical_accuracy: 0.7427The average loss for epoch 21 is     nan
# 78/78 [==============================] - 19s 249ms/step - loss: nan - categorical_accuracy: 0.9968
# 652/652 [==============================] - 116s 177ms/step - loss: nan - categorical_accuracy: 0.7429
# Epoch 23/100
# 651/652 [============================>.] - ETA: 0s - loss: nan - categorical_accuracy: 0.7425The average loss for epoch 22 is     nan
# 78/78 [==============================] - 24s 310ms/step - loss: nan - categorical_accuracy: 0.5705
# 652/652 [==============================] - 125s 191ms/step - loss: nan - categorical_accuracy: 0.7429
# Epoch 24/100
# 651/652 [============================>.] - ETA: 0s - loss: nan - categorical_accuracy: 0.7437The average loss for epoch 23 is     nan
# 78/78 [==============================] - 19s 245ms/step - loss: nan - categorical_accuracy: 0.9535
# 652/652 [==============================] - 123s 189ms/step - loss: nan - categorical_accuracy: 0.7427
# Epoch 25/100
# 651/652 [============================>.] - ETA: 0s - loss: nan - categorical_accuracy: 0.7425The average loss for epoch 24 is     nan
# 78/78 [==============================] - 19s 243ms/step - loss: nan - categorical_accuracy: 1.0000
# 652/652 [==============================] - 117s 179ms/step - loss: nan - categorical_accuracy: 0.7429
# Epoch 26/100
# 651/652 [============================>.] - ETA: 0s - loss: nan - categorical_accuracy: 0.7425The average loss for epoch 25 is     nan
# 78/78 [==============================] - 20s 260ms/step - loss: nan - categorical_accuracy: 0.9071
# 652/652 [==============================] - 120s 184ms/step - loss: nan - categorical_accuracy: 0.7429
# Epoch 27/100
# 651/652 [============================>.] - ETA: 0s - loss: nan - categorical_accuracy: 0.7440The average loss for epoch 26 is     nan
# 78/78 [==============================] - 26s 329ms/step - loss: nan - categorical_accuracy: 0.2596
# 652/652 [==============================] - 125s 192ms/step - loss: nan - categorical_accuracy: 0.7429
# Epoch 28/100
# 651/652 [============================>.] - ETA: 0s - loss: nan - categorical_accuracy: 0.7423The average loss for epoch 27 is     nan
# 78/78 [==============================] - 19s 244ms/step - loss: nan - categorical_accuracy: 1.0000
# 652/652 [==============================] - 121s 186ms/step - loss: nan - categorical_accuracy: 0.7427
# Epoch 29/100
# 651/652 [============================>.] - ETA: 0s - loss: nan - categorical_accuracy: 0.7425The average loss for epoch 28 is     nan
# 78/78 [==============================] - 27s 341ms/step - loss: nan - categorical_accuracy: 0.4183
# 652/652 [==============================] - 129s 198ms/step - loss: nan - categorical_accuracy: 0.7429
# Epoch 30/100
# 651/652 [============================>.] - ETA: 0s - loss: nan - categorical_accuracy: 0.7440The average loss for epoch 29 is     nan
# 78/78 [==============================] - 22s 278ms/step - loss: nan - categorical_accuracy: 0.7452
# 652/652 [==============================] - 123s 189ms/step - loss: nan - categorical_accuracy: 0.7429
# Epoch 31/100
# 651/652 [============================>.] - ETA: 0s - loss: nan - categorical_accuracy: 0.7425The average loss for epoch 30 is     nan
# 78/78 [==============================] - 19s 248ms/step - loss: nan - categorical_accuracy: 0.9231
# 652/652 [==============================] - 119s 183ms/step - loss: nan - categorical_accuracy: 0.7429
# Epoch 32/100
# 651/652 [============================>.] - ETA: 0s - loss: nan - categorical_accuracy: 0.7435The average loss for epoch 31 is     nan
# 78/78 [==============================] - 20s 262ms/step - loss: nan - categorical_accuracy: 0.6042
# 652/652 [==============================] - 117s 180ms/step - loss: nan - categorical_accuracy: 0.7423
# Epoch 33/100
# 651/652 [============================>.] - ETA: 0s - loss: nan - categorical_accuracy: 0.7425The average loss for epoch 32 is     nan
# 78/78 [==============================] - 20s 251ms/step - loss: nan - categorical_accuracy: 1.0000
# 652/652 [==============================] - 121s 185ms/step - loss: nan - categorical_accuracy: 0.7429
# Epoch 34/100
# 651/652 [============================>.] - ETA: 0s - loss: nan - categorical_accuracy: 0.7425The average loss for epoch 33 is     nan
# 78/78 [==============================] - 20s 251ms/step - loss: nan - categorical_accuracy: 1.0000
# 652/652 [==============================] - 122s 188ms/step - loss: nan - categorical_accuracy: 0.7429
# Epoch 35/100
# 651/652 [============================>.] - ETA: 0s - loss: nan - categorical_accuracy: 0.7425The average loss for epoch 34 is     nan
# 78/78 [==============================] - 27s 345ms/step - loss: nan - categorical_accuracy: 0.2708
# 652/652 [==============================] - 129s 197ms/step - loss: nan - categorical_accuracy: 0.7429
# Epoch 36/100
# 651/652 [============================>.] - ETA: 0s - loss: nan - categorical_accuracy: 0.7440The average loss for epoch 35 is     nan
# 78/78 [==============================] - 20s 254ms/step - loss: nan - categorical_accuracy: 0.8942
# 652/652 [==============================] - 118s 180ms/step - loss: nan - categorical_accuracy: 0.7429
# Epoch 37/100
# 651/652 [============================>.] - ETA: 0s - loss: nan - categorical_accuracy: 0.7425The average loss for epoch 36 is     nan
# 78/78 [==============================] - 21s 267ms/step - loss: nan - categorical_accuracy: 0.7772
# 652/652 [==============================] - 123s 189ms/step - loss: nan - categorical_accuracy: 0.7429
# Epoch 38/100
# 651/652 [============================>.] - ETA: 0s - loss: nan - categorical_accuracy: 0.7439The average loss for epoch 37 is     nan
# 78/78 [==============================] - 29s 370ms/step - loss: nan - categorical_accuracy: 0.3878
# 652/652 [==============================] - 138s 211ms/step - loss: nan - categorical_accuracy: 0.7427
# Epoch 39/100
# 651/652 [============================>.] - ETA: 0s - loss: nan - categorical_accuracy: 0.7425The average loss for epoch 38 is     nan
# 78/78 [==============================] - 20s 258ms/step - loss: nan - categorical_accuracy: 1.0000
# 652/652 [==============================] - 130s 199ms/step - loss: nan - categorical_accuracy: 0.7429
# Epoch 40/100
# 651/652 [============================>.] - ETA: 0s - loss: nan - categorical_accuracy: 0.7425The average loss for epoch 39 is     nan
# 78/78 [==============================] - 25s 317ms/step - loss: nan - categorical_accuracy: 0.5224
# 652/652 [==============================] - 131s 201ms/step - loss: nan - categorical_accuracy: 0.7429
# Epoch 41/100
# 651/652 [============================>.] - ETA: 0s - loss: nan - categorical_accuracy: 0.7425The average loss for epoch 40 is     nan
# 78/78 [==============================] - 20s 260ms/step - loss: nan - categorical_accuracy: 1.0000
# 652/652 [==============================] - 131s 202ms/step - loss: nan - categorical_accuracy: 0.7429
# Epoch 42/100
# 651/652 [============================>.] - ETA: 0s - loss: nan - categorical_accuracy: 0.7425The average loss for epoch 41 is     nan
# 78/78 [==============================] - 21s 265ms/step - loss: nan - categorical_accuracy: 1.0000
# 652/652 [==============================] - 129s 198ms/step - loss: nan - categorical_accuracy: 0.7429
# Epoch 43/100
# 651/652 [============================>.] - ETA: 0s - loss: nan - categorical_accuracy: 0.7425The average loss for epoch 42 is     nan
# 78/78 [==============================] - 24s 313ms/step - loss: nan - categorical_accuracy: 0.6298
# 652/652 [==============================] - 133s 204ms/step - loss: nan - categorical_accuracy: 0.7429
# Epoch 44/100
# 651/652 [============================>.] - ETA: 0s - loss: nan - categorical_accuracy: 0.7440The average loss for epoch 43 is     nan
# 78/78 [==============================] - 23s 293ms/step - loss: nan - categorical_accuracy: 0.5353
# 652/652 [==============================] - 131s 201ms/step - loss: nan - categorical_accuracy: 0.7429
# Epoch 45/100
# 651/652 [============================>.] - ETA: 0s - loss: nan - categorical_accuracy: 0.7425The average loss for epoch 44 is     nan
# 78/78 [==============================] - 20s 253ms/step - loss: nan - categorical_accuracy: 1.0000
# 652/652 [==============================] - 130s 199ms/step - loss: nan - categorical_accuracy: 0.7429
# Epoch 46/100
# 651/652 [============================>.] - ETA: 0s - loss: nan - categorical_accuracy: 0.7425The average loss for epoch 45 is     nan
# 78/78 [==============================] - 33s 422ms/step - loss: nan - categorical_accuracy: 0.1843
# 652/652 [==============================] - 136s 209ms/step - loss: nan - categorical_accuracy: 0.7429
# Epoch 47/100
# 651/652 [============================>.] - ETA: 0s - loss: nan - categorical_accuracy: 0.7423The average loss for epoch 46 is     nan
# 78/78 [==============================] - 20s 262ms/step - loss: nan - categorical_accuracy: 0.9856
# 652/652 [==============================] - 129s 198ms/step - loss: nan - categorical_accuracy: 0.7421
# Epoch 48/100
# 651/652 [============================>.] - ETA: 0s - loss: nan - categorical_accuracy: 0.7425The average loss for epoch 47 is     nan
# 78/78 [==============================] - 24s 302ms/step - loss: nan - categorical_accuracy: 0.6458
# 652/652 [==============================] - 128s 197ms/step - loss: nan - categorical_accuracy: 0.7429
# Epoch 49/100
# 651/652 [============================>.] - ETA: 0s - loss: nan - categorical_accuracy: 0.7440The average loss for epoch 48 is     nan
# 78/78 [==============================] - 21s 264ms/step - loss: nan - categorical_accuracy: 0.8766
# 652/652 [==============================] - 126s 194ms/step - loss: nan - categorical_accuracy: 0.7429
# Epoch 50/100
# 651/652 [============================>.] - ETA: 0s - loss: nan - categorical_accuracy: 0.7425The average loss for epoch 49 is     nan
# 78/78 [==============================] - 20s 260ms/step - loss: nan - categorical_accuracy: 1.0000
# 652/652 [==============================] - 125s 191ms/step - loss: nan - categorical_accuracy: 0.7429
# Epoch 51/100
# 651/652 [============================>.] - ETA: 0s - loss: nan - categorical_accuracy: 0.7425The average loss for epoch 50 is     nan
# 78/78 [==============================] - 21s 268ms/step - loss: nan - categorical_accuracy: 0.9744
# 652/652 [==============================] - 127s 195ms/step - loss: nan - categorical_accuracy: 0.7429
# Epoch 52/100
# 651/652 [============================>.] - ETA: 0s - loss: nan - categorical_accuracy: 0.7427The average loss for epoch 51 is     nan
# 78/78 [==============================] - 28s 357ms/step - loss: nan - categorical_accuracy: 0.1939
# 652/652 [==============================] - 135s 206ms/step - loss: nan - categorical_accuracy: 0.7427
# Epoch 53/100
# 651/652 [============================>.] - ETA: 0s - loss: nan - categorical_accuracy: 0.7423The average loss for epoch 52 is     nan
# 78/78 [==============================] - 20s 253ms/step - loss: nan - categorical_accuracy: 1.0000
# 652/652 [==============================] - 127s 194ms/step - loss: nan - categorical_accuracy: 0.7427
# Epoch 54/100
# 651/652 [============================>.] - ETA: 0s - loss: nan - categorical_accuracy: 0.7425The average loss for epoch 53 is     nan
# 78/78 [==============================] - 27s 345ms/step - loss: nan - categorical_accuracy: 0.4952
# 652/652 [==============================] - 129s 198ms/step - loss: nan - categorical_accuracy: 0.7429
# Epoch 55/100
# 651/652 [============================>.] - ETA: 0s - loss: nan - categorical_accuracy: 0.7440The average loss for epoch 54 is     nan
# 78/78 [==============================] - 24s 311ms/step - loss: nan - categorical_accuracy: 0.6683
# 652/652 [==============================] - 132s 202ms/step - loss: nan - categorical_accuracy: 0.7429
# Epoch 56/100
# 651/652 [============================>.] - ETA: 0s - loss: nan - categorical_accuracy: 0.7425The average loss for epoch 55 is     nan
# 78/78 [==============================] - 21s 274ms/step - loss: nan - categorical_accuracy: 0.9760
# 652/652 [==============================] - 130s 199ms/step - loss: nan - categorical_accuracy: 0.7429
# Epoch 57/100
# 651/652 [============================>.] - ETA: 0s - loss: nan - categorical_accuracy: 0.7435The average loss for epoch 56 is     nan
# 78/78 [==============================] - 23s 295ms/step - loss: nan - categorical_accuracy: 0.5497
# 652/652 [==============================] - 129s 199ms/step - loss: nan - categorical_accuracy: 0.7425
# Epoch 58/100
# 651/652 [============================>.] - ETA: 0s - loss: nan - categorical_accuracy: 0.7425The average loss for epoch 57 is     nan
# 78/78 [==============================] - 20s 251ms/step - loss: nan - categorical_accuracy: 1.0000
# 652/652 [==============================] - 124s 190ms/step - loss: nan - categorical_accuracy: 0.7429
# Epoch 59/100
# 651/652 [============================>.] - ETA: 0s - loss: nan - categorical_accuracy: 0.7425The average loss for epoch 58 is     nan
# 78/78 [==============================] - 19s 249ms/step - loss: nan - categorical_accuracy: 1.0000
# 652/652 [==============================] - 121s 186ms/step - loss: nan - categorical_accuracy: 0.7429
# Epoch 60/100
# 651/652 [============================>.] - ETA: 0s - loss: nan - categorical_accuracy: 0.7425The average loss for epoch 59 is     nan
# 78/78 [==============================] - 28s 359ms/step - loss: nan - categorical_accuracy: 0.3478
# 652/652 [==============================] - 132s 203ms/step - loss: nan - categorical_accuracy: 0.7429
# Epoch 61/100
# 651/652 [============================>.] - ETA: 0s - loss: nan - categorical_accuracy: 0.7440The average loss for epoch 60 is     nan
# 78/78 [==============================] - 21s 265ms/step - loss: nan - categorical_accuracy: 0.8173
# 652/652 [==============================] - 125s 191ms/step - loss: nan - categorical_accuracy: 0.7429
# Epoch 62/100
# 651/652 [============================>.] - ETA: 0s - loss: nan - categorical_accuracy: 0.7425The average loss for epoch 61 is     nan
# 78/78 [==============================] - 22s 278ms/step - loss: nan - categorical_accuracy: 0.8526
# 652/652 [==============================] - 130s 199ms/step - loss: nan - categorical_accuracy: 0.7429
# Epoch 63/100
# 651/652 [============================>.] - ETA: 0s - loss: nan - categorical_accuracy: 0.7440The average loss for epoch 62 is     nan
# 78/78 [==============================] - 30s 386ms/step - loss: nan - categorical_accuracy: 0.3109
# 652/652 [==============================] - 137s 210ms/step - loss: nan - categorical_accuracy: 0.7429
# Epoch 64/100
# 651/652 [============================>.] - ETA: 0s - loss: nan - categorical_accuracy: 0.7425The average loss for epoch 63 is     nan
# 78/78 [==============================] - 21s 265ms/step - loss: nan - categorical_accuracy: 1.0000
# 652/652 [==============================] - 130s 200ms/step - loss: nan - categorical_accuracy: 0.7429
# Epoch 65/100
# 651/652 [============================>.] - ETA: 0s - loss: nan - categorical_accuracy: 0.7425The average loss for epoch 64 is     nan
# 78/78 [==============================] - 25s 327ms/step - loss: nan - categorical_accuracy: 0.5256
# 652/652 [==============================] - 132s 202ms/step - loss: nan - categorical_accuracy: 0.7429
# Epoch 66/100
# 651/652 [============================>.] - ETA: 0s - loss: nan - categorical_accuracy: 0.7429The average loss for epoch 65 is     nan
# 78/78 [==============================] - 21s 270ms/step - loss: nan - categorical_accuracy: 0.9952
# 652/652 [==============================] - 129s 197ms/step - loss: nan - categorical_accuracy: 0.7431
# Epoch 67/100
# 651/652 [============================>.] - ETA: 0s - loss: nan - categorical_accuracy: 0.7425The average loss for epoch 66 is     nan
# 78/78 [==============================] - 21s 270ms/step - loss: nan - categorical_accuracy: 1.0000
# 652/652 [==============================] - 127s 195ms/step - loss: nan - categorical_accuracy: 0.7429
# Epoch 68/100
# 651/652 [============================>.] - ETA: 0s - loss: nan - categorical_accuracy: 0.7425The average loss for epoch 67 is     nan
# 78/78 [==============================] - 23s 294ms/step - loss: nan - categorical_accuracy: 0.7067
# 652/652 [==============================] - 129s 198ms/step - loss: nan - categorical_accuracy: 0.7429
# Epoch 69/100
# 651/652 [============================>.] - ETA: 0s - loss: nan - categorical_accuracy: 0.7440The average loss for epoch 68 is     nan
# 78/78 [==============================] - 25s 314ms/step - loss: nan - categorical_accuracy: 0.4583
# 652/652 [==============================] - 137s 210ms/step - loss: nan - categorical_accuracy: 0.7429
# Epoch 70/100
# 651/652 [============================>.] - ETA: 0s - loss: nan - categorical_accuracy: 0.7425The average loss for epoch 69 is     nan
# 78/78 [==============================] - 21s 264ms/step - loss: nan - categorical_accuracy: 1.0000
# 652/652 [==============================] - 132s 203ms/step - loss: nan - categorical_accuracy: 0.7429
# Epoch 71/100
# 651/652 [============================>.] - ETA: 0s - loss: nan - categorical_accuracy: 0.7425The average loss for epoch 70 is     nan
# 78/78 [==============================] - 32s 406ms/step - loss: nan - categorical_accuracy: 0.2131
# 652/652 [==============================] - 134s 206ms/step - loss: nan - categorical_accuracy: 0.7429
# Epoch 72/100
# 651/652 [============================>.] - ETA: 0s - loss: nan - categorical_accuracy: 0.7440The average loss for epoch 71 is     nan
# 78/78 [==============================] - 20s 252ms/step - loss: nan - categorical_accuracy: 0.9487
# 652/652 [==============================] - 119s 183ms/step - loss: nan - categorical_accuracy: 0.7431
# Epoch 73/100
# 651/652 [============================>.] - ETA: 0s - loss: nan - categorical_accuracy: 0.7425The average loss for epoch 72 is     nan
# 78/78 [==============================] - 22s 281ms/step - loss: nan - categorical_accuracy: 0.7212
# 652/652 [==============================] - 124s 190ms/step - loss: nan - categorical_accuracy: 0.7429
# Epoch 74/100
# 651/652 [============================>.] - ETA: 0s - loss: nan - categorical_accuracy: 0.7442The average loss for epoch 73 is     nan
# 78/78 [==============================] - 20s 262ms/step - loss: nan - categorical_accuracy: 0.7997
# 652/652 [==============================] - 122s 187ms/step - loss: nan - categorical_accuracy: 0.7431
# Epoch 75/100
# 651/652 [============================>.] - ETA: 0s - loss: nan - categorical_accuracy: 0.7425The average loss for epoch 74 is     nan
# 78/78 [==============================] - 19s 249ms/step - loss: nan - categorical_accuracy: 1.0000
# 652/652 [==============================] - 120s 184ms/step - loss: nan - categorical_accuracy: 0.7429
# Epoch 76/100
# 651/652 [============================>.] - ETA: 0s - loss: nan - categorical_accuracy: 0.7425The average loss for epoch 75 is     nan
# 78/78 [==============================] - 20s 256ms/step - loss: nan - categorical_accuracy: 1.0000
# 652/652 [==============================] - 122s 187ms/step - loss: nan - categorical_accuracy: 0.7429
# Epoch 77/100
# 651/652 [============================>.] - ETA: 0s - loss: nan - categorical_accuracy: 0.7425The average loss for epoch 76 is     nan
# 78/78 [==============================] - 29s 366ms/step - loss: nan - categorical_accuracy: 0.1667
# 652/652 [==============================] - 131s 201ms/step - loss: nan - categorical_accuracy: 0.7429
# Epoch 78/100
# 651/652 [============================>.] - ETA: 0s - loss: nan - categorical_accuracy: 0.7429The average loss for epoch 77 is     nan
# 78/78 [==============================] - 20s 257ms/step - loss: nan - categorical_accuracy: 0.9952
# 652/652 [==============================] - 124s 190ms/step - loss: nan - categorical_accuracy: 0.7433
# Epoch 79/100
# 651/652 [============================>.] - ETA: 0s - loss: nan - categorical_accuracy: 0.7425The average loss for epoch 78 is     nan
# 78/78 [==============================] - 24s 313ms/step - loss: nan - categorical_accuracy: 0.5721
# 652/652 [==============================] - 128s 196ms/step - loss: nan - categorical_accuracy: 0.7429
# Epoch 80/100
# 651/652 [============================>.] - ETA: 0s - loss: nan - categorical_accuracy: 0.7440The average loss for epoch 79 is     nan
# 78/78 [==============================] - 25s 318ms/step - loss: nan - categorical_accuracy: 0.5913
# 652/652 [==============================] - 127s 195ms/step - loss: nan - categorical_accuracy: 0.7429
# Epoch 81/100
# 651/652 [============================>.] - ETA: 0s - loss: nan - categorical_accuracy: 0.7425The average loss for epoch 80 is     nan
# 78/78 [==============================] - 20s 259ms/step - loss: nan - categorical_accuracy: 1.0000
# 652/652 [==============================] - 124s 190ms/step - loss: nan - categorical_accuracy: 0.7429
# Epoch 82/100
# 651/652 [============================>.] - ETA: 0s - loss: nan - categorical_accuracy: 0.7425The average loss for epoch 81 is     nan
# 78/78 [==============================] - 23s 295ms/step - loss: nan - categorical_accuracy: 0.5224
# 652/652 [==============================] - 125s 192ms/step - loss: nan - categorical_accuracy: 0.7429
# Epoch 83/100
# 651/652 [============================>.] - ETA: 0s - loss: nan - categorical_accuracy: 0.7425The average loss for epoch 82 is     nan
# 78/78 [==============================] - 21s 265ms/step - loss: nan - categorical_accuracy: 1.0000
# 652/652 [==============================] - 127s 195ms/step - loss: nan - categorical_accuracy: 0.7429
# Epoch 84/100
# 651/652 [============================>.] - ETA: 0s - loss: nan - categorical_accuracy: 0.7425The average loss for epoch 83 is     nan
# 78/78 [==============================] - 20s 254ms/step - loss: nan - categorical_accuracy: 1.0000
# 652/652 [==============================] - 127s 195ms/step - loss: nan - categorical_accuracy: 0.7429
# Epoch 85/100
# 651/652 [============================>.] - ETA: 0s - loss: nan - categorical_accuracy: 0.7425The average loss for epoch 84 is     nan
# 78/78 [==============================] - 28s 355ms/step - loss: nan - categorical_accuracy: 0.4247
# 652/652 [==============================] - 134s 205ms/step - loss: nan - categorical_accuracy: 0.7429
# Epoch 86/100
# 651/652 [============================>.] - ETA: 0s - loss: nan - categorical_accuracy: 0.7440The average loss for epoch 85 is     nan
# 78/78 [==============================] - 22s 287ms/step - loss: nan - categorical_accuracy: 0.7404
# 652/652 [==============================] - 131s 201ms/step - loss: nan - categorical_accuracy: 0.7429
# Epoch 87/100
# 651/652 [============================>.] - ETA: 0s - loss: nan - categorical_accuracy: 0.7425The average loss for epoch 86 is     nan
# 78/78 [==============================] - 21s 275ms/step - loss: nan - categorical_accuracy: 0.9215
# 652/652 [==============================] - 130s 200ms/step - loss: nan - categorical_accuracy: 0.7429
# Epoch 88/100
# 651/652 [============================>.] - ETA: 0s - loss: nan - categorical_accuracy: 0.7439The average loss for epoch 87 is     nan
# 78/78 [==============================] - 30s 390ms/step - loss: nan - categorical_accuracy: 0.2436
# 652/652 [==============================] - 134s 206ms/step - loss: nan - categorical_accuracy: 0.7427
# Epoch 89/100
# 651/652 [============================>.] - ETA: 0s - loss: nan - categorical_accuracy: 0.7427The average loss for epoch 88 is     nan
# 78/78 [==============================] - 21s 264ms/step - loss: nan - categorical_accuracy: 0.9984
# 652/652 [==============================] - 125s 192ms/step - loss: nan - categorical_accuracy: 0.7431
# Epoch 90/100
# 651/652 [============================>.] - ETA: 0s - loss: nan - categorical_accuracy: 0.7425The average loss for epoch 89 is     nan
# 78/78 [==============================] - 24s 313ms/step - loss: nan - categorical_accuracy: 0.5337
# 652/652 [==============================] - 131s 201ms/step - loss: nan - categorical_accuracy: 0.7429
# Epoch 91/100
# 651/652 [============================>.] - ETA: 0s - loss: nan - categorical_accuracy: 0.7421The average loss for epoch 90 is     nan
# 78/78 [==============================] - 20s 259ms/step - loss: nan - categorical_accuracy: 0.9936
# 652/652 [==============================] - 126s 194ms/step - loss: nan - categorical_accuracy: 0.7423
# Epoch 92/100
# 651/652 [============================>.] - ETA: 0s - loss: nan - categorical_accuracy: 0.7425The average loss for epoch 91 is     nan
# 78/78 [==============================] - 20s 255ms/step - loss: nan - categorical_accuracy: 1.0000
# 652/652 [==============================] - 126s 193ms/step - loss: nan - categorical_accuracy: 0.7429
# Epoch 93/100
# 651/652 [============================>.] - ETA: 0s - loss: nan - categorical_accuracy: 0.7425The average loss for epoch 92 is     nan
# 78/78 [==============================] - 21s 274ms/step - loss: nan - categorical_accuracy: 0.7837
# 652/652 [==============================] - 128s 197ms/step - loss: nan - categorical_accuracy: 0.7429
# Epoch 94/100
# 651/652 [============================>.] - ETA: 0s - loss: nan - categorical_accuracy: 0.7440The average loss for epoch 93 is     nan
# 78/78 [==============================] - 24s 309ms/step - loss: nan - categorical_accuracy: 0.3814
# 652/652 [==============================] - 129s 198ms/step - loss: nan - categorical_accuracy: 0.7429
# Epoch 95/100
# 651/652 [============================>.] - ETA: 0s - loss: nan - categorical_accuracy: 0.7425The average loss for epoch 94 is     nan
# 78/78 [==============================] - 20s 253ms/step - loss: nan - categorical_accuracy: 1.0000
# 652/652 [==============================] - 123s 189ms/step - loss: nan - categorical_accuracy: 0.7429
# Epoch 96/100
# 651/652 [============================>.] - ETA: 0s - loss: nan - categorical_accuracy: 0.7425The average loss for epoch 95 is     nan
# 78/78 [==============================] - 33s 421ms/step - loss: nan - categorical_accuracy: 0.2901
# 652/652 [==============================] - 138s 212ms/step - loss: nan - categorical_accuracy: 0.7429
# Epoch 97/100
# 651/652 [============================>.] - ETA: 0s - loss: nan - categorical_accuracy: 0.7440The average loss for epoch 96 is     nan
# 78/78 [==============================] - 22s 280ms/step - loss: nan - categorical_accuracy: 0.8734
# 652/652 [==============================] - 132s 203ms/step - loss: nan - categorical_accuracy: 0.7429
# Epoch 98/100
# 651/652 [============================>.] - ETA: 0s - loss: nan - categorical_accuracy: 0.7425The average loss for epoch 97 is     nan
# 78/78 [==============================] - 23s 288ms/step - loss: nan - categorical_accuracy: 0.7997
# 652/652 [==============================] - 135s 207ms/step - loss: nan - categorical_accuracy: 0.7429
# Epoch 99/100
# 651/652 [============================>.] - ETA: 0s - loss: nan - categorical_accuracy: 0.7439The average loss for epoch 98 is     nan
# 78/78 [==============================] - 23s 295ms/step - loss: nan - categorical_accuracy: 0.7244
# 652/652 [==============================] - 135s 206ms/step - loss: nan - categorical_accuracy: 0.7427
# Epoch 100/100
# 651/652 [============================>.] - ETA: 0s - loss: nan - categorical_accuracy: 0.7425The average loss for epoch 99 is     nan
# 78/78 [==============================] - 21s 269ms/step - loss: nan - categorical_accuracy: 1.0000
# 652/652 [==============================] - 133s 204ms/step - loss: nan - categorical_accuracy: 0.7429

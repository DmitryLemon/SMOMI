# %%
__author__ = 'Alexander Soroka, soroka.a.m@gmail.com'
__copyright__ = """Copyright 2020 Alexander Soroka"""


import argparse
import glob
import numpy as np
import tensorflow as tf
import time
from tensorflow.python import keras as keras
from tensorflow.python.keras.callbacks import LearningRateScheduler

import tensorflow_addons as tfa


LOG_DIR = 'logs'
SHUFFLE_BUFFER = 4
BATCH_SIZE = 32
NUM_CLASSES = 6
PARALLEL_CALLS=4
RESIZE_TO = 224
TRAINSET_SIZE = 14034
VALSET_SIZE = 3000


def parse_proto_example(proto):
    keys_to_features = {
        'image/encoded': tf.io.FixedLenFeature((), tf.string, default_value=''),
        'image/class/label': tf.io.FixedLenFeature([], tf.int64, default_value=tf.zeros([], dtype=tf.int64))
    }
    example = tf.io.parse_single_example(proto, keys_to_features)
    example['image'] = tf.image.decode_jpeg(example['image/encoded'], channels=3)
    example['image'] = tf.image.convert_image_dtype(example['image'], dtype=tf.float32)
    example['image'] = tf.image.resize(example['image'], tf.constant([RESIZE_TO, RESIZE_TO]))
    return example['image'], tf.one_hot(example['image/class/label'], depth=NUM_CLASSES)


def normalize(image, label):
    return tf.image.per_image_standardization(image), label

def resize(image, label):
    return tf.image.resize(image, tf.constant([RESIZE_TO, RESIZE_TO])), label

def augmentation(image, label):
    image = tf.image.convert_image_dtype(image, tf.float32)
    image = tf.image.random_brightness(image, 0.5, seed=None)
    image = tf.image.random_contrast(image, 0.3, 1.7, seed=None)
    return image, label

def create_dataset(filenames, batch_size):
    """Create dataset from tfrecords file
    :tfrecords_files: Mask to collect tfrecords file of dataset
    :returns: tf.data.Dataset
    """
    return tf.data.TFRecordDataset(filenames)\
        .map(parse_proto_example)\
        .map(resize)\
        .map(normalize)\
        .batch(batch_size)\
        .prefetch(batch_size)

def create_aug_dataset(filenames, batch_size):
    """Create dataset from tfrecords file
    :tfrecords_files: Mask to collect tfrecords file of dataset
    :returns: tf.data.Dataset
    """
    return tf.data.TFRecordDataset(filenames)\
        .map(parse_proto_example)\
        .map(augmentation)\
        .map(resize)\
        .map(normalize)\
        .shuffle(buffer_size=5 * batch_size)\
        .batch(batch_size)\
        .prefetch(2 * batch_size)


def build_model():
    new_model = tf.keras.applications.MobileNetV2(input_shape=(224,224,3),
						classes = NUM_CLASSES,
            include_top=False,
            weights='imagenet')
    
    return tf.keras.models.Sequential([
    	new_model,
      tf.keras.layers.GlobalAveragePooling2D(),
      tf.keras.layers.Dropout(0.2),
    	tf.keras.layers.Flatten(),
      tf.keras.layers.Dense(NUM_CLASSES, activation=tf.keras.activations.softmax)
    ])


def main():
    #args = argparse.ArgumentParser()
    #args.add_argument('--train', type=str, help='Glob pattern to collect train tfrecord files')
    #args.add_argument('--test', type=str, help='Glob pattern to collect test tfrecord files')
    #args = args.parse_args()
    train_path = '/content/drive/My Drive/SMOMI/dataset/train*'
    test_path = '/content/drive/My Drive/SMOMI/dataset/val*'

    train_dataset = create_aug_dataset(glob.glob(train_path), BATCH_SIZE)
    validation_dataset = create_dataset(glob.glob(test_path), BATCH_SIZE)

    model = build_model()

    model.compile(
        optimizer=tf.optimizers.Adam(lr=4e-6),
        loss=tf.keras.losses.categorical_crossentropy,
        metrics=[tf.keras.metrics.categorical_accuracy],
    )

    log_dir='/content/drive/My Drive/SMOMI/{}/lab4_3-3/ilcd-{}'.format(LOG_DIR, time.time())
    weights_file = "/content/drive/My Drive/SMOMI/w-4_3-3.hdf5"

    model.fit(
        train_dataset,
        epochs=100,
        validation_data=validation_dataset,
        callbacks=[
            tf.keras.callbacks.TensorBoard(log_dir),
            tf.keras.callbacks.ModelCheckpoint(filepath=weights_file, monitor='val_categorical_accuracy', mode='max', save_best_only=True, save_weights_only=True, verbose=1)
        ]
    )


if __name__ == '__main__':
    main()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9412608/9406464 [==============================] - 0s 0us/step
# Epoch 1/100
#       1/Unknown - 0s 2ms/step - loss: 1.7305 - categorical_accuracy: 0.2188WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/summary_ops_v2.py:1277: stop (from tensorflow.python.eager.profiler) is deprecated and will be removed after 2020-07-01.
# Instructions for updating:
# use `tf.profiler.experimental.stop` instead.
#       2/Unknown - 1s 362ms/step - loss: 1.8383 - categorical_accuracy: 0.2188WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1006s vs `on_train_batch_end` time: 0.6224s). Check your callbacks.
#     439/Unknown - 128s 292ms/step - loss: 1.7279 - categorical_accuracy: 0.1762
# Epoch 00001: val_categorical_accuracy improved from -inf to 0.27900, saving model to /content/drive/My Drive/SMOMI/w-4_3-3.hdf5
# 439/439 [==============================] - 144s 328ms/step - loss: 1.7279 - categorical_accuracy: 0.1762 - val_loss: 1.5161 - val_categorical_accuracy: 0.2790
# Epoch 2/100
# 439/439 [==============================] - ETA: 0s - loss: 1.4361 - categorical_accuracy: 0.2224
# Epoch 00002: val_categorical_accuracy improved from 0.27900 to 0.35067, saving model to /content/drive/My Drive/SMOMI/w-4_3-3.hdf5
# 439/439 [==============================] - 135s 307ms/step - loss: 1.4361 - categorical_accuracy: 0.2224 - val_loss: 1.2346 - val_categorical_accuracy: 0.3507
# Epoch 3/100
# 439/439 [==============================] - ETA: 0s - loss: 1.2344 - categorical_accuracy: 0.3137
# Epoch 00003: val_categorical_accuracy improved from 0.35067 to 0.41900, saving model to /content/drive/My Drive/SMOMI/w-4_3-3.hdf5
# 439/439 [==============================] - 135s 307ms/step - loss: 1.2344 - categorical_accuracy: 0.3137 - val_loss: 1.0301 - val_categorical_accuracy: 0.4190
# Epoch 4/100
# 439/439 [==============================] - ETA: 0s - loss: 1.1199 - categorical_accuracy: 0.3677
# Epoch 00004: val_categorical_accuracy improved from 0.41900 to 0.49400, saving model to /content/drive/My Drive/SMOMI/w-4_3-3.hdf5
# 439/439 [==============================] - 135s 308ms/step - loss: 1.1199 - categorical_accuracy: 0.3677 - val_loss: 0.9130 - val_categorical_accuracy: 0.4940
# Epoch 5/100
# 439/439 [==============================] - ETA: 0s - loss: 1.0346 - categorical_accuracy: 0.4094
# Epoch 00005: val_categorical_accuracy improved from 0.49400 to 0.55700, saving model to /content/drive/My Drive/SMOMI/w-4_3-3.hdf5
# 439/439 [==============================] - 135s 307ms/step - loss: 1.0346 - categorical_accuracy: 0.4094 - val_loss: 0.8571 - val_categorical_accuracy: 0.5570
# Epoch 6/100
# 439/439 [==============================] - ETA: 0s - loss: 0.9714 - categorical_accuracy: 0.4425
# Epoch 00006: val_categorical_accuracy improved from 0.55700 to 0.58000, saving model to /content/drive/My Drive/SMOMI/w-4_3-3.hdf5
# 439/439 [==============================] - 134s 306ms/step - loss: 0.9714 - categorical_accuracy: 0.4425 - val_loss: 0.8318 - val_categorical_accuracy: 0.5800
# Epoch 7/100
# 439/439 [==============================] - ETA: 0s - loss: 0.9185 - categorical_accuracy: 0.4649
# Epoch 00007: val_categorical_accuracy improved from 0.58000 to 0.60067, saving model to /content/drive/My Drive/SMOMI/w-4_3-3.hdf5
# 439/439 [==============================] - 135s 308ms/step - loss: 0.9185 - categorical_accuracy: 0.4649 - val_loss: 0.8231 - val_categorical_accuracy: 0.6007
# Epoch 8/100
# 439/439 [==============================] - ETA: 0s - loss: 0.8731 - categorical_accuracy: 0.4845
# Epoch 00008: val_categorical_accuracy improved from 0.60067 to 0.60600, saving model to /content/drive/My Drive/SMOMI/w-4_3-3.hdf5
# 439/439 [==============================] - 135s 308ms/step - loss: 0.8731 - categorical_accuracy: 0.4845 - val_loss: 0.8141 - val_categorical_accuracy: 0.6060
# Epoch 9/100
# 439/439 [==============================] - ETA: 0s - loss: 0.8282 - categorical_accuracy: 0.5040
# Epoch 00009: val_categorical_accuracy improved from 0.60600 to 0.60633, saving model to /content/drive/My Drive/SMOMI/w-4_3-3.hdf5
# 439/439 [==============================] - 135s 308ms/step - loss: 0.8282 - categorical_accuracy: 0.5040 - val_loss: 0.8110 - val_categorical_accuracy: 0.6063
# Epoch 10/100
# 439/439 [==============================] - ETA: 0s - loss: 0.7821 - categorical_accuracy: 0.5328
# Epoch 00010: val_categorical_accuracy improved from 0.60633 to 0.61100, saving model to /content/drive/My Drive/SMOMI/w-4_3-3.hdf5
# 439/439 [==============================] - 135s 308ms/step - loss: 0.7821 - categorical_accuracy: 0.5328 - val_loss: 0.8083 - val_categorical_accuracy: 0.6110
# Epoch 11/100
# 439/439 [==============================] - ETA: 0s - loss: 0.7527 - categorical_accuracy: 0.5435
# Epoch 00011: val_categorical_accuracy did not improve from 0.61100
# 439/439 [==============================] - 134s 304ms/step - loss: 0.7527 - categorical_accuracy: 0.5435 - val_loss: 0.8073 - val_categorical_accuracy: 0.6100
# Epoch 12/100
# 439/439 [==============================] - ETA: 0s - loss: 0.7151 - categorical_accuracy: 0.5653
# Epoch 00012: val_categorical_accuracy improved from 0.61100 to 0.61167, saving model to /content/drive/My Drive/SMOMI/w-4_3-3.hdf5
# 439/439 [==============================] - 136s 311ms/step - loss: 0.7151 - categorical_accuracy: 0.5653 - val_loss: 0.8046 - val_categorical_accuracy: 0.6117
# Epoch 13/100
# 439/439 [==============================] - ETA: 0s - loss: 0.6806 - categorical_accuracy: 0.5896
# Epoch 00013: val_categorical_accuracy did not improve from 0.61167
# 439/439 [==============================] - 135s 307ms/step - loss: 0.6806 - categorical_accuracy: 0.5896 - val_loss: 0.8043 - val_categorical_accuracy: 0.6070
# Epoch 14/100
# 439/439 [==============================] - ETA: 0s - loss: 0.6443 - categorical_accuracy: 0.6082
# Epoch 00014: val_categorical_accuracy did not improve from 0.61167
# 439/439 [==============================] - 133s 304ms/step - loss: 0.6443 - categorical_accuracy: 0.6082 - val_loss: 0.8076 - val_categorical_accuracy: 0.6083
# Epoch 15/100
# 439/439 [==============================] - ETA: 0s - loss: 0.6157 - categorical_accuracy: 0.6233
# Epoch 00015: val_categorical_accuracy did not improve from 0.61167
# 439/439 [==============================] - 134s 306ms/step - loss: 0.6157 - categorical_accuracy: 0.6233 - val_loss: 0.8131 - val_categorical_accuracy: 0.6033
# Epoch 16/100
# 439/439 [==============================] - ETA: 0s - loss: 0.5858 - categorical_accuracy: 0.6419
# Epoch 00016: val_categorical_accuracy did not improve from 0.61167
# 439/439 [==============================] - 135s 307ms/step - loss: 0.5858 - categorical_accuracy: 0.6419 - val_loss: 0.8146 - val_categorical_accuracy: 0.6073
# Epoch 17/100
# 439/439 [==============================] - ETA: 0s - loss: 0.5430 - categorical_accuracy: 0.6692
# Epoch 00017: val_categorical_accuracy did not improve from 0.61167
# 439/439 [==============================] - 134s 306ms/step - loss: 0.5430 - categorical_accuracy: 0.6692 - val_loss: 0.8260 - val_categorical_accuracy: 0.6060
# Epoch 18/100
# 439/439 [==============================] - ETA: 0s - loss: 0.5094 - categorical_accuracy: 0.6843
# Epoch 00018: val_categorical_accuracy did not improve from 0.61167
# 439/439 [==============================] - 134s 305ms/step - loss: 0.5094 - categorical_accuracy: 0.6843 - val_loss: 0.8245 - val_categorical_accuracy: 0.6117
# Epoch 19/100
# 439/439 [==============================] - ETA: 0s - loss: 0.4751 - categorical_accuracy: 0.7020
# Epoch 00019: val_categorical_accuracy did not improve from 0.61167
# 439/439 [==============================] - 135s 307ms/step - loss: 0.4751 - categorical_accuracy: 0.7020 - val_loss: 0.8415 - val_categorical_accuracy: 0.6067
# Epoch 20/100
# 439/439 [==============================] - ETA: 0s - loss: 0.4506 - categorical_accuracy: 0.7100
# Epoch 00020: val_categorical_accuracy did not improve from 0.61167
# 439/439 [==============================] - 134s 306ms/step - loss: 0.4506 - categorical_accuracy: 0.7100 - val_loss: 0.8382 - val_categorical_accuracy: 0.6063
# Epoch 21/100
# 439/439 [==============================] - ETA: 0s - loss: 0.4183 - categorical_accuracy: 0.7249
# Epoch 00021: val_categorical_accuracy did not improve from 0.61167
# 439/439 [==============================] - 134s 305ms/step - loss: 0.4183 - categorical_accuracy: 0.7249 - val_loss: 0.8502 - val_categorical_accuracy: 0.6043
# Epoch 22/100
# 439/439 [==============================] - ETA: 0s - loss: 0.3990 - categorical_accuracy: 0.7326
# Epoch 00022: val_categorical_accuracy did not improve from 0.61167
# 439/439 [==============================] - 134s 306ms/step - loss: 0.3990 - categorical_accuracy: 0.7326 - val_loss: 0.8499 - val_categorical_accuracy: 0.6087
# Epoch 23/100
# 439/439 [==============================] - ETA: 0s - loss: 0.3793 - categorical_accuracy: 0.7395
# Epoch 00023: val_categorical_accuracy improved from 0.61167 to 0.61667, saving model to /content/drive/My Drive/SMOMI/w-4_3-3.hdf5
# 439/439 [==============================] - 135s 308ms/step - loss: 0.3793 - categorical_accuracy: 0.7395 - val_loss: 0.8471 - val_categorical_accuracy: 0.6167
# Epoch 24/100
# 439/439 [==============================] - ETA: 0s - loss: 0.3530 - categorical_accuracy: 0.7531
# Epoch 00024: val_categorical_accuracy did not improve from 0.61667
# 439/439 [==============================] - 134s 306ms/step - loss: 0.3530 - categorical_accuracy: 0.7531 - val_loss: 0.8466 - val_categorical_accuracy: 0.6133
# Epoch 25/100
# 439/439 [==============================] - ETA: 0s - loss: 0.3416 - categorical_accuracy: 0.7522
# Epoch 00025: val_categorical_accuracy did not improve from 0.61667
# 439/439 [==============================] - 134s 304ms/step - loss: 0.3416 - categorical_accuracy: 0.7522 - val_loss: 0.8461 - val_categorical_accuracy: 0.6073
# Epoch 26/100
# 439/439 [==============================] - ETA: 0s - loss: 0.3276 - categorical_accuracy: 0.7547
# Epoch 00026: val_categorical_accuracy did not improve from 0.61667
# 439/439 [==============================] - 135s 307ms/step - loss: 0.3276 - categorical_accuracy: 0.7547 - val_loss: 0.8417 - val_categorical_accuracy: 0.6143
# Epoch 27/100
# 439/439 [==============================] - ETA: 0s - loss: 0.3197 - categorical_accuracy: 0.7564
# Epoch 00027: val_categorical_accuracy improved from 0.61667 to 0.62367, saving model to /content/drive/My Drive/SMOMI/w-4_3-3.hdf5
# 439/439 [==============================] - 135s 307ms/step - loss: 0.3197 - categorical_accuracy: 0.7564 - val_loss: 0.8407 - val_categorical_accuracy: 0.6237
# Epoch 28/100
# 439/439 [==============================] - ETA: 0s - loss: 0.3038 - categorical_accuracy: 0.7602
# Epoch 00028: val_categorical_accuracy improved from 0.62367 to 0.62833, saving model to /content/drive/My Drive/SMOMI/w-4_3-3.hdf5
# 439/439 [==============================] - 135s 308ms/step - loss: 0.3038 - categorical_accuracy: 0.7602 - val_loss: 0.8366 - val_categorical_accuracy: 0.6283
# Epoch 29/100
# 439/439 [==============================] - ETA: 0s - loss: 0.2897 - categorical_accuracy: 0.7638
# Epoch 00029: val_categorical_accuracy did not improve from 0.62833
# 439/439 [==============================] - 134s 305ms/step - loss: 0.2897 - categorical_accuracy: 0.7638 - val_loss: 0.8442 - val_categorical_accuracy: 0.6277
# Epoch 30/100
# 439/439 [==============================] - ETA: 0s - loss: 0.2727 - categorical_accuracy: 0.7713
# Epoch 00030: val_categorical_accuracy did not improve from 0.62833
# 439/439 [==============================] - 135s 306ms/step - loss: 0.2727 - categorical_accuracy: 0.7713 - val_loss: 0.8604 - val_categorical_accuracy: 0.6230
# Epoch 31/100
# 439/439 [==============================] - ETA: 0s - loss: 0.2781 - categorical_accuracy: 0.7650
# Epoch 00031: val_categorical_accuracy did not improve from 0.62833
# 439/439 [==============================] - 134s 305ms/step - loss: 0.2781 - categorical_accuracy: 0.7650 - val_loss: 0.8520 - val_categorical_accuracy: 0.6270
# Epoch 32/100
# 439/439 [==============================] - ETA: 0s - loss: 0.2696 - categorical_accuracy: 0.7657
# Epoch 00032: val_categorical_accuracy improved from 0.62833 to 0.63833, saving model to /content/drive/My Drive/SMOMI/w-4_3-3.hdf5
# 439/439 [==============================] - 135s 309ms/step - loss: 0.2696 - categorical_accuracy: 0.7657 - val_loss: 0.8397 - val_categorical_accuracy: 0.6383
# Epoch 33/100
# 439/439 [==============================] - ETA: 0s - loss: 0.2581 - categorical_accuracy: 0.7703
# Epoch 00033: val_categorical_accuracy improved from 0.63833 to 0.64133, saving model to /content/drive/My Drive/SMOMI/w-4_3-3.hdf5
# 439/439 [==============================] - 135s 308ms/step - loss: 0.2581 - categorical_accuracy: 0.7703 - val_loss: 0.8454 - val_categorical_accuracy: 0.6413
# Epoch 34/100
# 439/439 [==============================] - ETA: 0s - loss: 0.2533 - categorical_accuracy: 0.7708
# Epoch 00034: val_categorical_accuracy improved from 0.64133 to 0.64633, saving model to /content/drive/My Drive/SMOMI/w-4_3-3.hdf5
# 439/439 [==============================] - 136s 309ms/step - loss: 0.2533 - categorical_accuracy: 0.7708 - val_loss: 0.8484 - val_categorical_accuracy: 0.6463
# Epoch 35/100
# 439/439 [==============================] - ETA: 0s - loss: 0.2456 - categorical_accuracy: 0.7755
# Epoch 00035: val_categorical_accuracy did not improve from 0.64633
# 439/439 [==============================] - 133s 303ms/step - loss: 0.2456 - categorical_accuracy: 0.7755 - val_loss: 0.8586 - val_categorical_accuracy: 0.6457
# Epoch 36/100
# 439/439 [==============================] - ETA: 0s - loss: 0.2474 - categorical_accuracy: 0.7713
# Epoch 00036: val_categorical_accuracy improved from 0.64633 to 0.65600, saving model to /content/drive/My Drive/SMOMI/w-4_3-3.hdf5
# 439/439 [==============================] - 134s 305ms/step - loss: 0.2474 - categorical_accuracy: 0.7713 - val_loss: 0.8367 - val_categorical_accuracy: 0.6560
# Epoch 37/100
# 439/439 [==============================] - ETA: 0s - loss: 0.2473 - categorical_accuracy: 0.7701
# Epoch 00037: val_categorical_accuracy did not improve from 0.65600
# 439/439 [==============================] - 134s 304ms/step - loss: 0.2473 - categorical_accuracy: 0.7701 - val_loss: 0.8556 - val_categorical_accuracy: 0.6517
# Epoch 38/100
# 439/439 [==============================] - ETA: 0s - loss: 0.2394 - categorical_accuracy: 0.7727
# Epoch 00038: val_categorical_accuracy did not improve from 0.65600
# 439/439 [==============================] - 134s 305ms/step - loss: 0.2394 - categorical_accuracy: 0.7727 - val_loss: 0.8823 - val_categorical_accuracy: 0.6507
# Epoch 39/100
# 439/439 [==============================] - ETA: 0s - loss: 0.2376 - categorical_accuracy: 0.7718
# Epoch 00039: val_categorical_accuracy did not improve from 0.65600
# 439/439 [==============================] - 135s 307ms/step - loss: 0.2376 - categorical_accuracy: 0.7718 - val_loss: 0.8718 - val_categorical_accuracy: 0.6480
# Epoch 40/100
# 439/439 [==============================] - ETA: 0s - loss: 0.2259 - categorical_accuracy: 0.7768
# Epoch 00040: val_categorical_accuracy did not improve from 0.65600
# 439/439 [==============================] - 135s 307ms/step - loss: 0.2259 - categorical_accuracy: 0.7768 - val_loss: 0.8762 - val_categorical_accuracy: 0.6540
# Epoch 41/100
# 439/439 [==============================] - ETA: 0s - loss: 0.2309 - categorical_accuracy: 0.7735
# Epoch 00041: val_categorical_accuracy improved from 0.65600 to 0.66467, saving model to /content/drive/My Drive/SMOMI/w-4_3-3.hdf5
# 439/439 [==============================] - 136s 311ms/step - loss: 0.2309 - categorical_accuracy: 0.7735 - val_loss: 0.8595 - val_categorical_accuracy: 0.6647
# Epoch 42/100
# 439/439 [==============================] - ETA: 0s - loss: 0.2296 - categorical_accuracy: 0.7713
# Epoch 00042: val_categorical_accuracy improved from 0.66467 to 0.66633, saving model to /content/drive/My Drive/SMOMI/w-4_3-3.hdf5
# 439/439 [==============================] - 136s 309ms/step - loss: 0.2296 - categorical_accuracy: 0.7713 - val_loss: 0.8578 - val_categorical_accuracy: 0.6663
# Epoch 43/100
# 439/439 [==============================] - ETA: 0s - loss: 0.2215 - categorical_accuracy: 0.7752
# Epoch 00043: val_categorical_accuracy did not improve from 0.66633
# 439/439 [==============================] - 134s 306ms/step - loss: 0.2215 - categorical_accuracy: 0.7752 - val_loss: 0.8618 - val_categorical_accuracy: 0.6633
# Epoch 44/100
# 439/439 [==============================] - ETA: 0s - loss: 0.2101 - categorical_accuracy: 0.7816
# Epoch 00044: val_categorical_accuracy did not improve from 0.66633
# 439/439 [==============================] - 136s 309ms/step - loss: 0.2101 - categorical_accuracy: 0.7816 - val_loss: 0.8718 - val_categorical_accuracy: 0.6610
# Epoch 45/100
# 439/439 [==============================] - ETA: 0s - loss: 0.2198 - categorical_accuracy: 0.7778
# Epoch 00045: val_categorical_accuracy did not improve from 0.66633
# 439/439 [==============================] - 135s 307ms/step - loss: 0.2198 - categorical_accuracy: 0.7778 - val_loss: 0.8518 - val_categorical_accuracy: 0.6577
# Epoch 46/100
# 439/439 [==============================] - ETA: 0s - loss: 0.2109 - categorical_accuracy: 0.7772
# Epoch 00046: val_categorical_accuracy did not improve from 0.66633
# 439/439 [==============================] - 134s 304ms/step - loss: 0.2109 - categorical_accuracy: 0.7772 - val_loss: 0.8484 - val_categorical_accuracy: 0.6647
# Epoch 47/100
# 439/439 [==============================] - ETA: 0s - loss: 0.2130 - categorical_accuracy: 0.7785
# Epoch 00047: val_categorical_accuracy did not improve from 0.66633
# 439/439 [==============================] - 135s 307ms/step - loss: 0.2130 - categorical_accuracy: 0.7785 - val_loss: 0.8505 - val_categorical_accuracy: 0.6660
# Epoch 48/100
# 439/439 [==============================] - ETA: 0s - loss: 0.1985 - categorical_accuracy: 0.7831
# Epoch 00048: val_categorical_accuracy improved from 0.66633 to 0.67033, saving model to /content/drive/My Drive/SMOMI/w-4_3-3.hdf5
# 439/439 [==============================] - 136s 309ms/step - loss: 0.1985 - categorical_accuracy: 0.7831 - val_loss: 0.8322 - val_categorical_accuracy: 0.6703
# Epoch 49/100
# 439/439 [==============================] - ETA: 0s - loss: 0.2019 - categorical_accuracy: 0.7765
# Epoch 00049: val_categorical_accuracy improved from 0.67033 to 0.67500, saving model to /content/drive/My Drive/SMOMI/w-4_3-3.hdf5
# 439/439 [==============================] - 135s 308ms/step - loss: 0.2019 - categorical_accuracy: 0.7765 - val_loss: 0.8357 - val_categorical_accuracy: 0.6750
# Epoch 50/100
# 439/439 [==============================] - ETA: 0s - loss: 0.2079 - categorical_accuracy: 0.7773
# Epoch 00050: val_categorical_accuracy improved from 0.67500 to 0.67900, saving model to /content/drive/My Drive/SMOMI/w-4_3-3.hdf5
# 439/439 [==============================] - 136s 309ms/step - loss: 0.2079 - categorical_accuracy: 0.7773 - val_loss: 0.8225 - val_categorical_accuracy: 0.6790
# Epoch 51/100
# 439/439 [==============================] - ETA: 0s - loss: 0.1942 - categorical_accuracy: 0.7850
# Epoch 00051: val_categorical_accuracy improved from 0.67900 to 0.68067, saving model to /content/drive/My Drive/SMOMI/w-4_3-3.hdf5
# 439/439 [==============================] - 136s 309ms/step - loss: 0.1942 - categorical_accuracy: 0.7850 - val_loss: 0.8244 - val_categorical_accuracy: 0.6807
# Epoch 52/100
# 439/439 [==============================] - ETA: 0s - loss: 0.1953 - categorical_accuracy: 0.7824
# Epoch 00052: val_categorical_accuracy did not improve from 0.68067
# 439/439 [==============================] - 135s 307ms/step - loss: 0.1953 - categorical_accuracy: 0.7824 - val_loss: 0.8095 - val_categorical_accuracy: 0.6800
# Epoch 53/100
# 439/439 [==============================] - ETA: 0s - loss: 0.1992 - categorical_accuracy: 0.7778
# Epoch 00053: val_categorical_accuracy improved from 0.68067 to 0.68500, saving model to /content/drive/My Drive/SMOMI/w-4_3-3.hdf5
# 439/439 [==============================] - 136s 309ms/step - loss: 0.1992 - categorical_accuracy: 0.7778 - val_loss: 0.7963 - val_categorical_accuracy: 0.6850
# Epoch 54/100
# 439/439 [==============================] - ETA: 0s - loss: 0.1897 - categorical_accuracy: 0.7849
# Epoch 00054: val_categorical_accuracy improved from 0.68500 to 0.69067, saving model to /content/drive/My Drive/SMOMI/w-4_3-3.hdf5
# 439/439 [==============================] - 136s 309ms/step - loss: 0.1897 - categorical_accuracy: 0.7849 - val_loss: 0.7924 - val_categorical_accuracy: 0.6907
# Epoch 55/100
# 439/439 [==============================] - ETA: 0s - loss: 0.1837 - categorical_accuracy: 0.7862
# Epoch 00055: val_categorical_accuracy did not improve from 0.69067
# 439/439 [==============================] - 134s 306ms/step - loss: 0.1837 - categorical_accuracy: 0.7862 - val_loss: 0.8001 - val_categorical_accuracy: 0.6890
# Epoch 56/100
# 439/439 [==============================] - ETA: 0s - loss: 0.1803 - categorical_accuracy: 0.7842
# Epoch 00056: val_categorical_accuracy did not improve from 0.69067
# 439/439 [==============================] - 135s 307ms/step - loss: 0.1803 - categorical_accuracy: 0.7842 - val_loss: 0.8070 - val_categorical_accuracy: 0.6907
# Epoch 57/100
# 439/439 [==============================] - ETA: 0s - loss: 0.1817 - categorical_accuracy: 0.7862
# Epoch 00057: val_categorical_accuracy did not improve from 0.69067
# 439/439 [==============================] - 135s 307ms/step - loss: 0.1817 - categorical_accuracy: 0.7862 - val_loss: 0.7944 - val_categorical_accuracy: 0.6893
# Epoch 58/100
# 439/439 [==============================] - ETA: 0s - loss: 0.1834 - categorical_accuracy: 0.7833
# Epoch 00058: val_categorical_accuracy did not improve from 0.69067
# 439/439 [==============================] - 136s 309ms/step - loss: 0.1834 - categorical_accuracy: 0.7833 - val_loss: 0.8002 - val_categorical_accuracy: 0.6860
# Epoch 59/100
# 439/439 [==============================] - ETA: 0s - loss: 0.1732 - categorical_accuracy: 0.7870
# Epoch 00059: val_categorical_accuracy did not improve from 0.69067
# 439/439 [==============================] - 135s 308ms/step - loss: 0.1732 - categorical_accuracy: 0.7870 - val_loss: 0.7927 - val_categorical_accuracy: 0.6873
# Epoch 60/100
# 439/439 [==============================] - ETA: 0s - loss: 0.1703 - categorical_accuracy: 0.7867
# Epoch 00060: val_categorical_accuracy did not improve from 0.69067
# 439/439 [==============================] - 134s 305ms/step - loss: 0.1703 - categorical_accuracy: 0.7867 - val_loss: 0.7897 - val_categorical_accuracy: 0.6830
# Epoch 61/100
# 439/439 [==============================] - ETA: 0s - loss: 0.1729 - categorical_accuracy: 0.7871
# Epoch 00061: val_categorical_accuracy did not improve from 0.69067
# 439/439 [==============================] - 134s 306ms/step - loss: 0.1729 - categorical_accuracy: 0.7871 - val_loss: 0.8012 - val_categorical_accuracy: 0.6853
# Epoch 62/100
# 439/439 [==============================] - ETA: 0s - loss: 0.1726 - categorical_accuracy: 0.7872
# Epoch 00062: val_categorical_accuracy did not improve from 0.69067
# 439/439 [==============================] - 134s 306ms/step - loss: 0.1726 - categorical_accuracy: 0.7872 - val_loss: 0.8143 - val_categorical_accuracy: 0.6793
# Epoch 63/100
# 439/439 [==============================] - ETA: 0s - loss: 0.1634 - categorical_accuracy: 0.7902
# Epoch 00063: val_categorical_accuracy did not improve from 0.69067
# 439/439 [==============================] - 134s 306ms/step - loss: 0.1634 - categorical_accuracy: 0.7902 - val_loss: 0.7962 - val_categorical_accuracy: 0.6847
# Epoch 64/100
# 439/439 [==============================] - ETA: 0s - loss: 0.1591 - categorical_accuracy: 0.7898
# Epoch 00064: val_categorical_accuracy did not improve from 0.69067
# 439/439 [==============================] - 135s 306ms/step - loss: 0.1591 - categorical_accuracy: 0.7898 - val_loss: 0.7925 - val_categorical_accuracy: 0.6870
# Epoch 65/100
# 439/439 [==============================] - ETA: 0s - loss: 0.1562 - categorical_accuracy: 0.7931
# Epoch 00065: val_categorical_accuracy did not improve from 0.69067
# 439/439 [==============================] - 134s 306ms/step - loss: 0.1562 - categorical_accuracy: 0.7931 - val_loss: 0.7928 - val_categorical_accuracy: 0.6840
# Epoch 66/100
# 439/439 [==============================] - ETA: 0s - loss: 0.1606 - categorical_accuracy: 0.7888
# Epoch 00066: val_categorical_accuracy did not improve from 0.69067
# 439/439 [==============================] - 135s 307ms/step - loss: 0.1606 - categorical_accuracy: 0.7888 - val_loss: 0.7843 - val_categorical_accuracy: 0.6793
# Epoch 67/100
# 439/439 [==============================] - ETA: 0s - loss: 0.1585 - categorical_accuracy: 0.7884
# Epoch 00067: val_categorical_accuracy did not improve from 0.69067
# 439/439 [==============================] - 134s 306ms/step - loss: 0.1585 - categorical_accuracy: 0.7884 - val_loss: 0.7732 - val_categorical_accuracy: 0.6860
# Epoch 68/100
# 439/439 [==============================] - ETA: 0s - loss: 0.1597 - categorical_accuracy: 0.7859
# Epoch 00068: val_categorical_accuracy did not improve from 0.69067
# 439/439 [==============================] - 135s 307ms/step - loss: 0.1597 - categorical_accuracy: 0.7859 - val_loss: 0.7731 - val_categorical_accuracy: 0.6800
# Epoch 69/100
# 439/439 [==============================] - ETA: 0s - loss: 0.1501 - categorical_accuracy: 0.7909
# Epoch 00069: val_categorical_accuracy did not improve from 0.69067
# 439/439 [==============================] - 134s 306ms/step - loss: 0.1501 - categorical_accuracy: 0.7909 - val_loss: 0.7724 - val_categorical_accuracy: 0.6757
# Epoch 70/100
# 439/439 [==============================] - ETA: 0s - loss: 0.1449 - categorical_accuracy: 0.7928
# Epoch 00070: val_categorical_accuracy did not improve from 0.69067
# 439/439 [==============================] - 135s 306ms/step - loss: 0.1449 - categorical_accuracy: 0.7928 - val_loss: 0.7817 - val_categorical_accuracy: 0.6790
# Epoch 71/100
# 439/439 [==============================] - ETA: 0s - loss: 0.1431 - categorical_accuracy: 0.7918
# Epoch 00071: val_categorical_accuracy did not improve from 0.69067
# 439/439 [==============================] - 134s 306ms/step - loss: 0.1431 - categorical_accuracy: 0.7918 - val_loss: 0.7860 - val_categorical_accuracy: 0.6837
# Epoch 72/100
# 439/439 [==============================] - ETA: 0s - loss: 0.1403 - categorical_accuracy: 0.7955
# Epoch 00072: val_categorical_accuracy did not improve from 0.69067
# 439/439 [==============================] - 135s 308ms/step - loss: 0.1403 - categorical_accuracy: 0.7955 - val_loss: 0.7573 - val_categorical_accuracy: 0.6860
# Epoch 73/100
# 439/439 [==============================] - ETA: 0s - loss: 0.1394 - categorical_accuracy: 0.7931
# Epoch 00073: val_categorical_accuracy did not improve from 0.69067
# 439/439 [==============================] - 134s 306ms/step - loss: 0.1394 - categorical_accuracy: 0.7931 - val_loss: 0.7783 - val_categorical_accuracy: 0.6780
# Epoch 74/100
# 439/439 [==============================] - ETA: 0s - loss: 0.1349 - categorical_accuracy: 0.7930
# Epoch 00074: val_categorical_accuracy did not improve from 0.69067
# 439/439 [==============================] - 135s 308ms/step - loss: 0.1349 - categorical_accuracy: 0.7930 - val_loss: 0.7718 - val_categorical_accuracy: 0.6727
# Epoch 75/100
# 439/439 [==============================] - ETA: 0s - loss: 0.1347 - categorical_accuracy: 0.7953
# Epoch 00075: val_categorical_accuracy did not improve from 0.69067
# 439/439 [==============================] - 135s 307ms/step - loss: 0.1347 - categorical_accuracy: 0.7953 - val_loss: 0.7504 - val_categorical_accuracy: 0.6813
# Epoch 76/100
# 439/439 [==============================] - ETA: 0s - loss: 0.1388 - categorical_accuracy: 0.7949
# Epoch 00076: val_categorical_accuracy did not improve from 0.69067
# 439/439 [==============================] - 134s 305ms/step - loss: 0.1388 - categorical_accuracy: 0.7949 - val_loss: 0.7486 - val_categorical_accuracy: 0.6820
# Epoch 77/100
# 439/439 [==============================] - ETA: 0s - loss: 0.1281 - categorical_accuracy: 0.7959
# Epoch 00077: val_categorical_accuracy did not improve from 0.69067
# 439/439 [==============================] - 136s 309ms/step - loss: 0.1281 - categorical_accuracy: 0.7959 - val_loss: 0.7691 - val_categorical_accuracy: 0.6790
# Epoch 78/100
# 439/439 [==============================] - ETA: 0s - loss: 0.1324 - categorical_accuracy: 0.7958
# Epoch 00078: val_categorical_accuracy did not improve from 0.69067
# 439/439 [==============================] - 136s 309ms/step - loss: 0.1324 - categorical_accuracy: 0.7958 - val_loss: 0.7604 - val_categorical_accuracy: 0.6747
# Epoch 79/100
# 439/439 [==============================] - ETA: 0s - loss: 0.1325 - categorical_accuracy: 0.7971
# Epoch 00079: val_categorical_accuracy did not improve from 0.69067
# 439/439 [==============================] - 135s 307ms/step - loss: 0.1325 - categorical_accuracy: 0.7971 - val_loss: 0.7548 - val_categorical_accuracy: 0.6773
# Epoch 80/100
# 439/439 [==============================] - ETA: 0s - loss: 0.1212 - categorical_accuracy: 0.7982
# Epoch 00080: val_categorical_accuracy did not improve from 0.69067
# 439/439 [==============================] - 134s 306ms/step - loss: 0.1212 - categorical_accuracy: 0.7982 - val_loss: 0.7375 - val_categorical_accuracy: 0.6813
# Epoch 81/100
# 439/439 [==============================] - ETA: 0s - loss: 0.1279 - categorical_accuracy: 0.7961
# Epoch 00081: val_categorical_accuracy did not improve from 0.69067
# 439/439 [==============================] - 134s 305ms/step - loss: 0.1279 - categorical_accuracy: 0.7961 - val_loss: 0.7628 - val_categorical_accuracy: 0.6750
# Epoch 82/100
# 439/439 [==============================] - ETA: 0s - loss: 0.1255 - categorical_accuracy: 0.7947
# Epoch 00082: val_categorical_accuracy did not improve from 0.69067
# 439/439 [==============================] - 135s 307ms/step - loss: 0.1255 - categorical_accuracy: 0.7947 - val_loss: 0.7551 - val_categorical_accuracy: 0.6770
# Epoch 83/100
# 439/439 [==============================] - ETA: 0s - loss: 0.1259 - categorical_accuracy: 0.7954
# Epoch 00083: val_categorical_accuracy did not improve from 0.69067
# 439/439 [==============================] - 134s 306ms/step - loss: 0.1259 - categorical_accuracy: 0.7954 - val_loss: 0.7385 - val_categorical_accuracy: 0.6803
# Epoch 84/100
# 439/439 [==============================] - ETA: 0s - loss: 0.1206 - categorical_accuracy: 0.7984
# Epoch 00084: val_categorical_accuracy did not improve from 0.69067
# 439/439 [==============================] - 135s 308ms/step - loss: 0.1206 - categorical_accuracy: 0.7984 - val_loss: 0.7486 - val_categorical_accuracy: 0.6813
# Epoch 85/100
# 439/439 [==============================] - ETA: 0s - loss: 0.1165 - categorical_accuracy: 0.7993
# Epoch 00085: val_categorical_accuracy did not improve from 0.69067
# 439/439 [==============================] - 135s 307ms/step - loss: 0.1165 - categorical_accuracy: 0.7993 - val_loss: 0.7266 - val_categorical_accuracy: 0.6887
# Epoch 86/100
# 439/439 [==============================] - ETA: 0s - loss: 0.1157 - categorical_accuracy: 0.7998
# Epoch 00086: val_categorical_accuracy did not improve from 0.69067
# 439/439 [==============================] - 134s 306ms/step - loss: 0.1157 - categorical_accuracy: 0.7998 - val_loss: 0.7464 - val_categorical_accuracy: 0.6883
# Epoch 87/100
# 439/439 [==============================] - ETA: 0s - loss: 0.1145 - categorical_accuracy: 0.8005
# Epoch 00087: val_categorical_accuracy improved from 0.69067 to 0.69467, saving model to /content/drive/My Drive/SMOMI/w-4_3-3.hdf5
# 439/439 [==============================] - 135s 308ms/step - loss: 0.1145 - categorical_accuracy: 0.8005 - val_loss: 0.7443 - val_categorical_accuracy: 0.6947
# Epoch 88/100
# 439/439 [==============================] - ETA: 0s - loss: 0.1171 - categorical_accuracy: 0.8000
# Epoch 00088: val_categorical_accuracy did not improve from 0.69467
# 439/439 [==============================] - 134s 306ms/step - loss: 0.1171 - categorical_accuracy: 0.8000 - val_loss: 0.7390 - val_categorical_accuracy: 0.6927
# Epoch 89/100
# 439/439 [==============================] - ETA: 0s - loss: 0.1163 - categorical_accuracy: 0.7970
# Epoch 00089: val_categorical_accuracy did not improve from 0.69467
# 439/439 [==============================] - 135s 308ms/step - loss: 0.1163 - categorical_accuracy: 0.7970 - val_loss: 0.7302 - val_categorical_accuracy: 0.6897
# Epoch 90/100
# 439/439 [==============================] - ETA: 0s - loss: 0.1198 - categorical_accuracy: 0.7970
# Epoch 00090: val_categorical_accuracy did not improve from 0.69467
# 439/439 [==============================] - 135s 309ms/step - loss: 0.1198 - categorical_accuracy: 0.7970 - val_loss: 0.7234 - val_categorical_accuracy: 0.6900
# Epoch 91/100
# 439/439 [==============================] - ETA: 0s - loss: 0.1122 - categorical_accuracy: 0.8018
# Epoch 00091: val_categorical_accuracy did not improve from 0.69467
# 439/439 [==============================] - 134s 305ms/step - loss: 0.1122 - categorical_accuracy: 0.8018 - val_loss: 0.7191 - val_categorical_accuracy: 0.6923
# Epoch 92/100
# 439/439 [==============================] - ETA: 0s - loss: 0.1154 - categorical_accuracy: 0.7988
# Epoch 00092: val_categorical_accuracy improved from 0.69467 to 0.69567, saving model to /content/drive/My Drive/SMOMI/w-4_3-3.hdf5
# 439/439 [==============================] - 135s 308ms/step - loss: 0.1154 - categorical_accuracy: 0.7988 - val_loss: 0.7110 - val_categorical_accuracy: 0.6957
# Epoch 93/100
# 439/439 [==============================] - ETA: 0s - loss: 0.1078 - categorical_accuracy: 0.8018
# Epoch 00093: val_categorical_accuracy improved from 0.69567 to 0.69633, saving model to /content/drive/My Drive/SMOMI/w-4_3-3.hdf5
# 439/439 [==============================] - 136s 309ms/step - loss: 0.1078 - categorical_accuracy: 0.8018 - val_loss: 0.7095 - val_categorical_accuracy: 0.6963
# Epoch 94/100
# 439/439 [==============================] - ETA: 0s - loss: 0.1124 - categorical_accuracy: 0.8001
# Epoch 00094: val_categorical_accuracy did not improve from 0.69633
# 439/439 [==============================] - 135s 307ms/step - loss: 0.1124 - categorical_accuracy: 0.8001 - val_loss: 0.7018 - val_categorical_accuracy: 0.6900
# Epoch 95/100
#  48/439 [==>...........................] - ETA: 1:56 - loss: 0.0960 - categorical_accuracy: 0.9720

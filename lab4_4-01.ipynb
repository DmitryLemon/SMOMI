# %%
"""This module implements data feeding and training loop to create model
to classify X-Ray chest images as a lab example for BSU students.
"""

__author__ = 'Alexander Soroka, soroka.a.m@gmail.com'
__copyright__ = """Copyright 2020 Alexander Soroka"""


import argparse
import glob
import numpy as np
import tensorflow as tf
import time
from tensorflow.python import keras as keras
from tensorflow.python.keras.callbacks import LearningRateScheduler


LOG_DIR = 'logs'
SHUFFLE_BUFFER = 4
BATCH_SIZE = 64
NUM_CLASSES = 6
PARALLEL_CALLS=4
RESIZE_TO = 224
TRAINSET_SIZE = 14034
VALSET_SIZE = 3000


def parse_proto_example(proto):
    keys_to_features = {
        'image/encoded': tf.io.FixedLenFeature((), tf.string, default_value=''),
        'image/class/label': tf.io.FixedLenFeature([], tf.int64, default_value=tf.zeros([], dtype=tf.int64))
    }
    example = tf.io.parse_single_example(proto, keys_to_features)
    example['image'] = tf.image.decode_jpeg(example['image/encoded'], channels=3)
    example['image'] = tf.image.convert_image_dtype(example['image'], dtype=tf.float32)
    example['image'] = tf.image.resize(example['image'], tf.constant([RESIZE_TO, RESIZE_TO]))
    return example['image'], tf.one_hot(example['image/class/label'], depth=NUM_CLASSES)


def normalize(image, label):
    return tf.image.per_image_standardization(image), label

def resize(image, label):
    return tf.image.resize(image, tf.constant([RESIZE_TO, RESIZE_TO])), label

def create_dataset(filenames, batch_size):
    """Create dataset from tfrecords file
    :tfrecords_files: Mask to collect tfrecords file of dataset
    :returns: tf.data.Dataset
    """
    return tf.data.TFRecordDataset(filenames)\
        .map(parse_proto_example)\
        .map(resize)\
        .map(normalize)\
        .batch(batch_size)\
        .prefetch(batch_size)

def create_aug_dataset(filenames, batch_size):
    return tf.data.TFRecordDataset(filenames)\
        .map(parse_proto_example)\
        .map(resize)\
        .map(normalize)\
        .map(augment)\
        .shuffle(buffer_size=5 * batch_size)\
        .batch(batch_size)\
        .prefetch(2 * batch_size)

def augment(image,label):
    with tf.name_scope('Add_gaussian_noise'):
        noise_img = image + tf.random.normal(shape=tf.shape(image), mean=0.0, stddev=0.1, dtype=tf.float32)
        noise_img = tf.clip_by_value(noise_img, -1.0, 1.0)
    return noise_img,label

def build_model():
    base_model = tf.keras.applications.MobileNetV2(
                                  include_top=False,
                                  weights='imagenet')
    global_average_layer = tf.keras.layers.GlobalAveragePooling2D()     
    prediction_layer = tf.keras.layers.Dense(6, activation=tf.keras.activations.softmax)

    inputs = tf.keras.Input(shape=(224, 224, 3))
    x = base_model(inputs, training=True)
    x = global_average_layer(x)
    x = tf.keras.layers.Dropout(0.4)(x)
    x = tf.keras.layers.Flatten()(x)
    outputs = prediction_layer(x)
    model = tf.keras.Model(inputs, outputs)

    return model

def main():
    train_path = '/content/drive/My Drive/SMOMI/dataset/train*'
    test_path = '/content/drive/My Drive/SMOMI/dataset/val*'

    train_dataset = create_aug_dataset(glob.glob(train_path), BATCH_SIZE)
    validation_dataset = create_aug_dataset(glob.glob(test_path), BATCH_SIZE)

    model = build_model()

    model.compile(
        optimizer=tf.optimizers.Adam(lr=3e-6),
        loss=tf.keras.losses.categorical_crossentropy,
        metrics=[tf.keras.metrics.categorical_accuracy],
    )

    weights_file = "/content/drive/My Drive/SMOMI/w-lab4_4-3.hdf5"
    log_dir='/content/drive/My Drive/SMOMI/{}/lab4_4-3-gug/ilcd-{}'.format(LOG_DIR, time.time())
    model.fit(
        train_dataset,
        epochs=100,
        validation_data=validation_dataset,
        callbacks=[
            tf.keras.callbacks.TensorBoard(log_dir),
            tf.keras.callbacks.ModelCheckpoint(filepath=weights_file, monitor='val_categorical_accuracy', mode='max', save_best_only=True, save_weights_only=True, verbose=1)
        ]
    )
if __name__ == '__main__':
    main()
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9412608/9406464 [==============================] - 0s 0us/step
# Epoch 1/100
#       1/Unknown - 0s 630us/step - loss: 1.9493 - categorical_accuracy: 0.2188WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/summary_ops_v2.py:1277: stop (from tensorflow.python.eager.profiler) is deprecated and will be removed after 2020-07-01.
# Instructions for updating:
# use `tf.profiler.experimental.stop` instead.
#       2/Unknown - 1s 298ms/step - loss: 2.0567 - categorical_accuracy: 0.1953WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1017s vs `on_train_batch_end` time: 0.4919s). Check your callbacks.
#     220/Unknown - 99s 448ms/step - loss: 1.7727 - categorical_accuracy: 0.1759
# Epoch 00001: val_categorical_accuracy improved from -inf to 0.24633, saving model to /content/drive/My Drive/SMOMI/w-lab4_4-3.hdf5
# 220/220 [==============================] - 128s 581ms/step - loss: 1.7727 - categorical_accuracy: 0.1759 - val_loss: 1.4272 - val_categorical_accuracy: 0.2463
# Epoch 2/100
# 220/220 [==============================] - ETA: 0s - loss: 1.6195 - categorical_accuracy: 0.2029
# Epoch 00002: val_categorical_accuracy improved from 0.24633 to 0.32400, saving model to /content/drive/My Drive/SMOMI/w-lab4_4-3.hdf5
# 220/220 [==============================] - 108s 493ms/step - loss: 1.6195 - categorical_accuracy: 0.2029 - val_loss: 1.2371 - val_categorical_accuracy: 0.3240
# Epoch 3/100
# 220/220 [==============================] - ETA: 0s - loss: 1.5220 - categorical_accuracy: 0.2194
# Epoch 00003: val_categorical_accuracy improved from 0.32400 to 0.38933, saving model to /content/drive/My Drive/SMOMI/w-lab4_4-3.hdf5
# 220/220 [==============================] - 108s 491ms/step - loss: 1.5220 - categorical_accuracy: 0.2194 - val_loss: 1.1259 - val_categorical_accuracy: 0.3893
# Epoch 4/100
# 220/220 [==============================] - ETA: 0s - loss: 1.4498 - categorical_accuracy: 0.2389
# Epoch 00004: val_categorical_accuracy improved from 0.38933 to 0.43600, saving model to /content/drive/My Drive/SMOMI/w-lab4_4-3.hdf5
# 220/220 [==============================] - 108s 492ms/step - loss: 1.4498 - categorical_accuracy: 0.2389 - val_loss: 1.0664 - val_categorical_accuracy: 0.4360
# Epoch 5/100
# 220/220 [==============================] - ETA: 0s - loss: 1.4106 - categorical_accuracy: 0.2517
# Epoch 00005: val_categorical_accuracy improved from 0.43600 to 0.44867, saving model to /content/drive/My Drive/SMOMI/w-lab4_4-3.hdf5
# 220/220 [==============================] - 108s 492ms/step - loss: 1.4106 - categorical_accuracy: 0.2517 - val_loss: 1.0313 - val_categorical_accuracy: 0.4487
# Epoch 6/100
# 220/220 [==============================] - ETA: 0s - loss: 1.3856 - categorical_accuracy: 0.2590
# Epoch 00006: val_categorical_accuracy improved from 0.44867 to 0.45867, saving model to /content/drive/My Drive/SMOMI/w-lab4_4-3.hdf5
# 220/220 [==============================] - 109s 493ms/step - loss: 1.3856 - categorical_accuracy: 0.2590 - val_loss: 1.0014 - val_categorical_accuracy: 0.4587
# Epoch 7/100
# 220/220 [==============================] - ETA: 0s - loss: 1.3508 - categorical_accuracy: 0.2729
# Epoch 00007: val_categorical_accuracy improved from 0.45867 to 0.46300, saving model to /content/drive/My Drive/SMOMI/w-lab4_4-3.hdf5
# 220/220 [==============================] - 108s 491ms/step - loss: 1.3508 - categorical_accuracy: 0.2729 - val_loss: 0.9776 - val_categorical_accuracy: 0.4630
# Epoch 8/100
# 220/220 [==============================] - ETA: 0s - loss: 1.3323 - categorical_accuracy: 0.2815
# Epoch 00008: val_categorical_accuracy improved from 0.46300 to 0.49667, saving model to /content/drive/My Drive/SMOMI/w-lab4_4-3.hdf5
# 220/220 [==============================] - 108s 492ms/step - loss: 1.3323 - categorical_accuracy: 0.2815 - val_loss: 0.9477 - val_categorical_accuracy: 0.4967
# Epoch 9/100
# 220/220 [==============================] - ETA: 0s - loss: 1.3042 - categorical_accuracy: 0.2912
# Epoch 00009: val_categorical_accuracy improved from 0.49667 to 0.50600, saving model to /content/drive/My Drive/SMOMI/w-lab4_4-3.hdf5
# 220/220 [==============================] - 108s 489ms/step - loss: 1.3042 - categorical_accuracy: 0.2912 - val_loss: 0.9257 - val_categorical_accuracy: 0.5060
# Epoch 10/100
# 220/220 [==============================] - ETA: 0s - loss: 1.2719 - categorical_accuracy: 0.3072
# Epoch 00010: val_categorical_accuracy did not improve from 0.50600
# 220/220 [==============================] - 107s 488ms/step - loss: 1.2719 - categorical_accuracy: 0.3072 - val_loss: 0.9243 - val_categorical_accuracy: 0.4957
# Epoch 11/100
# 220/220 [==============================] - ETA: 0s - loss: 1.2532 - categorical_accuracy: 0.3127
# Epoch 00011: val_categorical_accuracy improved from 0.50600 to 0.51600, saving model to /content/drive/My Drive/SMOMI/w-lab4_4-3.hdf5
# 220/220 [==============================] - 109s 493ms/step - loss: 1.2532 - categorical_accuracy: 0.3127 - val_loss: 0.9062 - val_categorical_accuracy: 0.5160
# Epoch 12/100
# 220/220 [==============================] - ETA: 0s - loss: 1.2243 - categorical_accuracy: 0.3273
# Epoch 00012: val_categorical_accuracy improved from 0.51600 to 0.51967, saving model to /content/drive/My Drive/SMOMI/w-lab4_4-3.hdf5
# 220/220 [==============================] - 108s 489ms/step - loss: 1.2243 - categorical_accuracy: 0.3273 - val_loss: 0.8904 - val_categorical_accuracy: 0.5197
# Epoch 13/100
# 220/220 [==============================] - ETA: 0s - loss: 1.1961 - categorical_accuracy: 0.3394
# Epoch 00013: val_categorical_accuracy improved from 0.51967 to 0.52767, saving model to /content/drive/My Drive/SMOMI/w-lab4_4-3.hdf5
# 220/220 [==============================] - 108s 491ms/step - loss: 1.1961 - categorical_accuracy: 0.3394 - val_loss: 0.8715 - val_categorical_accuracy: 0.5277
# Epoch 14/100
# 220/220 [==============================] - ETA: 0s - loss: 1.1817 - categorical_accuracy: 0.3446
# Epoch 00014: val_categorical_accuracy improved from 0.52767 to 0.53767, saving model to /content/drive/My Drive/SMOMI/w-lab4_4-3.hdf5
# 220/220 [==============================] - 108s 489ms/step - loss: 1.1817 - categorical_accuracy: 0.3446 - val_loss: 0.8641 - val_categorical_accuracy: 0.5377
# Epoch 15/100
# 220/220 [==============================] - ETA: 0s - loss: 1.1461 - categorical_accuracy: 0.3677
# Epoch 00015: val_categorical_accuracy improved from 0.53767 to 0.54000, saving model to /content/drive/My Drive/SMOMI/w-lab4_4-3.hdf5
# 220/220 [==============================] - 107s 487ms/step - loss: 1.1461 - categorical_accuracy: 0.3677 - val_loss: 0.8527 - val_categorical_accuracy: 0.5400
# Epoch 16/100
# 220/220 [==============================] - ETA: 0s - loss: 1.1223 - categorical_accuracy: 0.3727
# Epoch 00016: val_categorical_accuracy improved from 0.54000 to 0.55900, saving model to /content/drive/My Drive/SMOMI/w-lab4_4-3.hdf5
# 220/220 [==============================] - 108s 491ms/step - loss: 1.1223 - categorical_accuracy: 0.3727 - val_loss: 0.8334 - val_categorical_accuracy: 0.5590
# Epoch 17/100
# 220/220 [==============================] - ETA: 0s - loss: 1.1015 - categorical_accuracy: 0.3821
# Epoch 00017: val_categorical_accuracy improved from 0.55900 to 0.56100, saving model to /content/drive/My Drive/SMOMI/w-lab4_4-3.hdf5
# 220/220 [==============================] - 109s 494ms/step - loss: 1.1015 - categorical_accuracy: 0.3821 - val_loss: 0.8340 - val_categorical_accuracy: 0.5610
# Epoch 18/100
# 220/220 [==============================] - ETA: 0s - loss: 1.0747 - categorical_accuracy: 0.4065
# Epoch 00018: val_categorical_accuracy improved from 0.56100 to 0.56467, saving model to /content/drive/My Drive/SMOMI/w-lab4_4-3.hdf5
# 220/220 [==============================] - 108s 491ms/step - loss: 1.0747 - categorical_accuracy: 0.4065 - val_loss: 0.8233 - val_categorical_accuracy: 0.5647
# Epoch 19/100
# 220/220 [==============================] - ETA: 0s - loss: 1.0456 - categorical_accuracy: 0.4178
# Epoch 00019: val_categorical_accuracy did not improve from 0.56467
# 220/220 [==============================] - 106s 481ms/step - loss: 1.0456 - categorical_accuracy: 0.4178 - val_loss: 0.8202 - val_categorical_accuracy: 0.5633
# Epoch 20/100
# 220/220 [==============================] - ETA: 0s - loss: 1.0154 - categorical_accuracy: 0.4318
# Epoch 00020: val_categorical_accuracy did not improve from 0.56467
# 220/220 [==============================] - 108s 489ms/step - loss: 1.0154 - categorical_accuracy: 0.4318 - val_loss: 0.8151 - val_categorical_accuracy: 0.5627
# Epoch 21/100
# 220/220 [==============================] - ETA: 0s - loss: 0.9902 - categorical_accuracy: 0.4520
# Epoch 00021: val_categorical_accuracy improved from 0.56467 to 0.58033, saving model to /content/drive/My Drive/SMOMI/w-lab4_4-3.hdf5
# 220/220 [==============================] - 109s 496ms/step - loss: 0.9902 - categorical_accuracy: 0.4520 - val_loss: 0.8070 - val_categorical_accuracy: 0.5803
# Epoch 22/100
# 220/220 [==============================] - ETA: 0s - loss: 0.9808 - categorical_accuracy: 0.4549
# Epoch 00022: val_categorical_accuracy improved from 0.58033 to 0.58500, saving model to /content/drive/My Drive/SMOMI/w-lab4_4-3.hdf5
# 220/220 [==============================] - 107s 488ms/step - loss: 0.9808 - categorical_accuracy: 0.4549 - val_loss: 0.8007 - val_categorical_accuracy: 0.5850
# Epoch 23/100
# 220/220 [==============================] - ETA: 0s - loss: 0.9502 - categorical_accuracy: 0.4699
# Epoch 00023: val_categorical_accuracy did not improve from 0.58500
# 220/220 [==============================] - 106s 480ms/step - loss: 0.9502 - categorical_accuracy: 0.4699 - val_loss: 0.8161 - val_categorical_accuracy: 0.5733
# Epoch 24/100
# 220/220 [==============================] - ETA: 0s - loss: 0.9289 - categorical_accuracy: 0.4808
# Epoch 00024: val_categorical_accuracy did not improve from 0.58500
# 220/220 [==============================] - 107s 487ms/step - loss: 0.9289 - categorical_accuracy: 0.4808 - val_loss: 0.8154 - val_categorical_accuracy: 0.5737
# Epoch 25/100
# 220/220 [==============================] - ETA: 0s - loss: 0.9169 - categorical_accuracy: 0.4937
# Epoch 00025: val_categorical_accuracy did not improve from 0.58500
# 220/220 [==============================] - 107s 486ms/step - loss: 0.9169 - categorical_accuracy: 0.4937 - val_loss: 0.8032 - val_categorical_accuracy: 0.5797
# Epoch 26/100
# 220/220 [==============================] - ETA: 0s - loss: 0.8887 - categorical_accuracy: 0.5097
# Epoch 00026: val_categorical_accuracy did not improve from 0.58500
# 220/220 [==============================] - 106s 481ms/step - loss: 0.8887 - categorical_accuracy: 0.5097 - val_loss: 0.8038 - val_categorical_accuracy: 0.5800
# Epoch 27/100
# 220/220 [==============================] - ETA: 0s - loss: 0.8647 - categorical_accuracy: 0.5262
# Epoch 00027: val_categorical_accuracy did not improve from 0.58500
# 220/220 [==============================] - 108s 490ms/step - loss: 0.8647 - categorical_accuracy: 0.5262 - val_loss: 0.8040 - val_categorical_accuracy: 0.5720
# Epoch 28/100
# 220/220 [==============================] - ETA: 0s - loss: 0.8435 - categorical_accuracy: 0.5405
# Epoch 00028: val_categorical_accuracy did not improve from 0.58500
# 220/220 [==============================] - 107s 488ms/step - loss: 0.8435 - categorical_accuracy: 0.5405 - val_loss: 0.8125 - val_categorical_accuracy: 0.5753
# Epoch 29/100
# 220/220 [==============================] - ETA: 0s - loss: 0.8305 - categorical_accuracy: 0.5460
# Epoch 00029: val_categorical_accuracy did not improve from 0.58500
# 220/220 [==============================] - 106s 482ms/step - loss: 0.8305 - categorical_accuracy: 0.5460 - val_loss: 0.8000 - val_categorical_accuracy: 0.5783
# Epoch 30/100
# 220/220 [==============================] - ETA: 0s - loss: 0.8091 - categorical_accuracy: 0.5618
# Epoch 00030: val_categorical_accuracy did not improve from 0.58500
# 220/220 [==============================] - 106s 483ms/step - loss: 0.8091 - categorical_accuracy: 0.5618 - val_loss: 0.8120 - val_categorical_accuracy: 0.5723
# Epoch 31/100
# 220/220 [==============================] - ETA: 0s - loss: 0.7894 - categorical_accuracy: 0.5741
# Epoch 00031: val_categorical_accuracy improved from 0.58500 to 0.59067, saving model to /content/drive/My Drive/SMOMI/w-lab4_4-3.hdf5
# 220/220 [==============================] - 107s 488ms/step - loss: 0.7894 - categorical_accuracy: 0.5741 - val_loss: 0.7826 - val_categorical_accuracy: 0.5907
# Epoch 32/100
# 220/220 [==============================] - ETA: 0s - loss: 0.7628 - categorical_accuracy: 0.5938
# Epoch 00032: val_categorical_accuracy did not improve from 0.59067
# 220/220 [==============================] - 106s 481ms/step - loss: 0.7628 - categorical_accuracy: 0.5938 - val_loss: 0.7883 - val_categorical_accuracy: 0.5790
# Epoch 33/100
# 220/220 [==============================] - ETA: 0s - loss: 0.7455 - categorical_accuracy: 0.6005
# Epoch 00033: val_categorical_accuracy did not improve from 0.59067
# 220/220 [==============================] - 106s 481ms/step - loss: 0.7455 - categorical_accuracy: 0.6005 - val_loss: 0.7720 - val_categorical_accuracy: 0.5827
# Epoch 34/100
# 220/220 [==============================] - ETA: 0s - loss: 0.7292 - categorical_accuracy: 0.6077
# Epoch 00034: val_categorical_accuracy did not improve from 0.59067
# 220/220 [==============================] - 106s 481ms/step - loss: 0.7292 - categorical_accuracy: 0.6077 - val_loss: 0.7688 - val_categorical_accuracy: 0.5833
# Epoch 35/100
# 220/220 [==============================] - ETA: 0s - loss: 0.6967 - categorical_accuracy: 0.6263
# Epoch 00035: val_categorical_accuracy did not improve from 0.59067
# 220/220 [==============================] - 106s 482ms/step - loss: 0.6967 - categorical_accuracy: 0.6263 - val_loss: 0.7660 - val_categorical_accuracy: 0.5890
# Epoch 36/100
# 220/220 [==============================] - ETA: 0s - loss: 0.6841 - categorical_accuracy: 0.6373
# Epoch 00036: val_categorical_accuracy improved from 0.59067 to 0.59100, saving model to /content/drive/My Drive/SMOMI/w-lab4_4-3.hdf5
# 220/220 [==============================] - 107s 487ms/step - loss: 0.6841 - categorical_accuracy: 0.6373 - val_loss: 0.7474 - val_categorical_accuracy: 0.5910
# Epoch 37/100
# 220/220 [==============================] - ETA: 0s - loss: 0.6597 - categorical_accuracy: 0.6494
# Epoch 00037: val_categorical_accuracy improved from 0.59100 to 0.59700, saving model to /content/drive/My Drive/SMOMI/w-lab4_4-3.hdf5
# 220/220 [==============================] - 107s 487ms/step - loss: 0.6597 - categorical_accuracy: 0.6494 - val_loss: 0.7334 - val_categorical_accuracy: 0.5970
# Epoch 38/100
# 220/220 [==============================] - ETA: 0s - loss: 0.6404 - categorical_accuracy: 0.6531
# Epoch 00038: val_categorical_accuracy did not improve from 0.59700
# 220/220 [==============================] - 107s 486ms/step - loss: 0.6404 - categorical_accuracy: 0.6531 - val_loss: 0.7423 - val_categorical_accuracy: 0.5743
# Epoch 39/100
# 220/220 [==============================] - ETA: 0s - loss: 0.6230 - categorical_accuracy: 0.6665
# Epoch 00039: val_categorical_accuracy improved from 0.59700 to 0.60333, saving model to /content/drive/My Drive/SMOMI/w-lab4_4-3.hdf5
# 220/220 [==============================] - 107s 485ms/step - loss: 0.6230 - categorical_accuracy: 0.6665 - val_loss: 0.7206 - val_categorical_accuracy: 0.6033
# Epoch 40/100
# 220/220 [==============================] - ETA: 0s - loss: 0.6139 - categorical_accuracy: 0.6682
# Epoch 00040: val_categorical_accuracy did not improve from 0.60333
# 220/220 [==============================] - 107s 487ms/step - loss: 0.6139 - categorical_accuracy: 0.6682 - val_loss: 0.7298 - val_categorical_accuracy: 0.5800
# Epoch 41/100
# 220/220 [==============================] - ETA: 0s - loss: 0.5765 - categorical_accuracy: 0.6848
# Epoch 00041: val_categorical_accuracy improved from 0.60333 to 0.61300, saving model to /content/drive/My Drive/SMOMI/w-lab4_4-3.hdf5
# 220/220 [==============================] - 107s 488ms/step - loss: 0.5765 - categorical_accuracy: 0.6848 - val_loss: 0.6978 - val_categorical_accuracy: 0.6130
# Epoch 42/100
# 220/220 [==============================] - ETA: 0s - loss: 0.5652 - categorical_accuracy: 0.6890
# Epoch 00042: val_categorical_accuracy did not improve from 0.61300
# 220/220 [==============================] - 106s 480ms/step - loss: 0.5652 - categorical_accuracy: 0.6890 - val_loss: 0.6952 - val_categorical_accuracy: 0.6053
# Epoch 43/100
# 220/220 [==============================] - ETA: 0s - loss: 0.5375 - categorical_accuracy: 0.7056
# Epoch 00043: val_categorical_accuracy improved from 0.61300 to 0.62800, saving model to /content/drive/My Drive/SMOMI/w-lab4_4-3.hdf5
# 220/220 [==============================] - 107s 488ms/step - loss: 0.5375 - categorical_accuracy: 0.7056 - val_loss: 0.6588 - val_categorical_accuracy: 0.6280
# Epoch 44/100
# 220/220 [==============================] - ETA: 0s - loss: 0.5265 - categorical_accuracy: 0.7046
# Epoch 00044: val_categorical_accuracy improved from 0.62800 to 0.64167, saving model to /content/drive/My Drive/SMOMI/w-lab4_4-3.hdf5
# 220/220 [==============================] - 108s 489ms/step - loss: 0.5265 - categorical_accuracy: 0.7046 - val_loss: 0.6456 - val_categorical_accuracy: 0.6417
# Epoch 45/100
# 220/220 [==============================] - ETA: 0s - loss: 0.5103 - categorical_accuracy: 0.7104
# Epoch 00045: val_categorical_accuracy did not improve from 0.64167
# 220/220 [==============================] - 107s 487ms/step - loss: 0.5103 - categorical_accuracy: 0.7104 - val_loss: 0.6554 - val_categorical_accuracy: 0.6257
# Epoch 46/100
# 220/220 [==============================] - ETA: 0s - loss: 0.4950 - categorical_accuracy: 0.7185
# Epoch 00046: val_categorical_accuracy did not improve from 0.64167
# 220/220 [==============================] - 106s 482ms/step - loss: 0.4950 - categorical_accuracy: 0.7185 - val_loss: 0.6688 - val_categorical_accuracy: 0.6223
# Epoch 47/100
# 220/220 [==============================] - ETA: 0s - loss: 0.4803 - categorical_accuracy: 0.7233
# Epoch 00047: val_categorical_accuracy did not improve from 0.64167
# 220/220 [==============================] - 106s 482ms/step - loss: 0.4803 - categorical_accuracy: 0.7233 - val_loss: 0.6516 - val_categorical_accuracy: 0.6213
# Epoch 48/100
# 220/220 [==============================] - ETA: 0s - loss: 0.4554 - categorical_accuracy: 0.7362
# Epoch 00048: val_categorical_accuracy did not improve from 0.64167
# 220/220 [==============================] - 106s 482ms/step - loss: 0.4554 - categorical_accuracy: 0.7362 - val_loss: 0.6286 - val_categorical_accuracy: 0.6307
# Epoch 49/100
# 220/220 [==============================] - ETA: 0s - loss: 0.4451 - categorical_accuracy: 0.7408
# Epoch 00049: val_categorical_accuracy improved from 0.64167 to 0.64833, saving model to /content/drive/My Drive/SMOMI/w-lab4_4-3.hdf5
# 220/220 [==============================] - 107s 488ms/step - loss: 0.4451 - categorical_accuracy: 0.7408 - val_loss: 0.5975 - val_categorical_accuracy: 0.6483
# Epoch 50/100
# 220/220 [==============================] - ETA: 0s - loss: 0.4215 - categorical_accuracy: 0.7450
# Epoch 00050: val_categorical_accuracy did not improve from 0.64833
# 220/220 [==============================] - 107s 484ms/step - loss: 0.4215 - categorical_accuracy: 0.7450 - val_loss: 0.6332 - val_categorical_accuracy: 0.6360
# Epoch 51/100
# 220/220 [==============================] - ETA: 0s - loss: 0.4191 - categorical_accuracy: 0.7448
# Epoch 00051: val_categorical_accuracy did not improve from 0.64833
# 220/220 [==============================] - 106s 482ms/step - loss: 0.4191 - categorical_accuracy: 0.7448 - val_loss: 0.6127 - val_categorical_accuracy: 0.6287
# Epoch 52/100
# 220/220 [==============================] - ETA: 0s - loss: 0.4051 - categorical_accuracy: 0.7505
# Epoch 00052: val_categorical_accuracy did not improve from 0.64833
# 220/220 [==============================] - 106s 481ms/step - loss: 0.4051 - categorical_accuracy: 0.7505 - val_loss: 0.5887 - val_categorical_accuracy: 0.6377
# Epoch 53/100
# 220/220 [==============================] - ETA: 0s - loss: 0.3895 - categorical_accuracy: 0.7565
# Epoch 00053: val_categorical_accuracy improved from 0.64833 to 0.65267, saving model to /content/drive/My Drive/SMOMI/w-lab4_4-3.hdf5
# 220/220 [==============================] - 107s 488ms/step - loss: 0.3895 - categorical_accuracy: 0.7565 - val_loss: 0.5657 - val_categorical_accuracy: 0.6527
# Epoch 54/100
# 220/220 [==============================] - ETA: 0s - loss: 0.3777 - categorical_accuracy: 0.7593
# Epoch 00054: val_categorical_accuracy did not improve from 0.65267
# 220/220 [==============================] - 106s 482ms/step - loss: 0.3777 - categorical_accuracy: 0.7593 - val_loss: 0.5888 - val_categorical_accuracy: 0.6270
# Epoch 55/100
# 220/220 [==============================] - ETA: 0s - loss: 0.3745 - categorical_accuracy: 0.7584
# Epoch 00055: val_categorical_accuracy improved from 0.65267 to 0.66700, saving model to /content/drive/My Drive/SMOMI/w-lab4_4-3.hdf5
# 220/220 [==============================] - 108s 489ms/step - loss: 0.3745 - categorical_accuracy: 0.7584 - val_loss: 0.5501 - val_categorical_accuracy: 0.6670
# Epoch 56/100
# 220/220 [==============================] - ETA: 0s - loss: 0.3578 - categorical_accuracy: 0.7642
# Epoch 00056: val_categorical_accuracy did not improve from 0.66700
# 220/220 [==============================] - 106s 481ms/step - loss: 0.3578 - categorical_accuracy: 0.7642 - val_loss: 0.5395 - val_categorical_accuracy: 0.6663
# Epoch 57/100
# 220/220 [==============================] - ETA: 0s - loss: 0.3607 - categorical_accuracy: 0.7587
# Epoch 00057: val_categorical_accuracy did not improve from 0.66700
# 220/220 [==============================] - 105s 478ms/step - loss: 0.3607 - categorical_accuracy: 0.7587 - val_loss: 0.5608 - val_categorical_accuracy: 0.6440
# Epoch 58/100
# 220/220 [==============================] - ETA: 0s - loss: 0.3480 - categorical_accuracy: 0.7656
# Epoch 00058: val_categorical_accuracy did not improve from 0.66700
# 220/220 [==============================] - 106s 482ms/step - loss: 0.3480 - categorical_accuracy: 0.7656 - val_loss: 0.5656 - val_categorical_accuracy: 0.6420
# Epoch 59/100
# 220/220 [==============================] - ETA: 0s - loss: 0.3414 - categorical_accuracy: 0.7631
# Epoch 00059: val_categorical_accuracy did not improve from 0.66700
# 220/220 [==============================] - 107s 485ms/step - loss: 0.3414 - categorical_accuracy: 0.7631 - val_loss: 0.5730 - val_categorical_accuracy: 0.6300
# Epoch 60/100
# 220/220 [==============================] - ETA: 0s - loss: 0.3413 - categorical_accuracy: 0.7644
# Epoch 00060: val_categorical_accuracy did not improve from 0.66700
# 220/220 [==============================] - 106s 480ms/step - loss: 0.3413 - categorical_accuracy: 0.7644 - val_loss: 0.5570 - val_categorical_accuracy: 0.6400
# Epoch 61/100
# 220/220 [==============================] - ETA: 0s - loss: 0.3279 - categorical_accuracy: 0.7665
# Epoch 00061: val_categorical_accuracy improved from 0.66700 to 0.66767, saving model to /content/drive/My Drive/SMOMI/w-lab4_4-3.hdf5
# 220/220 [==============================] - 107s 486ms/step - loss: 0.3279 - categorical_accuracy: 0.7665 - val_loss: 0.5290 - val_categorical_accuracy: 0.6677
# Epoch 62/100
# 220/220 [==============================] - ETA: 0s - loss: 0.3182 - categorical_accuracy: 0.7674
# Epoch 00062: val_categorical_accuracy improved from 0.66767 to 0.67167, saving model to /content/drive/My Drive/SMOMI/w-lab4_4-3.hdf5
# 220/220 [==============================] - 107s 488ms/step - loss: 0.3182 - categorical_accuracy: 0.7674 - val_loss: 0.5040 - val_categorical_accuracy: 0.6717
# Epoch 63/100
# 220/220 [==============================] - ETA: 0s - loss: 0.3160 - categorical_accuracy: 0.7666
# Epoch 00063: val_categorical_accuracy did not improve from 0.67167
# 220/220 [==============================] - 106s 480ms/step - loss: 0.3160 - categorical_accuracy: 0.7666 - val_loss: 0.5083 - val_categorical_accuracy: 0.6690
# Epoch 64/100
# 220/220 [==============================] - ETA: 0s - loss: 0.3099 - categorical_accuracy: 0.7690
# Epoch 00064: val_categorical_accuracy did not improve from 0.67167
# 220/220 [==============================] - 106s 481ms/step - loss: 0.3099 - categorical_accuracy: 0.7690 - val_loss: 0.5275 - val_categorical_accuracy: 0.6633
# Epoch 65/100
# 220/220 [==============================] - ETA: 0s - loss: 0.3030 - categorical_accuracy: 0.7703
# Epoch 00065: val_categorical_accuracy improved from 0.67167 to 0.67400, saving model to /content/drive/My Drive/SMOMI/w-lab4_4-3.hdf5
# 220/220 [==============================] - 108s 490ms/step - loss: 0.3030 - categorical_accuracy: 0.7703 - val_loss: 0.4975 - val_categorical_accuracy: 0.6740
# Epoch 66/100
# 220/220 [==============================] - ETA: 0s - loss: 0.2842 - categorical_accuracy: 0.7745
# Epoch 00066: val_categorical_accuracy did not improve from 0.67400
# 220/220 [==============================] - 107s 487ms/step - loss: 0.2842 - categorical_accuracy: 0.7745 - val_loss: 0.5067 - val_categorical_accuracy: 0.6657
# Epoch 67/100
# 220/220 [==============================] - ETA: 0s - loss: 0.2882 - categorical_accuracy: 0.7732
# Epoch 00067: val_categorical_accuracy did not improve from 0.67400
# 220/220 [==============================] - 107s 485ms/step - loss: 0.2882 - categorical_accuracy: 0.7732 - val_loss: 0.5027 - val_categorical_accuracy: 0.6633
# Epoch 68/100
# 220/220 [==============================] - ETA: 0s - loss: 0.2778 - categorical_accuracy: 0.7761
# Epoch 00068: val_categorical_accuracy did not improve from 0.67400
# 220/220 [==============================] - 108s 489ms/step - loss: 0.2778 - categorical_accuracy: 0.7761 - val_loss: 0.5032 - val_categorical_accuracy: 0.6603
# Epoch 69/100
# 220/220 [==============================] - ETA: 0s - loss: 0.2687 - categorical_accuracy: 0.7803
# Epoch 00069: val_categorical_accuracy improved from 0.67400 to 0.68133, saving model to /content/drive/My Drive/SMOMI/w-lab4_4-3.hdf5
# 220/220 [==============================] - 108s 492ms/step - loss: 0.2687 - categorical_accuracy: 0.7803 - val_loss: 0.4861 - val_categorical_accuracy: 0.6813
# Epoch 70/100
# 220/220 [==============================] - ETA: 0s - loss: 0.2748 - categorical_accuracy: 0.7718
# Epoch 00070: val_categorical_accuracy did not improve from 0.68133
# 220/220 [==============================] - 107s 485ms/step - loss: 0.2748 - categorical_accuracy: 0.7718 - val_loss: 0.5020 - val_categorical_accuracy: 0.6563
# Epoch 71/100
# 220/220 [==============================] - ETA: 0s - loss: 0.2661 - categorical_accuracy: 0.7765
# Epoch 00071: val_categorical_accuracy did not improve from 0.68133
# 220/220 [==============================] - 108s 489ms/step - loss: 0.2661 - categorical_accuracy: 0.7765 - val_loss: 0.4817 - val_categorical_accuracy: 0.6680
# Epoch 72/100
# 220/220 [==============================] - ETA: 0s - loss: 0.2649 - categorical_accuracy: 0.7758
# Epoch 00072: val_categorical_accuracy did not improve from 0.68133
# 220/220 [==============================] - 108s 491ms/step - loss: 0.2649 - categorical_accuracy: 0.7758 - val_loss: 0.4944 - val_categorical_accuracy: 0.6577
# Epoch 73/100
# 220/220 [==============================] - ETA: 0s - loss: 0.2545 - categorical_accuracy: 0.7801
# Epoch 00073: val_categorical_accuracy did not improve from 0.68133
# 220/220 [==============================] - 108s 489ms/step - loss: 0.2545 - categorical_accuracy: 0.7801 - val_loss: 0.4708 - val_categorical_accuracy: 0.6640
# Epoch 74/100
# 220/220 [==============================] - ETA: 0s - loss: 0.2539 - categorical_accuracy: 0.7764
# Epoch 00074: val_categorical_accuracy did not improve from 0.68133
# 220/220 [==============================] - 108s 493ms/step - loss: 0.2539 - categorical_accuracy: 0.7764 - val_loss: 0.4928 - val_categorical_accuracy: 0.6627
# Epoch 75/100
# 220/220 [==============================] - ETA: 0s - loss: 0.2497 - categorical_accuracy: 0.7819
# Epoch 00075: val_categorical_accuracy did not improve from 0.68133
# 220/220 [==============================] - 108s 490ms/step - loss: 0.2497 - categorical_accuracy: 0.7819 - val_loss: 0.4986 - val_categorical_accuracy: 0.6623
# Epoch 76/100
# 220/220 [==============================] - ETA: 0s - loss: 0.2527 - categorical_accuracy: 0.7769
# Epoch 00076: val_categorical_accuracy did not improve from 0.68133
# 220/220 [==============================] - 108s 492ms/step - loss: 0.2527 - categorical_accuracy: 0.7769 - val_loss: 0.4960 - val_categorical_accuracy: 0.6670
# Epoch 77/100
# 220/220 [==============================] - ETA: 0s - loss: 0.2463 - categorical_accuracy: 0.7779
# Epoch 00077: val_categorical_accuracy did not improve from 0.68133
# 220/220 [==============================] - 109s 495ms/step - loss: 0.2463 - categorical_accuracy: 0.7779 - val_loss: 0.4781 - val_categorical_accuracy: 0.6623
# Epoch 78/100
# 220/220 [==============================] - ETA: 0s - loss: 0.2372 - categorical_accuracy: 0.7825
# Epoch 00078: val_categorical_accuracy did not improve from 0.68133
# 220/220 [==============================] - 108s 490ms/step - loss: 0.2372 - categorical_accuracy: 0.7825 - val_loss: 0.4833 - val_categorical_accuracy: 0.6653
# Epoch 79/100
# 220/220 [==============================] - ETA: 0s - loss: 0.2407 - categorical_accuracy: 0.7800
# Epoch 00079: val_categorical_accuracy did not improve from 0.68133
# 220/220 [==============================] - 108s 490ms/step - loss: 0.2407 - categorical_accuracy: 0.7800 - val_loss: 0.4976 - val_categorical_accuracy: 0.6697
# Epoch 80/100
# 220/220 [==============================] - ETA: 0s - loss: 0.2449 - categorical_accuracy: 0.7800
# Epoch 00080: val_categorical_accuracy improved from 0.68133 to 0.68900, saving model to /content/drive/My Drive/SMOMI/w-lab4_4-3.hdf5
# 220/220 [==============================] - 111s 505ms/step - loss: 0.2449 - categorical_accuracy: 0.7800 - val_loss: 0.4394 - val_categorical_accuracy: 0.6890
# Epoch 81/100
# 220/220 [==============================] - ETA: 0s - loss: 0.2376 - categorical_accuracy: 0.7811
# Epoch 00081: val_categorical_accuracy did not improve from 0.68900
# 220/220 [==============================] - 108s 492ms/step - loss: 0.2376 - categorical_accuracy: 0.7811 - val_loss: 0.4911 - val_categorical_accuracy: 0.6587
# Epoch 82/100
# 220/220 [==============================] - ETA: 0s - loss: 0.2347 - categorical_accuracy: 0.7800
# Epoch 00082: val_categorical_accuracy did not improve from 0.68900
# 220/220 [==============================] - 109s 493ms/step - loss: 0.2347 - categorical_accuracy: 0.7800 - val_loss: 0.4562 - val_categorical_accuracy: 0.6683
# Epoch 83/100
# 220/220 [==============================] - ETA: 0s - loss: 0.2245 - categorical_accuracy: 0.7834
# Epoch 00083: val_categorical_accuracy did not improve from 0.68900
# 220/220 [==============================] - 109s 494ms/step - loss: 0.2245 - categorical_accuracy: 0.7834 - val_loss: 0.4658 - val_categorical_accuracy: 0.6830
# Epoch 84/100
# 220/220 [==============================] - ETA: 0s - loss: 0.2283 - categorical_accuracy: 0.7817
# Epoch 00084: val_categorical_accuracy did not improve from 0.68900
# 220/220 [==============================] - 108s 492ms/step - loss: 0.2283 - categorical_accuracy: 0.7817 - val_loss: 0.4450 - val_categorical_accuracy: 0.6880
# Epoch 85/100
# 220/220 [==============================] - ETA: 0s - loss: 0.2203 - categorical_accuracy: 0.7845
# Epoch 00085: val_categorical_accuracy did not improve from 0.68900
# 220/220 [==============================] - 108s 492ms/step - loss: 0.2203 - categorical_accuracy: 0.7845 - val_loss: 0.4852 - val_categorical_accuracy: 0.6673
# Epoch 86/100
# 220/220 [==============================] - ETA: 0s - loss: 0.2229 - categorical_accuracy: 0.7842
# Epoch 00086: val_categorical_accuracy did not improve from 0.68900
# 220/220 [==============================] - 107s 487ms/step - loss: 0.2229 - categorical_accuracy: 0.7842 - val_loss: 0.4495 - val_categorical_accuracy: 0.6753
# Epoch 87/100
# 220/220 [==============================] - ETA: 0s - loss: 0.2236 - categorical_accuracy: 0.7810
# Epoch 00087: val_categorical_accuracy did not improve from 0.68900
# 220/220 [==============================] - 107s 487ms/step - loss: 0.2236 - categorical_accuracy: 0.7810 - val_loss: 0.4643 - val_categorical_accuracy: 0.6783
# Epoch 88/100
# 220/220 [==============================] - ETA: 0s - loss: 0.2311 - categorical_accuracy: 0.7778
# Epoch 00088: val_categorical_accuracy did not improve from 0.68900
# 220/220 [==============================] - 107s 486ms/step - loss: 0.2311 - categorical_accuracy: 0.7778 - val_loss: 0.4598 - val_categorical_accuracy: 0.6880
# Epoch 89/100
# 220/220 [==============================] - ETA: 0s - loss: 0.2126 - categorical_accuracy: 0.7827
# Epoch 00089: val_categorical_accuracy improved from 0.68900 to 0.68967, saving model to /content/drive/My Drive/SMOMI/w-lab4_4-3.hdf5
# 220/220 [==============================] - 108s 493ms/step - loss: 0.2126 - categorical_accuracy: 0.7827 - val_loss: 0.4359 - val_categorical_accuracy: 0.6897
# Epoch 90/100
# 220/220 [==============================] - ETA: 0s - loss: 0.2012 - categorical_accuracy: 0.7893
# Epoch 00090: val_categorical_accuracy did not improve from 0.68967
# 220/220 [==============================] - 107s 485ms/step - loss: 0.2012 - categorical_accuracy: 0.7893 - val_loss: 0.4439 - val_categorical_accuracy: 0.6830
# Epoch 91/100
# 220/220 [==============================] - ETA: 0s - loss: 0.2041 - categorical_accuracy: 0.7883
# Epoch 00091: val_categorical_accuracy did not improve from 0.68967
# 220/220 [==============================] - 106s 484ms/step - loss: 0.2041 - categorical_accuracy: 0.7883 - val_loss: 0.4744 - val_categorical_accuracy: 0.6770
# Epoch 92/100
# 220/220 [==============================] - ETA: 0s - loss: 0.2028 - categorical_accuracy: 0.7874
# Epoch 00092: val_categorical_accuracy did not improve from 0.68967
# 220/220 [==============================] - 106s 483ms/step - loss: 0.2028 - categorical_accuracy: 0.7874 - val_loss: 0.4932 - val_categorical_accuracy: 0.6460
# Epoch 93/100
# 220/220 [==============================] - ETA: 0s - loss: 0.2099 - categorical_accuracy: 0.7870
# Epoch 00093: val_categorical_accuracy did not improve from 0.68967
# 220/220 [==============================] - 106s 481ms/step - loss: 0.2099 - categorical_accuracy: 0.7870 - val_loss: 0.4933 - val_categorical_accuracy: 0.6590
# Epoch 94/100
# 220/220 [==============================] - ETA: 0s - loss: 0.1925 - categorical_accuracy: 0.7920
# Epoch 00094: val_categorical_accuracy did not improve from 0.68967
# 220/220 [==============================] - 107s 485ms/step - loss: 0.1925 - categorical_accuracy: 0.7920 - val_loss: 0.4690 - val_categorical_accuracy: 0.6547
# Epoch 95/100
# 220/220 [==============================] - ETA: 0s - loss: 0.1981 - categorical_accuracy: 0.7864
# Epoch 00095: val_categorical_accuracy did not improve from 0.68967
# 220/220 [==============================] - 107s 487ms/step - loss: 0.1981 - categorical_accuracy: 0.7864 - val_loss: 0.4422 - val_categorical_accuracy: 0.6803
# Epoch 96/100
# 220/220 [==============================] - ETA: 0s - loss: 0.1893 - categorical_accuracy: 0.7908
# Epoch 00096: val_categorical_accuracy did not improve from 0.68967
# 220/220 [==============================] - 108s 493ms/step - loss: 0.1893 - categorical_accuracy: 0.7908 - val_loss: 0.4427 - val_categorical_accuracy: 0.6887
# Epoch 97/100
# 220/220 [==============================] - ETA: 0s - loss: 0.1907 - categorical_accuracy: 0.7892
# Epoch 00097: val_categorical_accuracy improved from 0.68967 to 0.71433, saving model to /content/drive/My Drive/SMOMI/w-lab4_4-3.hdf5
# 220/220 [==============================] - 108s 493ms/step - loss: 0.1907 - categorical_accuracy: 0.7892 - val_loss: 0.3892 - val_categorical_accuracy: 0.7143
# Epoch 98/100
# 220/220 [==============================] - ETA: 0s - loss: 0.1814 - categorical_accuracy: 0.7894
# Epoch 00098: val_categorical_accuracy did not improve from 0.71433
# 220/220 [==============================] - 107s 486ms/step - loss: 0.1814 - categorical_accuracy: 0.7894 - val_loss: 0.4804 - val_categorical_accuracy: 0.6463
# Epoch 99/100
# 220/220 [==============================] - ETA: 0s - loss: 0.1828 - categorical_accuracy: 0.7926
# Epoch 00099: val_categorical_accuracy did not improve from 0.71433
# 220/220 [==============================] - 108s 490ms/step - loss: 0.1828 - categorical_accuracy: 0.7926 - val_loss: 0.4419 - val_categorical_accuracy: 0.6887
# Epoch 100/100
# 220/220 [==============================] - ETA: 0s - loss: 0.1811 - categorical_accuracy: 0.7911
# Epoch 00100: val_categorical_accuracy did not improve from 0.71433
# 220/220 [==============================] - 107s 488ms/step - loss: 0.1811 - categorical_accuracy: 0.7911 - val_loss: 0.4078 - val_categorical_accuracy: 0.6823

# %%
__author__ = 'Alexander Soroka, soroka.a.m@gmail.com'
__copyright__ = """Copyright 2020 Alexander Soroka"""


import argparse
import glob
import numpy as np
import tensorflow as tf
import time
from tensorflow.python import keras as keras
from tensorflow.python.keras.callbacks import LearningRateScheduler

import tensorflow_addons as tfa


LOG_DIR = 'logs'
SHUFFLE_BUFFER = 4
BATCH_SIZE = 32
NUM_CLASSES = 6
PARALLEL_CALLS=4
RESIZE_TO = 224
TRAINSET_SIZE = 14034
VALSET_SIZE = 3000


def parse_proto_example(proto):
    keys_to_features = {
        'image/encoded': tf.io.FixedLenFeature((), tf.string, default_value=''),
        'image/class/label': tf.io.FixedLenFeature([], tf.int64, default_value=tf.zeros([], dtype=tf.int64))
    }
    example = tf.io.parse_single_example(proto, keys_to_features)
    example['image'] = tf.image.decode_jpeg(example['image/encoded'], channels=3)
    example['image'] = tf.image.convert_image_dtype(example['image'], dtype=tf.float32)
    example['image'] = tf.image.resize(example['image'], tf.constant([RESIZE_TO, RESIZE_TO]))
    return example['image'], tf.one_hot(example['image/class/label'], depth=NUM_CLASSES)


def normalize(image, label):
    return tf.image.per_image_standardization(image), label

def resize(image, label):
    return tf.image.resize(image, tf.constant([RESIZE_TO, RESIZE_TO])), label

def augmentation(image, label):
    image = tf.image.convert_image_dtype(image, tf.float32)
    image = tf.image.random_brightness(image, 0.1, seed=None)
    image = tf.image.random_contrast(image, 0.7, 1.4, seed=None)
    return image, label

def create_dataset(filenames, batch_size):
    """Create dataset from tfrecords file
    :tfrecords_files: Mask to collect tfrecords file of dataset
    :returns: tf.data.Dataset
    """
    return tf.data.TFRecordDataset(filenames)\
        .map(parse_proto_example)\
        .map(resize)\
        .map(normalize)\
        .batch(batch_size)\
        .prefetch(batch_size)

def create_aug_dataset(filenames, batch_size):
    """Create dataset from tfrecords file
    :tfrecords_files: Mask to collect tfrecords file of dataset
    :returns: tf.data.Dataset
    """
    return tf.data.TFRecordDataset(filenames)\
        .map(parse_proto_example)\
        .map(augmentation)\
        .map(resize)\
        .map(normalize)\
        .shuffle(buffer_size=5 * batch_size)\
        .batch(batch_size)\
        .prefetch(2 * batch_size)


def build_model():
    new_model = tf.keras.applications.MobileNetV2(input_shape=(224,224,3),
						classes = NUM_CLASSES,
            include_top=False,
            weights='imagenet')
    
    return tf.keras.models.Sequential([
    	new_model,
      tf.keras.layers.GlobalAveragePooling2D(),
      tf.keras.layers.Dropout(0.2),
    	tf.keras.layers.Flatten(),
      tf.keras.layers.Dense(NUM_CLASSES, activation=tf.keras.activations.softmax)
    ])


def main():
    #args = argparse.ArgumentParser()
    #args.add_argument('--train', type=str, help='Glob pattern to collect train tfrecord files')
    #args.add_argument('--test', type=str, help='Glob pattern to collect test tfrecord files')
    #args = args.parse_args()
    train_path = '/content/drive/My Drive/SMOMI/dataset/train*'
    test_path = '/content/drive/My Drive/SMOMI/dataset/val*'

    train_dataset = create_aug_dataset(glob.glob(train_path), BATCH_SIZE)
    validation_dataset = create_dataset(glob.glob(test_path), BATCH_SIZE)

    model = build_model()

    model.compile(
        optimizer=tf.optimizers.Adam(lr=4e-6),
        loss=tf.keras.losses.categorical_crossentropy,
        metrics=[tf.keras.metrics.categorical_accuracy],
    )

    log_dir='/content/drive/My Drive/SMOMI/{}/lab4_3-2/ilcd-{}'.format(LOG_DIR, time.time())
    weights_file = "/content/drive/My Drive/SMOMI/w-4_3-2.hdf5"

    model.fit(
        train_dataset,
        epochs=100,
        validation_data=validation_dataset,
        callbacks=[
            tf.keras.callbacks.TensorBoard(log_dir),
            tf.keras.callbacks.ModelCheckpoint(filepath=weights_file, monitor='val_categorical_accuracy', mode='max', save_best_only=True, save_weights_only=True, verbose=1)
        ]
    )


if __name__ == '__main__':
    main()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9412608/9406464 [==============================] - 0s 0us/step
# Epoch 1/100
#       1/Unknown - 0s 713us/step - loss: 1.9911 - categorical_accuracy: 0.1875WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/summary_ops_v2.py:1277: stop (from tensorflow.python.eager.profiler) is deprecated and will be removed after 2020-07-01.
# Instructions for updating:
# use `tf.profiler.experimental.stop` instead.
#       2/Unknown - 1s 308ms/step - loss: 1.9833 - categorical_accuracy: 0.2031WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0977s vs `on_train_batch_end` time: 0.5169s). Check your callbacks.
#     439/Unknown - 91s 207ms/step - loss: 1.6350 - categorical_accuracy: 0.1632
# Epoch 00001: val_categorical_accuracy improved from -inf to 0.31200, saving model to /content/drive/My Drive/SMOMI/w-4_3-2.hdf5
# 439/439 [==============================] - 106s 242ms/step - loss: 1.6350 - categorical_accuracy: 0.1632 - val_loss: 1.5091 - val_categorical_accuracy: 0.3120
# Epoch 2/100
# 439/439 [==============================] - ETA: 0s - loss: 1.4666 - categorical_accuracy: 0.2121
# Epoch 00002: val_categorical_accuracy improved from 0.31200 to 0.43333, saving model to /content/drive/My Drive/SMOMI/w-4_3-2.hdf5
# 439/439 [==============================] - 99s 226ms/step - loss: 1.4666 - categorical_accuracy: 0.2121 - val_loss: 1.2034 - val_categorical_accuracy: 0.4333
# Epoch 3/100
# 439/439 [==============================] - ETA: 0s - loss: 1.3812 - categorical_accuracy: 0.2458
# Epoch 00003: val_categorical_accuracy improved from 0.43333 to 0.49067, saving model to /content/drive/My Drive/SMOMI/w-4_3-2.hdf5
# 439/439 [==============================] - 98s 222ms/step - loss: 1.3812 - categorical_accuracy: 0.2458 - val_loss: 1.0178 - val_categorical_accuracy: 0.4907
# Epoch 4/100
# 439/439 [==============================] - ETA: 0s - loss: 1.3093 - categorical_accuracy: 0.2788
# Epoch 00004: val_categorical_accuracy improved from 0.49067 to 0.52167, saving model to /content/drive/My Drive/SMOMI/w-4_3-2.hdf5
# 439/439 [==============================] - 99s 225ms/step - loss: 1.3093 - categorical_accuracy: 0.2788 - val_loss: 0.9122 - val_categorical_accuracy: 0.5217
# Epoch 5/100
# 439/439 [==============================] - ETA: 0s - loss: 1.2254 - categorical_accuracy: 0.3237
# Epoch 00005: val_categorical_accuracy improved from 0.52167 to 0.55367, saving model to /content/drive/My Drive/SMOMI/w-4_3-2.hdf5
# 439/439 [==============================] - 100s 227ms/step - loss: 1.2254 - categorical_accuracy: 0.3237 - val_loss: 0.8522 - val_categorical_accuracy: 0.5537
# Epoch 6/100
# 439/439 [==============================] - ETA: 0s - loss: 1.1306 - categorical_accuracy: 0.3777
# Epoch 00006: val_categorical_accuracy improved from 0.55367 to 0.57800, saving model to /content/drive/My Drive/SMOMI/w-4_3-2.hdf5
# 439/439 [==============================] - 98s 223ms/step - loss: 1.1306 - categorical_accuracy: 0.3777 - val_loss: 0.8131 - val_categorical_accuracy: 0.5780
# Epoch 7/100
# 439/439 [==============================] - ETA: 0s - loss: 1.0373 - categorical_accuracy: 0.4203
# Epoch 00007: val_categorical_accuracy improved from 0.57800 to 0.59167, saving model to /content/drive/My Drive/SMOMI/w-4_3-2.hdf5
# 439/439 [==============================] - 98s 224ms/step - loss: 1.0373 - categorical_accuracy: 0.4203 - val_loss: 0.7851 - val_categorical_accuracy: 0.5917
# Epoch 8/100
# 439/439 [==============================] - ETA: 0s - loss: 0.9623 - categorical_accuracy: 0.4615
# Epoch 00008: val_categorical_accuracy improved from 0.59167 to 0.60567, saving model to /content/drive/My Drive/SMOMI/w-4_3-2.hdf5
# 439/439 [==============================] - 99s 225ms/step - loss: 0.9623 - categorical_accuracy: 0.4615 - val_loss: 0.7668 - val_categorical_accuracy: 0.6057
# Epoch 9/100
# 439/439 [==============================] - ETA: 0s - loss: 0.8909 - categorical_accuracy: 0.5006
# Epoch 00009: val_categorical_accuracy improved from 0.60567 to 0.61667, saving model to /content/drive/My Drive/SMOMI/w-4_3-2.hdf5
# 439/439 [==============================] - 98s 223ms/step - loss: 0.8909 - categorical_accuracy: 0.5006 - val_loss: 0.7489 - val_categorical_accuracy: 0.6167
# Epoch 10/100
# 439/439 [==============================] - ETA: 0s - loss: 0.8245 - categorical_accuracy: 0.5393
# Epoch 00010: val_categorical_accuracy improved from 0.61667 to 0.62233, saving model to /content/drive/My Drive/SMOMI/w-4_3-2.hdf5
# 439/439 [==============================] - 98s 224ms/step - loss: 0.8245 - categorical_accuracy: 0.5393 - val_loss: 0.7387 - val_categorical_accuracy: 0.6223
# Epoch 11/100
# 439/439 [==============================] - ETA: 0s - loss: 0.7637 - categorical_accuracy: 0.5737
# Epoch 00011: val_categorical_accuracy improved from 0.62233 to 0.63100, saving model to /content/drive/My Drive/SMOMI/w-4_3-2.hdf5
# 439/439 [==============================] - 99s 225ms/step - loss: 0.7637 - categorical_accuracy: 0.5737 - val_loss: 0.7279 - val_categorical_accuracy: 0.6310
# Epoch 12/100
# 439/439 [==============================] - ETA: 0s - loss: 0.7038 - categorical_accuracy: 0.6067
# Epoch 00012: val_categorical_accuracy improved from 0.63100 to 0.63367, saving model to /content/drive/My Drive/SMOMI/w-4_3-2.hdf5
# 439/439 [==============================] - 98s 222ms/step - loss: 0.7038 - categorical_accuracy: 0.6067 - val_loss: 0.7275 - val_categorical_accuracy: 0.6337
# Epoch 13/100
# 439/439 [==============================] - ETA: 0s - loss: 0.6442 - categorical_accuracy: 0.6373
# Epoch 00013: val_categorical_accuracy did not improve from 0.63367
# 439/439 [==============================] - 98s 222ms/step - loss: 0.6442 - categorical_accuracy: 0.6373 - val_loss: 0.7255 - val_categorical_accuracy: 0.6330
# Epoch 14/100
# 439/439 [==============================] - ETA: 0s - loss: 0.5985 - categorical_accuracy: 0.6560
# Epoch 00014: val_categorical_accuracy did not improve from 0.63367
# 439/439 [==============================] - 97s 222ms/step - loss: 0.5985 - categorical_accuracy: 0.6560 - val_loss: 0.7268 - val_categorical_accuracy: 0.6307
# Epoch 15/100
# 439/439 [==============================] - ETA: 0s - loss: 0.5557 - categorical_accuracy: 0.6741
# Epoch 00015: val_categorical_accuracy did not improve from 0.63367
# 439/439 [==============================] - 98s 223ms/step - loss: 0.5557 - categorical_accuracy: 0.6741 - val_loss: 0.7256 - val_categorical_accuracy: 0.6283
# Epoch 16/100
# 439/439 [==============================] - ETA: 0s - loss: 0.5123 - categorical_accuracy: 0.6982
# Epoch 00016: val_categorical_accuracy did not improve from 0.63367
# 439/439 [==============================] - 98s 224ms/step - loss: 0.5123 - categorical_accuracy: 0.6982 - val_loss: 0.7281 - val_categorical_accuracy: 0.6320
# Epoch 17/100
# 439/439 [==============================] - ETA: 0s - loss: 0.4709 - categorical_accuracy: 0.7115
# Epoch 00017: val_categorical_accuracy did not improve from 0.63367
# 439/439 [==============================] - 97s 220ms/step - loss: 0.4709 - categorical_accuracy: 0.7115 - val_loss: 0.7369 - val_categorical_accuracy: 0.6273
# Epoch 18/100
# 439/439 [==============================] - ETA: 0s - loss: 0.4401 - categorical_accuracy: 0.7297
# Epoch 00018: val_categorical_accuracy did not improve from 0.63367
# 439/439 [==============================] - 97s 221ms/step - loss: 0.4401 - categorical_accuracy: 0.7297 - val_loss: 0.7342 - val_categorical_accuracy: 0.6257
# Epoch 19/100
# 439/439 [==============================] - ETA: 0s - loss: 0.4154 - categorical_accuracy: 0.7297
# Epoch 00019: val_categorical_accuracy improved from 0.63367 to 0.63467, saving model to /content/drive/My Drive/SMOMI/w-4_3-2.hdf5
# 439/439 [==============================] - 98s 224ms/step - loss: 0.4154 - categorical_accuracy: 0.7297 - val_loss: 0.7342 - val_categorical_accuracy: 0.6347
# Epoch 20/100
# 439/439 [==============================] - ETA: 0s - loss: 0.3889 - categorical_accuracy: 0.7403
# Epoch 00020: val_categorical_accuracy did not improve from 0.63467
# 439/439 [==============================] - 98s 223ms/step - loss: 0.3889 - categorical_accuracy: 0.7403 - val_loss: 0.7432 - val_categorical_accuracy: 0.6327
# Epoch 21/100
# 439/439 [==============================] - ETA: 0s - loss: 0.3679 - categorical_accuracy: 0.7460
# Epoch 00021: val_categorical_accuracy did not improve from 0.63467
# 439/439 [==============================] - 96s 220ms/step - loss: 0.3679 - categorical_accuracy: 0.7460 - val_loss: 0.7550 - val_categorical_accuracy: 0.6290
# Epoch 22/100
# 439/439 [==============================] - ETA: 0s - loss: 0.3433 - categorical_accuracy: 0.7554
# Epoch 00022: val_categorical_accuracy did not improve from 0.63467
# 439/439 [==============================] - 96s 218ms/step - loss: 0.3433 - categorical_accuracy: 0.7554 - val_loss: 0.7663 - val_categorical_accuracy: 0.6220
# Epoch 23/100
# 439/439 [==============================] - ETA: 0s - loss: 0.3205 - categorical_accuracy: 0.7626
# Epoch 00023: val_categorical_accuracy did not improve from 0.63467
# 439/439 [==============================] - 98s 223ms/step - loss: 0.3205 - categorical_accuracy: 0.7626 - val_loss: 0.7762 - val_categorical_accuracy: 0.6257
# Epoch 24/100
# 439/439 [==============================] - ETA: 0s - loss: 0.3059 - categorical_accuracy: 0.7664
# Epoch 00024: val_categorical_accuracy did not improve from 0.63467
# 439/439 [==============================] - 97s 220ms/step - loss: 0.3059 - categorical_accuracy: 0.7664 - val_loss: 0.7822 - val_categorical_accuracy: 0.6263
# Epoch 25/100
# 439/439 [==============================] - ETA: 0s - loss: 0.2864 - categorical_accuracy: 0.7704
# Epoch 00025: val_categorical_accuracy did not improve from 0.63467
# 439/439 [==============================] - 98s 222ms/step - loss: 0.2864 - categorical_accuracy: 0.7704 - val_loss: 0.7903 - val_categorical_accuracy: 0.6250
# Epoch 26/100
# 439/439 [==============================] - ETA: 0s - loss: 0.2852 - categorical_accuracy: 0.7701
# Epoch 00026: val_categorical_accuracy did not improve from 0.63467
# 439/439 [==============================] - 96s 220ms/step - loss: 0.2852 - categorical_accuracy: 0.7701 - val_loss: 0.7867 - val_categorical_accuracy: 0.6257
# Epoch 27/100
# 439/439 [==============================] - ETA: 0s - loss: 0.2669 - categorical_accuracy: 0.7761
# Epoch 00027: val_categorical_accuracy did not improve from 0.63467
# 439/439 [==============================] - 96s 219ms/step - loss: 0.2669 - categorical_accuracy: 0.7761 - val_loss: 0.8098 - val_categorical_accuracy: 0.6143
# Epoch 28/100
# 439/439 [==============================] - ETA: 0s - loss: 0.2693 - categorical_accuracy: 0.7725
# Epoch 00028: val_categorical_accuracy did not improve from 0.63467
# 439/439 [==============================] - 96s 219ms/step - loss: 0.2693 - categorical_accuracy: 0.7725 - val_loss: 0.8159 - val_categorical_accuracy: 0.6193
# Epoch 29/100
# 439/439 [==============================] - ETA: 0s - loss: 0.2559 - categorical_accuracy: 0.7759
# Epoch 00029: val_categorical_accuracy did not improve from 0.63467
# 439/439 [==============================] - 96s 219ms/step - loss: 0.2559 - categorical_accuracy: 0.7759 - val_loss: 0.8495 - val_categorical_accuracy: 0.5990
# Epoch 30/100
# 439/439 [==============================] - ETA: 0s - loss: 0.2477 - categorical_accuracy: 0.7780
# Epoch 00030: val_categorical_accuracy did not improve from 0.63467
# 439/439 [==============================] - 96s 219ms/step - loss: 0.2477 - categorical_accuracy: 0.7780 - val_loss: 0.8295 - val_categorical_accuracy: 0.6093
# Epoch 31/100
# 439/439 [==============================] - ETA: 0s - loss: 0.2417 - categorical_accuracy: 0.7768
# Epoch 00031: val_categorical_accuracy did not improve from 0.63467
# 439/439 [==============================] - 97s 221ms/step - loss: 0.2417 - categorical_accuracy: 0.7768 - val_loss: 0.8336 - val_categorical_accuracy: 0.6040
# Epoch 32/100
# 439/439 [==============================] - ETA: 0s - loss: 0.2360 - categorical_accuracy: 0.7779
# Epoch 00032: val_categorical_accuracy did not improve from 0.63467
# 439/439 [==============================] - 97s 221ms/step - loss: 0.2360 - categorical_accuracy: 0.7779 - val_loss: 0.8408 - val_categorical_accuracy: 0.6040
# Epoch 33/100
# 439/439 [==============================] - ETA: 0s - loss: 0.2301 - categorical_accuracy: 0.7811
# Epoch 00033: val_categorical_accuracy did not improve from 0.63467
# 439/439 [==============================] - 97s 222ms/step - loss: 0.2301 - categorical_accuracy: 0.7811 - val_loss: 0.8591 - val_categorical_accuracy: 0.6007
# Epoch 34/100
# 439/439 [==============================] - ETA: 0s - loss: 0.2303 - categorical_accuracy: 0.7797
# Epoch 00034: val_categorical_accuracy did not improve from 0.63467
# 439/439 [==============================] - 98s 222ms/step - loss: 0.2303 - categorical_accuracy: 0.7797 - val_loss: 0.8529 - val_categorical_accuracy: 0.6000
# Epoch 35/100
# 439/439 [==============================] - ETA: 0s - loss: 0.2225 - categorical_accuracy: 0.7840
# Epoch 00035: val_categorical_accuracy did not improve from 0.63467
# 439/439 [==============================] - 98s 223ms/step - loss: 0.2225 - categorical_accuracy: 0.7840 - val_loss: 0.8743 - val_categorical_accuracy: 0.5870
# Epoch 36/100
# 439/439 [==============================] - ETA: 0s - loss: 0.2170 - categorical_accuracy: 0.7863
# Epoch 00036: val_categorical_accuracy did not improve from 0.63467
# 439/439 [==============================] - 97s 220ms/step - loss: 0.2170 - categorical_accuracy: 0.7863 - val_loss: 0.8602 - val_categorical_accuracy: 0.5927
# Epoch 37/100
# 439/439 [==============================] - ETA: 0s - loss: 0.2265 - categorical_accuracy: 0.7782
# Epoch 00037: val_categorical_accuracy did not improve from 0.63467
# 439/439 [==============================] - 97s 220ms/step - loss: 0.2265 - categorical_accuracy: 0.7782 - val_loss: 0.8463 - val_categorical_accuracy: 0.6100
# Epoch 38/100
# 439/439 [==============================] - ETA: 0s - loss: 0.2145 - categorical_accuracy: 0.7816
# Epoch 00038: val_categorical_accuracy did not improve from 0.63467
# 439/439 [==============================] - 97s 220ms/step - loss: 0.2145 - categorical_accuracy: 0.7816 - val_loss: 0.8407 - val_categorical_accuracy: 0.6167
# Epoch 39/100
# 439/439 [==============================] - ETA: 0s - loss: 0.2110 - categorical_accuracy: 0.7834
# Epoch 00039: val_categorical_accuracy did not improve from 0.63467
# 439/439 [==============================] - 97s 222ms/step - loss: 0.2110 - categorical_accuracy: 0.7834 - val_loss: 0.8628 - val_categorical_accuracy: 0.5983
# Epoch 40/100
# 439/439 [==============================] - ETA: 0s - loss: 0.1983 - categorical_accuracy: 0.7870
# Epoch 00040: val_categorical_accuracy did not improve from 0.63467
# 439/439 [==============================] - 97s 221ms/step - loss: 0.1983 - categorical_accuracy: 0.7870 - val_loss: 0.8217 - val_categorical_accuracy: 0.6197
# Epoch 41/100
# 439/439 [==============================] - ETA: 0s - loss: 0.2014 - categorical_accuracy: 0.7848
# Epoch 00041: val_categorical_accuracy did not improve from 0.63467
# 439/439 [==============================] - 98s 223ms/step - loss: 0.2014 - categorical_accuracy: 0.7848 - val_loss: 0.8208 - val_categorical_accuracy: 0.6293
# Epoch 42/100
# 439/439 [==============================] - ETA: 0s - loss: 0.1909 - categorical_accuracy: 0.7909
# Epoch 00042: val_categorical_accuracy did not improve from 0.63467
# 439/439 [==============================] - 98s 223ms/step - loss: 0.1909 - categorical_accuracy: 0.7909 - val_loss: 0.8195 - val_categorical_accuracy: 0.6313
# Epoch 43/100
# 439/439 [==============================] - ETA: 0s - loss: 0.1849 - categorical_accuracy: 0.7925
# Epoch 00043: val_categorical_accuracy improved from 0.63467 to 0.63500, saving model to /content/drive/My Drive/SMOMI/w-4_3-2.hdf5
# 439/439 [==============================] - 99s 226ms/step - loss: 0.1849 - categorical_accuracy: 0.7925 - val_loss: 0.8083 - val_categorical_accuracy: 0.6350
# Epoch 44/100
# 439/439 [==============================] - ETA: 0s - loss: 0.1822 - categorical_accuracy: 0.7910
# Epoch 00044: val_categorical_accuracy did not improve from 0.63500
# 439/439 [==============================] - 97s 222ms/step - loss: 0.1822 - categorical_accuracy: 0.7910 - val_loss: 0.8681 - val_categorical_accuracy: 0.5923
# Epoch 45/100
# 439/439 [==============================] - ETA: 0s - loss: 0.1785 - categorical_accuracy: 0.7891
# Epoch 00045: val_categorical_accuracy did not improve from 0.63500
# 439/439 [==============================] - 96s 220ms/step - loss: 0.1785 - categorical_accuracy: 0.7891 - val_loss: 0.8189 - val_categorical_accuracy: 0.6273
# Epoch 46/100
# 439/439 [==============================] - ETA: 0s - loss: 0.1737 - categorical_accuracy: 0.7927
# Epoch 00046: val_categorical_accuracy did not improve from 0.63500
# 439/439 [==============================] - 96s 219ms/step - loss: 0.1737 - categorical_accuracy: 0.7927 - val_loss: 0.8188 - val_categorical_accuracy: 0.6257
# Epoch 47/100
# 439/439 [==============================] - ETA: 0s - loss: 0.1734 - categorical_accuracy: 0.7919
# Epoch 00047: val_categorical_accuracy improved from 0.63500 to 0.63567, saving model to /content/drive/My Drive/SMOMI/w-4_3-2.hdf5
# 439/439 [==============================] - 98s 222ms/step - loss: 0.1734 - categorical_accuracy: 0.7919 - val_loss: 0.8153 - val_categorical_accuracy: 0.6357
# Epoch 48/100
# 439/439 [==============================] - ETA: 0s - loss: 0.1672 - categorical_accuracy: 0.7936
# Epoch 00048: val_categorical_accuracy did not improve from 0.63567
# 439/439 [==============================] - 97s 221ms/step - loss: 0.1672 - categorical_accuracy: 0.7936 - val_loss: 0.8488 - val_categorical_accuracy: 0.6070
# Epoch 49/100
# 439/439 [==============================] - ETA: 0s - loss: 0.1774 - categorical_accuracy: 0.7886
# Epoch 00049: val_categorical_accuracy did not improve from 0.63567
# 439/439 [==============================] - 97s 220ms/step - loss: 0.1774 - categorical_accuracy: 0.7886 - val_loss: 0.8365 - val_categorical_accuracy: 0.6050
# Epoch 50/100
# 439/439 [==============================] - ETA: 0s - loss: 0.1658 - categorical_accuracy: 0.7929
# Epoch 00050: val_categorical_accuracy improved from 0.63567 to 0.63800, saving model to /content/drive/My Drive/SMOMI/w-4_3-2.hdf5
# 439/439 [==============================] - 99s 226ms/step - loss: 0.1658 - categorical_accuracy: 0.7929 - val_loss: 0.7997 - val_categorical_accuracy: 0.6380
# Epoch 51/100
# 439/439 [==============================] - ETA: 0s - loss: 0.1569 - categorical_accuracy: 0.7938
# Epoch 00051: val_categorical_accuracy did not improve from 0.63800
# 439/439 [==============================] - 98s 224ms/step - loss: 0.1569 - categorical_accuracy: 0.7938 - val_loss: 0.7936 - val_categorical_accuracy: 0.6347
# Epoch 52/100
# 439/439 [==============================] - ETA: 0s - loss: 0.1583 - categorical_accuracy: 0.7951
# Epoch 00052: val_categorical_accuracy did not improve from 0.63800
# 439/439 [==============================] - 98s 222ms/step - loss: 0.1583 - categorical_accuracy: 0.7951 - val_loss: 0.7915 - val_categorical_accuracy: 0.6283
# Epoch 53/100
# 439/439 [==============================] - ETA: 0s - loss: 0.1590 - categorical_accuracy: 0.7923
# Epoch 00053: val_categorical_accuracy improved from 0.63800 to 0.64933, saving model to /content/drive/My Drive/SMOMI/w-4_3-2.hdf5
# 439/439 [==============================] - 99s 226ms/step - loss: 0.1590 - categorical_accuracy: 0.7923 - val_loss: 0.7772 - val_categorical_accuracy: 0.6493
# Epoch 54/100
# 439/439 [==============================] - ETA: 0s - loss: 0.1520 - categorical_accuracy: 0.7934
# Epoch 00054: val_categorical_accuracy improved from 0.64933 to 0.64967, saving model to /content/drive/My Drive/SMOMI/w-4_3-2.hdf5
# 439/439 [==============================] - 98s 224ms/step - loss: 0.1520 - categorical_accuracy: 0.7934 - val_loss: 0.7689 - val_categorical_accuracy: 0.6497
# Epoch 55/100
# 439/439 [==============================] - ETA: 0s - loss: 0.1481 - categorical_accuracy: 0.7950
# Epoch 00055: val_categorical_accuracy did not improve from 0.64967
# 439/439 [==============================] - 97s 221ms/step - loss: 0.1481 - categorical_accuracy: 0.7950 - val_loss: 0.7820 - val_categorical_accuracy: 0.6417
# Epoch 56/100
# 439/439 [==============================] - ETA: 0s - loss: 0.1432 - categorical_accuracy: 0.7960
# Epoch 00056: val_categorical_accuracy improved from 0.64967 to 0.65600, saving model to /content/drive/My Drive/SMOMI/w-4_3-2.hdf5
# 439/439 [==============================] - 99s 225ms/step - loss: 0.1432 - categorical_accuracy: 0.7960 - val_loss: 0.7528 - val_categorical_accuracy: 0.6560
# Epoch 57/100
# 439/439 [==============================] - ETA: 0s - loss: 0.1359 - categorical_accuracy: 0.7996
# Epoch 00057: val_categorical_accuracy did not improve from 0.65600
# 439/439 [==============================] - 98s 223ms/step - loss: 0.1359 - categorical_accuracy: 0.7996 - val_loss: 0.7578 - val_categorical_accuracy: 0.6477
# Epoch 58/100
# 439/439 [==============================] - ETA: 0s - loss: 0.1446 - categorical_accuracy: 0.7953
# Epoch 00058: val_categorical_accuracy did not improve from 0.65600
# 439/439 [==============================] - 97s 221ms/step - loss: 0.1446 - categorical_accuracy: 0.7953 - val_loss: 0.7602 - val_categorical_accuracy: 0.6553
# Epoch 59/100
# 439/439 [==============================] - ETA: 0s - loss: 0.1337 - categorical_accuracy: 0.7986
# Epoch 00059: val_categorical_accuracy did not improve from 0.65600
# 439/439 [==============================] - 96s 219ms/step - loss: 0.1337 - categorical_accuracy: 0.7986 - val_loss: 0.7782 - val_categorical_accuracy: 0.6453
# Epoch 60/100
# 439/439 [==============================] - ETA: 0s - loss: 0.1337 - categorical_accuracy: 0.7986
# Epoch 00060: val_categorical_accuracy did not improve from 0.65600
# 439/439 [==============================] - 96s 219ms/step - loss: 0.1337 - categorical_accuracy: 0.7986 - val_loss: 0.7725 - val_categorical_accuracy: 0.6447
# Epoch 61/100
# 439/439 [==============================] - ETA: 0s - loss: 0.1339 - categorical_accuracy: 0.7969
# Epoch 00061: val_categorical_accuracy did not improve from 0.65600
# 439/439 [==============================] - 98s 222ms/step - loss: 0.1339 - categorical_accuracy: 0.7969 - val_loss: 0.7605 - val_categorical_accuracy: 0.6480
# Epoch 62/100
# 439/439 [==============================] - ETA: 0s - loss: 0.1371 - categorical_accuracy: 0.7952
# Epoch 00062: val_categorical_accuracy did not improve from 0.65600
# 439/439 [==============================] - 96s 219ms/step - loss: 0.1371 - categorical_accuracy: 0.7952 - val_loss: 0.7646 - val_categorical_accuracy: 0.6547
# Epoch 63/100
# 439/439 [==============================] - ETA: 0s - loss: 0.1353 - categorical_accuracy: 0.7993
# Epoch 00063: val_categorical_accuracy improved from 0.65600 to 0.66833, saving model to /content/drive/My Drive/SMOMI/w-4_3-2.hdf5
# 439/439 [==============================] - 98s 223ms/step - loss: 0.1353 - categorical_accuracy: 0.7993 - val_loss: 0.7364 - val_categorical_accuracy: 0.6683
# Epoch 64/100
# 439/439 [==============================] - ETA: 0s - loss: 0.1229 - categorical_accuracy: 0.8003
# Epoch 00064: val_categorical_accuracy improved from 0.66833 to 0.67267, saving model to /content/drive/My Drive/SMOMI/w-4_3-2.hdf5
# 439/439 [==============================] - 99s 225ms/step - loss: 0.1229 - categorical_accuracy: 0.8003 - val_loss: 0.7266 - val_categorical_accuracy: 0.6727
# Epoch 65/100
# 439/439 [==============================] - ETA: 0s - loss: 0.1155 - categorical_accuracy: 0.8039
# Epoch 00065: val_categorical_accuracy improved from 0.67267 to 0.67700, saving model to /content/drive/My Drive/SMOMI/w-4_3-2.hdf5
# 439/439 [==============================] - 99s 224ms/step - loss: 0.1155 - categorical_accuracy: 0.8039 - val_loss: 0.7398 - val_categorical_accuracy: 0.6770
# Epoch 66/100
# 439/439 [==============================] - ETA: 0s - loss: 0.1201 - categorical_accuracy: 0.8000
# Epoch 00066: val_categorical_accuracy improved from 0.67700 to 0.67800, saving model to /content/drive/My Drive/SMOMI/w-4_3-2.hdf5
# 439/439 [==============================] - 99s 224ms/step - loss: 0.1201 - categorical_accuracy: 0.8000 - val_loss: 0.7272 - val_categorical_accuracy: 0.6780
# Epoch 67/100
# 439/439 [==============================] - ETA: 0s - loss: 0.1185 - categorical_accuracy: 0.7989
# Epoch 00067: val_categorical_accuracy did not improve from 0.67800
# 439/439 [==============================] - 97s 222ms/step - loss: 0.1185 - categorical_accuracy: 0.7989 - val_loss: 0.7510 - val_categorical_accuracy: 0.6583
# Epoch 68/100
# 439/439 [==============================] - ETA: 0s - loss: 0.1137 - categorical_accuracy: 0.8037
# Epoch 00068: val_categorical_accuracy did not improve from 0.67800
# 439/439 [==============================] - 97s 221ms/step - loss: 0.1137 - categorical_accuracy: 0.8037 - val_loss: 0.7320 - val_categorical_accuracy: 0.6640
# Epoch 69/100
# 439/439 [==============================] - ETA: 0s - loss: 0.1138 - categorical_accuracy: 0.8022
# Epoch 00069: val_categorical_accuracy did not improve from 0.67800
# 439/439 [==============================] - 98s 224ms/step - loss: 0.1138 - categorical_accuracy: 0.8022 - val_loss: 0.6889 - val_categorical_accuracy: 0.6780
# Epoch 70/100
# 439/439 [==============================] - ETA: 0s - loss: 0.1133 - categorical_accuracy: 0.8014
# Epoch 00070: val_categorical_accuracy improved from 0.67800 to 0.68633, saving model to /content/drive/My Drive/SMOMI/w-4_3-2.hdf5
# 439/439 [==============================] - 98s 223ms/step - loss: 0.1133 - categorical_accuracy: 0.8014 - val_loss: 0.6944 - val_categorical_accuracy: 0.6863
# Epoch 71/100
# 439/439 [==============================] - ETA: 0s - loss: 0.1085 - categorical_accuracy: 0.8029
# Epoch 00071: val_categorical_accuracy did not improve from 0.68633
# 439/439 [==============================] - 97s 221ms/step - loss: 0.1085 - categorical_accuracy: 0.8029 - val_loss: 0.7109 - val_categorical_accuracy: 0.6587
# Epoch 72/100
# 439/439 [==============================] - ETA: 0s - loss: 0.1092 - categorical_accuracy: 0.8025
# Epoch 00072: val_categorical_accuracy did not improve from 0.68633
# 439/439 [==============================] - 97s 222ms/step - loss: 0.1092 - categorical_accuracy: 0.8025 - val_loss: 0.7011 - val_categorical_accuracy: 0.6627
# Epoch 73/100
# 439/439 [==============================] - ETA: 0s - loss: 0.1105 - categorical_accuracy: 0.8040
# Epoch 00073: val_categorical_accuracy did not improve from 0.68633
# 439/439 [==============================] - 98s 223ms/step - loss: 0.1105 - categorical_accuracy: 0.8040 - val_loss: 0.7073 - val_categorical_accuracy: 0.6690
# Epoch 74/100
# 439/439 [==============================] - ETA: 0s - loss: 0.1078 - categorical_accuracy: 0.8050
# Epoch 00074: val_categorical_accuracy did not improve from 0.68633
# 439/439 [==============================] - 97s 220ms/step - loss: 0.1078 - categorical_accuracy: 0.8050 - val_loss: 0.7193 - val_categorical_accuracy: 0.6623
# Epoch 75/100
# 439/439 [==============================] - ETA: 0s - loss: 0.1070 - categorical_accuracy: 0.8043
# Epoch 00075: val_categorical_accuracy did not improve from 0.68633
# 439/439 [==============================] - 98s 223ms/step - loss: 0.1070 - categorical_accuracy: 0.8043 - val_loss: 0.6675 - val_categorical_accuracy: 0.6800
# Epoch 76/100
# 439/439 [==============================] - ETA: 0s - loss: 0.1066 - categorical_accuracy: 0.8032
# Epoch 00076: val_categorical_accuracy did not improve from 0.68633
# 439/439 [==============================] - 97s 221ms/step - loss: 0.1066 - categorical_accuracy: 0.8032 - val_loss: 0.6750 - val_categorical_accuracy: 0.6863
# Epoch 77/100
# 439/439 [==============================] - ETA: 0s - loss: 0.0997 - categorical_accuracy: 0.8064
# Epoch 00077: val_categorical_accuracy improved from 0.68633 to 0.68800, saving model to /content/drive/My Drive/SMOMI/w-4_3-2.hdf5
# 439/439 [==============================] - 100s 229ms/step - loss: 0.0997 - categorical_accuracy: 0.8064 - val_loss: 0.6717 - val_categorical_accuracy: 0.6880
# Epoch 78/100
# 439/439 [==============================] - ETA: 0s - loss: 0.1024 - categorical_accuracy: 0.8063
# Epoch 00078: val_categorical_accuracy did not improve from 0.68800
# 439/439 [==============================] - 98s 223ms/step - loss: 0.1024 - categorical_accuracy: 0.8063 - val_loss: 0.6719 - val_categorical_accuracy: 0.6827
# Epoch 79/100
# 439/439 [==============================] - ETA: 0s - loss: 0.1020 - categorical_accuracy: 0.8058
# Epoch 00079: val_categorical_accuracy did not improve from 0.68800
# 439/439 [==============================] - 97s 222ms/step - loss: 0.1020 - categorical_accuracy: 0.8058 - val_loss: 0.6758 - val_categorical_accuracy: 0.6830
# Epoch 80/100
# 439/439 [==============================] - ETA: 0s - loss: 0.0990 - categorical_accuracy: 0.8055
# Epoch 00080: val_categorical_accuracy did not improve from 0.68800
# 439/439 [==============================] - 97s 222ms/step - loss: 0.0990 - categorical_accuracy: 0.8055 - val_loss: 0.6750 - val_categorical_accuracy: 0.6793
# Epoch 81/100
# 439/439 [==============================] - ETA: 0s - loss: 0.0945 - categorical_accuracy: 0.8075
# Epoch 00081: val_categorical_accuracy did not improve from 0.68800
# 439/439 [==============================] - 98s 222ms/step - loss: 0.0945 - categorical_accuracy: 0.8075 - val_loss: 0.6592 - val_categorical_accuracy: 0.6850
# Epoch 82/100
# 439/439 [==============================] - ETA: 0s - loss: 0.1055 - categorical_accuracy: 0.8033
# Epoch 00082: val_categorical_accuracy improved from 0.68800 to 0.69633, saving model to /content/drive/My Drive/SMOMI/w-4_3-2.hdf5
# 439/439 [==============================] - 99s 225ms/step - loss: 0.1055 - categorical_accuracy: 0.8033 - val_loss: 0.6389 - val_categorical_accuracy: 0.6963
# Epoch 83/100
# 439/439 [==============================] - ETA: 0s - loss: 0.0995 - categorical_accuracy: 0.8049
# Epoch 00083: val_categorical_accuracy did not improve from 0.69633
# 439/439 [==============================] - 98s 223ms/step - loss: 0.0995 - categorical_accuracy: 0.8049 - val_loss: 0.6170 - val_categorical_accuracy: 0.6947
# Epoch 84/100
# 439/439 [==============================] - ETA: 0s - loss: 0.0934 - categorical_accuracy: 0.8069
# Epoch 00084: val_categorical_accuracy did not improve from 0.69633
# 439/439 [==============================] - 98s 223ms/step - loss: 0.0934 - categorical_accuracy: 0.8069 - val_loss: 0.6493 - val_categorical_accuracy: 0.6700
# Epoch 85/100
# 439/439 [==============================] - ETA: 0s - loss: 0.0941 - categorical_accuracy: 0.8098
# Epoch 00085: val_categorical_accuracy did not improve from 0.69633
# 439/439 [==============================] - 98s 222ms/step - loss: 0.0941 - categorical_accuracy: 0.8098 - val_loss: 0.6254 - val_categorical_accuracy: 0.6933
# Epoch 86/100
# 439/439 [==============================] - ETA: 0s - loss: 0.0910 - categorical_accuracy: 0.8092
# Epoch 00086: val_categorical_accuracy did not improve from 0.69633
# 439/439 [==============================] - 97s 222ms/step - loss: 0.0910 - categorical_accuracy: 0.8092 - val_loss: 0.6380 - val_categorical_accuracy: 0.6857
# Epoch 87/100
# 439/439 [==============================] - ETA: 0s - loss: 0.0956 - categorical_accuracy: 0.8064
# Epoch 00087: val_categorical_accuracy did not improve from 0.69633
# 439/439 [==============================] - 98s 222ms/step - loss: 0.0956 - categorical_accuracy: 0.8064 - val_loss: 0.6415 - val_categorical_accuracy: 0.6850
# Epoch 88/100
# 439/439 [==============================] - ETA: 0s - loss: 0.0939 - categorical_accuracy: 0.8069
# Epoch 00088: val_categorical_accuracy did not improve from 0.69633
# 439/439 [==============================] - 98s 222ms/step - loss: 0.0939 - categorical_accuracy: 0.8069 - val_loss: 0.6395 - val_categorical_accuracy: 0.6830
# Epoch 89/100
# 439/439 [==============================] - ETA: 0s - loss: 0.0954 - categorical_accuracy: 0.8062
# Epoch 00089: val_categorical_accuracy did not improve from 0.69633
# 439/439 [==============================] - 97s 221ms/step - loss: 0.0954 - categorical_accuracy: 0.8062 - val_loss: 0.6460 - val_categorical_accuracy: 0.6743
# Epoch 90/100
# 439/439 [==============================] - ETA: 0s - loss: 0.0887 - categorical_accuracy: 0.8090
# Epoch 00090: val_categorical_accuracy improved from 0.69633 to 0.70033, saving model to /content/drive/My Drive/SMOMI/w-4_3-2.hdf5
# 439/439 [==============================] - 98s 223ms/step - loss: 0.0887 - categorical_accuracy: 0.8090 - val_loss: 0.6207 - val_categorical_accuracy: 0.7003
# Epoch 91/100
# 439/439 [==============================] - ETA: 0s - loss: 0.0842 - categorical_accuracy: 0.8098
# Epoch 00091: val_categorical_accuracy did not improve from 0.70033
# 439/439 [==============================] - 97s 221ms/step - loss: 0.0842 - categorical_accuracy: 0.8098 - val_loss: 0.6068 - val_categorical_accuracy: 0.6933
# Epoch 92/100
# 439/439 [==============================] - ETA: 0s - loss: 0.0893 - categorical_accuracy: 0.8076
# Epoch 00092: val_categorical_accuracy did not improve from 0.70033
# 439/439 [==============================] - 99s 225ms/step - loss: 0.0893 - categorical_accuracy: 0.8076 - val_loss: 0.6053 - val_categorical_accuracy: 0.6957
# Epoch 93/100
# 439/439 [==============================] - ETA: 0s - loss: 0.0914 - categorical_accuracy: 0.8063
# Epoch 00093: val_categorical_accuracy did not improve from 0.70033
# 439/439 [==============================] - 98s 223ms/step - loss: 0.0914 - categorical_accuracy: 0.8063 - val_loss: 0.6112 - val_categorical_accuracy: 0.6880
# Epoch 94/100
# 439/439 [==============================] - ETA: 0s - loss: 0.0898 - categorical_accuracy: 0.8064
# Epoch 00094: val_categorical_accuracy did not improve from 0.70033
# 439/439 [==============================] - 98s 224ms/step - loss: 0.0898 - categorical_accuracy: 0.8064 - val_loss: 0.6261 - val_categorical_accuracy: 0.6843
# Epoch 95/100
# 439/439 [==============================] - ETA: 0s - loss: 0.0907 - categorical_accuracy: 0.8068
# Epoch 00095: val_categorical_accuracy did not improve from 0.70033
# 439/439 [==============================] - 97s 222ms/step - loss: 0.0907 - categorical_accuracy: 0.8068 - val_loss: 0.6214 - val_categorical_accuracy: 0.6857
# Epoch 96/100
# 439/439 [==============================] - ETA: 0s - loss: 0.0829 - categorical_accuracy: 0.8117
# Epoch 00096: val_categorical_accuracy did not improve from 0.70033
# 439/439 [==============================] - 98s 222ms/step - loss: 0.0829 - categorical_accuracy: 0.8117 - val_loss: 0.6326 - val_categorical_accuracy: 0.6803
# Epoch 97/100
# 439/439 [==============================] - ETA: 0s - loss: 0.0858 - categorical_accuracy: 0.8079
# Epoch 00097: val_categorical_accuracy did not improve from 0.70033
# 439/439 [==============================] - 98s 224ms/step - loss: 0.0858 - categorical_accuracy: 0.8079 - val_loss: 0.6530 - val_categorical_accuracy: 0.6587
# Epoch 98/100
# 439/439 [==============================] - ETA: 0s - loss: 0.0903 - categorical_accuracy: 0.8070
# Epoch 00098: val_categorical_accuracy did not improve from 0.70033
# 439/439 [==============================] - 97s 220ms/step - loss: 0.0903 - categorical_accuracy: 0.8070 - val_loss: 0.6121 - val_categorical_accuracy: 0.6887
# Epoch 99/100
# 439/439 [==============================] - ETA: 0s - loss: 0.0931 - categorical_accuracy: 0.8074
# Epoch 00099: val_categorical_accuracy did not improve from 0.70033
# 439/439 [==============================] - 96s 219ms/step - loss: 0.0931 - categorical_accuracy: 0.8074 - val_loss: 0.6321 - val_categorical_accuracy: 0.6783
# Epoch 100/100
# 439/439 [==============================] - ETA: 0s - loss: 0.0908 - categorical_accuracy: 0.8058
# Epoch 00100: val_categorical_accuracy did not improve from 0.70033
# 439/439 [==============================] - 96s 219ms/step - loss: 0.0908 - categorical_accuracy: 0.8058 - val_loss: 0.6307 - val_categorical_accuracy: 0.6793
